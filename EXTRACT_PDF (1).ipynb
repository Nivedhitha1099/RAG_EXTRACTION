# %%
# %%bash
#
# pip -qqq install pdfminer.six
# pip -qqq install pillow-heif==0.3.2
# pip -qqq install matplotlib
# pip -qqq install unstructured-inference
# pip -qqq install unstructured-pytesseract
# pip -qqq install tesseract-ocr
# pip -qqq install unstructured
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 23.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 12.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 61.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 55.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 83.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 75.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 86.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 71.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 23.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.4/149.4 kB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 44.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 586.9/586.9 kB 24.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.9/274.9 kB 14.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.9/62.9 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.9/434.9 kB 20.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 48.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 17.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 7.8 MB/s eta 0:00:00
#   ERROR: Failed building wheel for tesseract-ocr
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (tesseract-ocr)

# %%
# %%bash
# apt install tesseract-ocr
# apt install libtesseract-dev
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 49 not upgraded.
# Need to get 4,816 kB of archives.
# After this operation, 15.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1.1 [1,591 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1.1 [2,990 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr amd64 4.1.1-2.1build1 [236 kB]
# Fetched 4,816 kB in 2s (2,853 kB/s)
# Selecting previously unselected package tesseract-ocr-eng.
# (Reading database ... 123634 files and directories currently installed.)
# Preparing to unpack .../tesseract-ocr-eng_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# Unpacking tesseract-ocr-eng (1:4.00~git30-7274cfa-1.1) ...
# Selecting previously unselected package tesseract-ocr-osd.
# Preparing to unpack .../tesseract-ocr-osd_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# Unpacking tesseract-ocr-osd (1:4.00~git30-7274cfa-1.1) ...
# Selecting previously unselected package tesseract-ocr.
# Preparing to unpack .../tesseract-ocr_4.1.1-2.1build1_amd64.deb ...
# Unpacking tesseract-ocr (4.1.1-2.1build1) ...
# Setting up tesseract-ocr-eng (1:4.00~git30-7274cfa-1.1) ...
# Setting up tesseract-ocr-osd (1:4.00~git30-7274cfa-1.1) ...
# Setting up tesseract-ocr (4.1.1-2.1build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   libarchive-dev libleptonica-dev
# The following NEW packages will be installed:
#   libarchive-dev libleptonica-dev libtesseract-dev
# 0 upgraded, 3 newly installed, 0 to remove and 49 not upgraded.
# Need to get 3,743 kB of archives.
# After this operation, 16.0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libarchive-dev amd64 3.6.0-1ubuntu1.3 [581 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libleptonica-dev amd64 1.82.0-3build1 [1,562 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libtesseract-dev amd64 4.1.1-2.1build1 [1,600 kB]
# Fetched 3,743 kB in 2s (2,319 kB/s)
# Selecting previously unselected package libarchive-dev:amd64.
# (Reading database ... 123681 files and directories currently installed.)
# Preparing to unpack .../libarchive-dev_3.6.0-1ubuntu1.3_amd64.deb ...
# Unpacking libarchive-dev:amd64 (3.6.0-1ubuntu1.3) ...
# Selecting previously unselected package libleptonica-dev.
# Preparing to unpack .../libleptonica-dev_1.82.0-3build1_amd64.deb ...
# Unpacking libleptonica-dev (1.82.0-3build1) ...
# Selecting previously unselected package libtesseract-dev:amd64.
# Preparing to unpack .../libtesseract-dev_4.1.1-2.1build1_amd64.deb ...
# Unpacking libtesseract-dev:amd64 (4.1.1-2.1build1) ...
# Setting up libleptonica-dev (1.82.0-3build1) ...
# Setting up libarchive-dev:amd64 (3.6.0-1ubuntu1.3) ...
# Setting up libtesseract-dev:amd64 (4.1.1-2.1build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %%
# !pip install pi_heif
from unstructured.partition.pdf import partition_pdf
# Out:
# Collecting pi_heif
#   Downloading pi_heif-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.5 kB)
# Requirement already satisfied: pillow>=10.1.0 in /usr/local/lib/python3.10/dist-packages (from pi_heif) (11.0.0)
# Downloading pi_heif-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.8 MB/s eta 0:00:00
# Installing collected packages: pi_heif
# Successfully installed pi_heif-0.21.0

# %%
esg_report_path = "/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf"

# %%
# %%bash
# sudo apt-get update
# apt-get install poppler-utils
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:11 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,563 kB]
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [3,448 kB]
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,517 kB]
# Get:14 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,631 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,226 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,517 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,840 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [3,633 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [81.4 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [33.8 kB]
# Fetched 26.9 MB in 5s (5,752 kB/s)
# Reading package lists...
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 50 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 696 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.5 [186 kB]
# Fetched 186 kB in 0s (450 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 123814 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.5_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.5) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.5) ...
# Processing triggers for man-db (2.10.2-1) ...
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %%
esg_report_raw_data =partition_pdf(
    filename=esg_report_path,
    strategy="hi_res",
    extract_images_in_pdf=True,
    extract_image_block_to_payload=False,
    extract_image_block_output_dir="./data/images/"
    )
# Out:
# yolox_l0.05.onnx:   0%|          | 0.00/217M [00:00<?, ?B/s]

# %%
esg_report_raw_data
# Out:
# [<unstructured.documents.elements.Header at 0x7d62405b45e0>,
#  <unstructured.documents.elements.Header at 0x7d62405b4760>,
#  <unstructured.documents.elements.Title at 0x7d624e9f1780>,
#  <unstructured.documents.elements.Text at 0x7d6240628340>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405b4940>,
#  <unstructured.documents.elements.Title at 0x7d62405b4be0>,
#  <unstructured.documents.elements.Title at 0x7d6240628460>,
#  <unstructured.documents.elements.Title at 0x7d62406283a0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405b4790>,
#  <unstructured.documents.elements.Title at 0x7d624a3c1db0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405b5960>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624a3c2590>,
#  <unstructured.documents.elements.Table at 0x7d62405b5210>,
#  <unstructured.documents.elements.Title at 0x7d624a3c04c0>,
#  <unstructured.documents.elements.Title at 0x7d624a3c23b0>,
#  <unstructured.documents.elements.Text at 0x7d624a3c2170>,
#  <unstructured.documents.elements.Title at 0x7d624a3c2110>,
#  <unstructured.documents.elements.Text at 0x7d624a3c2140>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405b5900>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405b4fd0>,
#  <unstructured.documents.elements.Text at 0x7d624a3c0580>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405b53c0>,
#  <unstructured.documents.elements.Title at 0x7d624a3c20b0>,
#  <unstructured.documents.elements.Header at 0x7d62405b6fb0>,
#  <unstructured.documents.elements.Image at 0x7d62405b7130>,
#  <unstructured.documents.elements.Title at 0x7d62405b72e0>,
#  <unstructured.documents.elements.Title at 0x7d62405b6dd0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405b7640>,
#  <unstructured.documents.elements.FigureCaption at 0x7d62405b7310>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624a3c2770>,
#  <unstructured.documents.elements.Text at 0x7d624a3c0760>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624a3c2740>,
#  <unstructured.documents.elements.Table at 0x7d62405b78b0>,
#  <unstructured.documents.elements.Text at 0x7d624a3c17e0>,
#  <unstructured.documents.elements.Text at 0x7d624a3c2410>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405b76a0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405b7ac0>,
#  <unstructured.documents.elements.Title at 0x7d624a3c1810>,
#  <unstructured.documents.elements.ListItem at 0x7d62405b7850>,
#  <unstructured.documents.elements.ListItem at 0x7d62405b7df0>,
#  <unstructured.documents.elements.ListItem at 0x7d62405b7be0>,
#  <unstructured.documents.elements.ListItem at 0x7d62405b7fd0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405b5a50>,
#  <unstructured.documents.elements.Text at 0x7d624a3c24a0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6249da03d0>,
#  <unstructured.documents.elements.Text at 0x7d624a3c2b30>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6249da29b0>,
#  <unstructured.documents.elements.Header at 0x7d62498b46d0>,
#  <unstructured.documents.elements.Header at 0x7d62498b5210>,
#  <unstructured.documents.elements.ListItem at 0x7d62498b5870>,
#  <unstructured.documents.elements.Title at 0x7d62498b4430>,
#  <unstructured.documents.elements.Title at 0x7d62498b7d90>,
#  <unstructured.documents.elements.Title at 0x7d62498b7430>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62498b6a70>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62498b4fa0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62498b7f40>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62498b4610>,
#  <unstructured.documents.elements.Title at 0x7d62498b72b0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62498b6380>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62498b5660>,
#  <unstructured.documents.elements.Image at 0x7d62498b51e0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62498b4130>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62498b5ff0>,
#  <unstructured.documents.elements.ListItem at 0x7d62498b6320>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62498b5420>,
#  <unstructured.documents.elements.ListItem at 0x7d62498b4640>,
#  <unstructured.documents.elements.ListItem at 0x7d62498b7f10>,
#  <unstructured.documents.elements.ListItem at 0x7d62496525c0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62496512a0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6249650730>,
#  <unstructured.documents.elements.Header at 0x7d6249651f60>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6249652e00>,
#  <unstructured.documents.elements.Header at 0x7d62496502e0>,
#  <unstructured.documents.elements.Header at 0x7d6249650f10>,
#  <unstructured.documents.elements.ListItem at 0x7d6249653f40>,
#  <unstructured.documents.elements.Image at 0x7d6249650190>,
#  <unstructured.documents.elements.Title at 0x7d6249650220>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62496536a0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62496505b0>,
#  <unstructured.documents.elements.ListItem at 0x7d6249653670>,
#  <unstructured.documents.elements.ListItem at 0x7d6249651270>,
#  <unstructured.documents.elements.Text at 0x7d624a3c2ad0>,
#  <unstructured.documents.elements.ListItem at 0x7d62496521a0>,
#  <unstructured.documents.elements.Image at 0x7d6249652710>,
#  <unstructured.documents.elements.Title at 0x7d6249650cd0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6249652c20>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6249652560>,
#  <unstructured.documents.elements.Table at 0x7d62496528f0>,
#  <unstructured.documents.elements.Title at 0x7d6249651a80>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62496538b0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6249653ee0>,
#  <unstructured.documents.elements.Text at 0x7d624a3c13c0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6249651990>,
#  <unstructured.documents.elements.Header at 0x7d62405bd900>,
#  <unstructured.documents.elements.Header at 0x7d62405bd630>,
#  <unstructured.documents.elements.ListItem at 0x7d62405bc250>,
#  <unstructured.documents.elements.Title at 0x7d62405bc100>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405bc310>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405bc970>,
#  <unstructured.documents.elements.FigureCaption at 0x7d62405bc910>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405bc2b0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405bc7f0>,
#  <unstructured.documents.elements.ListItem at 0x7d62405bc850>,
#  <unstructured.documents.elements.ListItem at 0x7d62405bcdf0>,
#  <unstructured.documents.elements.ListItem at 0x7d62405bcf10>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405bcd00>,
#  <unstructured.documents.elements.Table at 0x7d62405bd0f0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405bdc30>,
#  <unstructured.documents.elements.Title at 0x7d62405bd840>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405bdbd0>,
#  <unstructured.documents.elements.Image at 0x7d62405bd960>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405bd4b0>,
#  <unstructured.documents.elements.Text at 0x7d624a3c1d20>,
#  <unstructured.documents.elements.Text at 0x7d624a3c2b90>,
#  <unstructured.documents.elements.Header at 0x7d62405be980>,
#  <unstructured.documents.elements.Header at 0x7d62405bec80>,
#  <unstructured.documents.elements.ListItem at 0x7d62405be1a0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405be9e0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405bf0a0>,
#  <unstructured.documents.elements.ListItem at 0x7d62405bf790>,
#  <unstructured.documents.elements.ListItem at 0x7d62405bfaf0>,
#  <unstructured.documents.elements.Title at 0x7d62405bf640>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405bf9a0>,
#  <unstructured.documents.elements.Title at 0x7d62405bfcd0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405bffa0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405bfb80>,
#  <unstructured.documents.elements.FigureCaption at 0x7d62405bffd0>,
#  <unstructured.documents.elements.Title at 0x7d624a3c29b0>,
#  <unstructured.documents.elements.Table at 0x7d62405bc460>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405bc670>,
#  <unstructured.documents.elements.Title at 0x7d624a3c06a0>,
#  <unstructured.documents.elements.Title at 0x7d624a3c1bd0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405bc700>,
#  <unstructured.documents.elements.Title at 0x7d624a374ee0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624a377700>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624a374610>,
#  <unstructured.documents.elements.Title at 0x7d624a376e60>,
#  <unstructured.documents.elements.Text at 0x7d624a3c1b70>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624a3763e0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624a3768c0>,
#  <unstructured.documents.elements.Title at 0x7d624a377c10>,
#  <unstructured.documents.elements.Text at 0x7d624a3c0ca0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624a377640>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624a377940>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62497d5cf0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624a377ca0>,
#  <unstructured.documents.elements.Header at 0x7d62497d4ca0>,
#  <unstructured.documents.elements.Header at 0x7d62497d4fa0>,
#  <unstructured.documents.elements.ListItem at 0x7d62497d5f30>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62497d4970>,
#  <unstructured.documents.elements.Table at 0x7d624c9cdc60>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624983b490>,
#  <unstructured.documents.elements.Title at 0x7d624983bc10>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62498381c0>,
#  <unstructured.documents.elements.Title at 0x7d624a3c2350>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6249838ac0>,
#  <unstructured.documents.elements.Title at 0x7d624983b580>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624983ba90>,
#  <unstructured.documents.elements.Title at 0x7d624a3c22c0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6249838340>,
#  <unstructured.documents.elements.Title at 0x7d624a37c640>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6249ab3c70>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624a37c550>,
#  <unstructured.documents.elements.Title at 0x7d6249ab0fd0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6249ab36a0>,
#  <unstructured.documents.elements.Title at 0x7d624a3c2320>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6249ab1570>,
#  <unstructured.documents.elements.Title at 0x7d6249ab0f10>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6249ab2620>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6249ab0c10>,
#  <unstructured.documents.elements.ListItem at 0x7d6249ab0790>,
#  <unstructured.documents.elements.ListItem at 0x7d6249ab37f0>,
#  <unstructured.documents.elements.ListItem at 0x7d6249ab06a0>,
#  <unstructured.documents.elements.ListItem at 0x7d6249ab3f40>,
#  <unstructured.documents.elements.Title at 0x7d6249ab2890>,
#  <unstructured.documents.elements.Text at 0x7d624a3c1540>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240576a70>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6249ab01f0>,
#  <unstructured.documents.elements.Title at 0x7d62405742b0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240575450>,
#  <unstructured.documents.elements.Title at 0x7d624a3c0070>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405765c0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240575420>,
#  <unstructured.documents.elements.Text at 0x7d624a3c1060>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240575630>,
#  <unstructured.documents.elements.Header at 0x7d6240575e70>,
#  <unstructured.documents.elements.Header at 0x7d6240576e30>,
#  <unstructured.documents.elements.ListItem at 0x7d6240576c80>,
#  <unstructured.documents.elements.Title at 0x7d6240576b00>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405766e0>,
#  <unstructured.documents.elements.ListItem at 0x7d62405762f0>,
#  <unstructured.documents.elements.Title at 0x7d6240576650>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240577820>,
#  <unstructured.documents.elements.ListItem at 0x7d6240577550>,
#  <unstructured.documents.elements.ListItem at 0x7d6240577430>,
#  <unstructured.documents.elements.ListItem at 0x7d62405779d0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624a3c1f30>,
#  <unstructured.documents.elements.ListItem at 0x7d6240577d60>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624a3c1ea0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624a3c0550>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624a3c1f00>,
#  <unstructured.documents.elements.ListItem at 0x7d6240577c40>,
#  <unstructured.documents.elements.Title at 0x7d624a3c0220>,
#  <unstructured.documents.elements.ListItem at 0x7d6240577bb0>,
#  <unstructured.documents.elements.ListItem at 0x7d6240577fd0>,
#  <unstructured.documents.elements.Title at 0x7d6240575870>,
#  <unstructured.documents.elements.Title at 0x7d6240574550>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240575690>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240574970>,
#  <unstructured.documents.elements.ListItem at 0x7d624a3c01f0>,
#  <unstructured.documents.elements.Table at 0x7d6240574910>,
#  <unstructured.documents.elements.Title at 0x7d6240575180>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240575540>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240577040>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624975faf0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624975fc10>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624975df00>,
#  <unstructured.documents.elements.Header at 0x7d624975f370>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624975ff70>,
#  <unstructured.documents.elements.Text at 0x7d624a3c2f80>,
#  <unstructured.documents.elements.Header at 0x7d624975ead0>,
#  <unstructured.documents.elements.Header at 0x7d624975eb00>,
#  <unstructured.documents.elements.ListItem at 0x7d624975fc70>,
#  <unstructured.documents.elements.Table at 0x7d624975f220>,
#  <unstructured.documents.elements.Title at 0x7d624a3c1030>,
#  <unstructured.documents.elements.Title at 0x7d624a3c0e80>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624975fbe0>,
#  <unstructured.documents.elements.Table at 0x7d624975fe80>,
#  <unstructured.documents.elements.Title at 0x7d624a3c1000>,
#  <unstructured.documents.elements.Title at 0x7d624a3c10f0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240548eb0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240549cf0>,
#  <unstructured.documents.elements.Table at 0x7d6240548790>,
#  <unstructured.documents.elements.Title at 0x7d624a3c0250>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240548610>,
#  <unstructured.documents.elements.Table at 0x7d6240548f70>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624a3c0280>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240548d00>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624054afb0>,
#  <unstructured.documents.elements.Table at 0x7d624054b220>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624054a500>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624054bc10>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624054aaa0>,
#  <unstructured.documents.elements.Text at 0x7d624a3c1ae0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624054a8c0>,
#  <unstructured.documents.elements.Header at 0x7d6240548430>,
#  <unstructured.documents.elements.Header at 0x7d62405499c0>,
#  <unstructured.documents.elements.ListItem at 0x7d6240548c10>,
#  <unstructured.documents.elements.Table at 0x7d62405c40d0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405c42b0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405c4250>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405c4340>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405c46a0>,
#  <unstructured.documents.elements.Table at 0x7d62405c47f0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405c4790>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405c4880>,
#  <unstructured.documents.elements.Title at 0x7d62405c4be0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405c4d30>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405c4cd0>,
#  <unstructured.documents.elements.Table at 0x7d62405c5030>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405c51e0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405c5240>,
#  <unstructured.documents.elements.Table at 0x7d62405c5390>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405c5570>,
#  <unstructured.documents.elements.Table at 0x7d62405c5720>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405c5780>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405c58d0>,
#  <unstructured.documents.elements.Text at 0x7d624a3c1ab0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405c5ab0>,
#  <unstructured.documents.elements.Header at 0x7d62405c5c90>,
#  <unstructured.documents.elements.Header at 0x7d62405c5e10>,
#  <unstructured.documents.elements.ListItem at 0x7d62405c5ff0>,
#  <unstructured.documents.elements.Table at 0x7d62405c6680>,
#  <unstructured.documents.elements.Title at 0x7d624a3c1150>,
#  <unstructured.documents.elements.Title at 0x7d6249750100>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405c66e0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405c67a0>,
#  <unstructured.documents.elements.Table at 0x7d62405c6bc0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405c7100>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405c7160>,
#  <unstructured.documents.elements.Table at 0x7d62405c7220>,
#  <unstructured.documents.elements.Title at 0x7d62497500a0>,
#  <unstructured.documents.elements.Title at 0x7d6249750070>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405c6080>,
#  <unstructured.documents.elements.Table at 0x7d62405c7af0>,
#  <unstructured.documents.elements.Title at 0x7d6249750220>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405c7b20>,
#  <unstructured.documents.elements.Table at 0x7d62405c7b80>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405c7d90>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405c7f40>,
#  <unstructured.documents.elements.Title at 0x7d624a31d930>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624a31d810>,
#  <unstructured.documents.elements.Text at 0x7d6249753f40>,
#  <unstructured.documents.elements.Text at 0x7d6249753fa0>,
#  <unstructured.documents.elements.Header at 0x7d624a31da50>,
#  <unstructured.documents.elements.Header at 0x7d624a31da80>,
#  <unstructured.documents.elements.ListItem at 0x7d62499fecb0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62499fd930>,
#  <unstructured.documents.elements.Title at 0x7d6249753e50>,
#  <unstructured.documents.elements.Table at 0x7d62499fc910>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62499fdb40>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62499fd0c0>,
#  <unstructured.documents.elements.Text at 0x7d6249753fd0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62499ff1f0>,
#  <unstructured.documents.elements.Header at 0x7d62499fca30>,
#  <unstructured.documents.elements.Header at 0x7d62499fdcf0>,
#  <unstructured.documents.elements.ListItem at 0x7d62499fda20>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62499fd810>,
#  <unstructured.documents.elements.Text at 0x7d6249753dc0>,
#  <unstructured.documents.elements.Title at 0x7d62499fcb80>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62499fd3c0>,
#  <unstructured.documents.elements.Text at 0x7d6249753cd0>,
#  <unstructured.documents.elements.Text at 0x7d6249753d00>,
#  <unstructured.documents.elements.Text at 0x7d6249753ca0>,
#  <unstructured.documents.elements.Text at 0x7d6249753bb0>,
#  <unstructured.documents.elements.Title at 0x7d6249753be0>,
#  <unstructured.documents.elements.Text at 0x7d62497502b0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62499fe740>,
#  <unstructured.documents.elements.Text at 0x7d6249753b80>,
#  <unstructured.documents.elements.Title at 0x7d6249753a90>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624c5a8eb0>,
#  <unstructured.documents.elements.Table at 0x7d62499fcbe0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240578670>,
#  <unstructured.documents.elements.Text at 0x7d6249753ac0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624057a740>,
#  <unstructured.documents.elements.Header at 0x7d624057a080>,
#  <unstructured.documents.elements.Header at 0x7d624057ad10>,
#  <unstructured.documents.elements.Title at 0x7d624057ab00>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624057ac50>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624057bf40>,
#  <unstructured.documents.elements.Table at 0x7d624057a7a0>,
#  <unstructured.documents.elements.Title at 0x7d6249753a60>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624057b7c0>,
#  <unstructured.documents.elements.FigureCaption at 0x7d624057b5e0>,
#  <unstructured.documents.elements.Title at 0x7d624057b3a0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624057a4d0>,
#  <unstructured.documents.elements.Title at 0x7d6249753970>,
#  <unstructured.documents.elements.ListItem at 0x7d624057b400>,
#  <unstructured.documents.elements.ListItem at 0x7d624057bd60>,
#  <unstructured.documents.elements.ListItem at 0x7d6240578bb0>,
#  <unstructured.documents.elements.ListItem at 0x7d6240579990>,
#  <unstructured.documents.elements.ListItem at 0x7d624057b7f0>,
#  <unstructured.documents.elements.ListItem at 0x7d6240579f90>,
#  <unstructured.documents.elements.ListItem at 0x7d6240579300>,
#  <unstructured.documents.elements.ListItem at 0x7d6240579a50>,
#  <unstructured.documents.elements.ListItem at 0x7d6240579ab0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624057aa40>,
#  <unstructured.documents.elements.Text at 0x7d62497509a0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624057b190>,
#  <unstructured.documents.elements.Title at 0x7d6249752440>,
#  <unstructured.documents.elements.Header at 0x7d62405f03a0>,
#  <unstructured.documents.elements.Header at 0x7d62405f0580>,
#  <unstructured.documents.elements.ListItem at 0x7d62405f0850>,
#  <unstructured.documents.elements.ListItem at 0x7d62405f0880>,
#  <unstructured.documents.elements.ListItem at 0x7d62405f0a30>,
#  <unstructured.documents.elements.ListItem at 0x7d62405f0a60>,
#  <unstructured.documents.elements.Title at 0x7d6249751780>,
#  <unstructured.documents.elements.Title at 0x7d62405f0d90>,
#  <unstructured.documents.elements.ListItem at 0x7d6249750310>,
#  <unstructured.documents.elements.Title at 0x7d62405f0dc0>,
#  <unstructured.documents.elements.ListItem at 0x7d6249750340>,
#  <unstructured.documents.elements.ListItem at 0x7d62405f0f70>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62497501f0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62497501c0>,
#  <unstructured.documents.elements.Table at 0x7d62405f12d0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405f1300>,
#  <unstructured.documents.elements.Table at 0x7d62405f14b0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405f14e0>,
#  <unstructured.documents.elements.Table at 0x7d62405f1810>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405f1840>,
#  <unstructured.documents.elements.Table at 0x7d62405f19f0>,
#  <unstructured.documents.elements.ListItem at 0x7d62405f1a20>,
#  <unstructured.documents.elements.Table at 0x7d62405f1d50>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405f1d80>,
#  <unstructured.documents.elements.Table at 0x7d62405f1f30>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405f1f60>,
#  <unstructured.documents.elements.Table at 0x7d62405f2290>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405f22c0>,
#  <unstructured.documents.elements.Text at 0x7d6249752290>,
#  <unstructured.documents.elements.Text at 0x7d6249751630>,
#  <unstructured.documents.elements.Header at 0x7d62405f2ce0>,
#  <unstructured.documents.elements.Header at 0x7d62405f3010>,
#  <unstructured.documents.elements.ListItem at 0x7d62405f32b0>,
#  <unstructured.documents.elements.Table at 0x7d62405f3550>,
#  <unstructured.documents.elements.Table at 0x7d62405f3a90>,
#  <unstructured.documents.elements.Title at 0x7d6249751600>,
#  <unstructured.documents.elements.Title at 0x7d62405f3be0>,
#  <unstructured.documents.elements.Title at 0x7d62405f3d30>,
#  <unstructured.documents.elements.Title at 0x7d62405f3e80>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62406280d0>,
#  <unstructured.documents.elements.Text at 0x7d62497515d0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240628160>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240628400>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62406286a0>,
#  <unstructured.documents.elements.Text at 0x7d62497516c0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62406287f0>,
#  <unstructured.documents.elements.Header at 0x7d6240628d00>,
#  <unstructured.documents.elements.Header at 0x7d6240628e80>,
#  <unstructured.documents.elements.ListItem at 0x7d6240628fd0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240629120>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240629270>,
#  <unstructured.documents.elements.ListItem at 0x7d62406293c0>,
#  <unstructured.documents.elements.ListItem at 0x7d6240629510>,
#  <unstructured.documents.elements.ListItem at 0x7d6240629660>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62406297b0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240629900>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240629a50>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240629ba0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240629cf0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240629e40>,
#  <unstructured.documents.elements.Title at 0x7d624062a0e0>,
#  <unstructured.documents.elements.Title at 0x7d6240629f90>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624062a230>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624062a380>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624062a4d0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624062a8c0>,
#  <unstructured.documents.elements.Header at 0x7d624062a620>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624062a770>,
#  <unstructured.documents.elements.Header at 0x7d624062a9e0>,
#  <unstructured.documents.elements.Header at 0x7d624062ab90>,
#  <unstructured.documents.elements.Title at 0x7d624062acb0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624062ae00>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624062af50>,
#  <unstructured.documents.elements.Title at 0x7d624062b0a0>,
#  <unstructured.documents.elements.Title at 0x7d6249751810>,
#  <unstructured.documents.elements.Text at 0x7d6249751840>,
#  <unstructured.documents.elements.Text at 0x7d6249751900>,
#  <unstructured.documents.elements.Title at 0x7d62497518d0>,
#  <unstructured.documents.elements.Text at 0x7d62497519c0>,
#  <unstructured.documents.elements.Title at 0x7d62497529b0>,
#  <unstructured.documents.elements.Title at 0x7d62497519f0>,
#  <unstructured.documents.elements.Text at 0x7d6249752950>,
#  <unstructured.documents.elements.Text at 0x7d6249752890>,
#  <unstructured.documents.elements.Title at 0x7d62497528c0>,
#  <unstructured.documents.elements.Title at 0x7d62497527d0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624062b490>,
#  <unstructured.documents.elements.Title at 0x7d6249752770>,
#  <unstructured.documents.elements.Title at 0x7d6249752710>,
#  <unstructured.documents.elements.Text at 0x7d62497528f0>,
#  <unstructured.documents.elements.Text at 0x7d6249752620>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624062bb20>,
#  <unstructured.documents.elements.Title at 0x7d624062b880>,
#  <unstructured.documents.elements.Table at 0x7d624062b9d0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624062bc70>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624062bdc0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624062bf10>,
#  <unstructured.documents.elements.Title at 0x7d62497525c0>,
#  <unstructured.documents.elements.Table at 0x7d62404381f0>,
#  <unstructured.documents.elements.Title at 0x7d6240438490>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404385e0>,
#  <unstructured.documents.elements.Title at 0x7d62497525f0>,
#  <unstructured.documents.elements.Title at 0x7d6249752560>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240438880>,
#  <unstructured.documents.elements.Text at 0x7d6249752350>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404389d0>,
#  <unstructured.documents.elements.Header at 0x7d624043a410>,
#  <unstructured.documents.elements.Header at 0x7d624043a590>,
#  <unstructured.documents.elements.ListItem at 0x7d624043a6e0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624043a830>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624043a980>,
#  <unstructured.documents.elements.Title at 0x7d624043aad0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624043ac20>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624043ad70>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624043aec0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624043b010>,
#  <unstructured.documents.elements.Title at 0x7d624043b160>,
#  <unstructured.documents.elements.Table at 0x7d624043b430>,
#  <unstructured.documents.elements.Title at 0x7d6249752410>,
#  <unstructured.documents.elements.Table at 0x7d624043b6d0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624043b580>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624043b820>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624043b970>,
#  <unstructured.documents.elements.Title at 0x7d62497524a0>,
#  <unstructured.documents.elements.Text at 0x7d62497522c0>,
#  <unstructured.documents.elements.Text at 0x7d6249752500>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624043bc10>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624043bd60>,
#  <unstructured.documents.elements.Table at 0x7d624043beb0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240444040>,
#  <unstructured.documents.elements.Text at 0x7d62497522f0>,
#  <unstructured.documents.elements.Text at 0x7d62497521d0>,
#  <unstructured.documents.elements.Header at 0x7d6240444940>,
#  <unstructured.documents.elements.Header at 0x7d6240444ac0>,
#  <unstructured.documents.elements.Title at 0x7d6240444c10>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240444d60>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240444eb0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240445150>,
#  <unstructured.documents.elements.Title at 0x7d6249752200>,
#  <unstructured.documents.elements.Title at 0x7d6249752110>,
#  <unstructured.documents.elements.Title at 0x7d62497520b0>,
#  <unstructured.documents.elements.Title at 0x7d62497520e0>,
#  <unstructured.documents.elements.Text at 0x7d6249751ff0>,
#  <unstructured.documents.elements.Title at 0x7d6249751f90>,
#  <unstructured.documents.elements.Title at 0x7d6249751fc0>,
#  <unstructured.documents.elements.Title at 0x7d6249751ed0>,
#  <unstructured.documents.elements.Text at 0x7d6249751e70>,
#  <unstructured.documents.elements.Title at 0x7d6249751ea0>,
#  <unstructured.documents.elements.Text at 0x7d6249751db0>,
#  <unstructured.documents.elements.Title at 0x7d6249751d50>,
#  <unstructured.documents.elements.Title at 0x7d62404453f0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240445540>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240445690>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404457e0>,
#  <unstructured.documents.elements.Title at 0x7d6249751d80>,
#  <unstructured.documents.elements.Title at 0x7d6249751c90>,
#  <unstructured.documents.elements.Text at 0x7d6249751c30>,
#  <unstructured.documents.elements.Title at 0x7d6249751c60>,
#  <unstructured.documents.elements.Text at 0x7d6249751bd0>,
#  <unstructured.documents.elements.Text at 0x7d6249751b10>,
#  <unstructured.documents.elements.Title at 0x7d6249751b40>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240445a80>,
#  <unstructured.documents.elements.Title at 0x7d6249751a50>,
#  <unstructured.documents.elements.Text at 0x7d62497533d0>,
#  <unstructured.documents.elements.Title at 0x7d6249751a20>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240445bd0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240445e70>,
#  <unstructured.documents.elements.Text at 0x7d6249753460>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240445fc0>,
#  <unstructured.documents.elements.Header at 0x7d624045c040>,
#  <unstructured.documents.elements.Header at 0x7d624045c100>,
#  <unstructured.documents.elements.ListItem at 0x7d624045c1f0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624045c370>,
#  <unstructured.documents.elements.Title at 0x7d624045c4c0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624045c610>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624045c760>,
#  <unstructured.documents.elements.Title at 0x7d624045ca00>,
#  <unstructured.documents.elements.Title at 0x7d6249753550>,
#  <unstructured.documents.elements.Text at 0x7d62497533a0>,
#  <unstructured.documents.elements.Text at 0x7d6249753520>,
#  <unstructured.documents.elements.Title at 0x7d624045cb50>,
#  <unstructured.documents.elements.Text at 0x7d6249750460>,
#  <unstructured.documents.elements.Text at 0x7d62497504c0>,
#  <unstructured.documents.elements.Title at 0x7d6249750490>,
#  <unstructured.documents.elements.Title at 0x7d6249750580>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624045cca0>,
#  <unstructured.documents.elements.Title at 0x7d624045cdf0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624045cf40>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624045d090>,
#  <unstructured.documents.elements.Title at 0x7d624045d330>,
#  <unstructured.documents.elements.Table at 0x7d624045d480>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624045d720>,
#  <unstructured.documents.elements.Title at 0x7d624045d870>,
#  <unstructured.documents.elements.Text at 0x7d62497505e0>,
#  <unstructured.documents.elements.Title at 0x7d62497505b0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624045db10>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624045d9c0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624045dc60>,
#  <unstructured.documents.elements.Footer at 0x7d624045ddb0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624045e1a0>,
#  <unstructured.documents.elements.Text at 0x7d62497506a0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624045e050>,
#  <unstructured.documents.elements.Header at 0x7d624045efe0>,
#  <unstructured.documents.elements.Header at 0x7d624045f1c0>,
#  <unstructured.documents.elements.ListItem at 0x7d624045f2b0>,
#  <unstructured.documents.elements.Table at 0x7d624045f580>,
#  <unstructured.documents.elements.Title at 0x7d624045f430>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624045f6d0>,
#  <unstructured.documents.elements.Title at 0x7d6249750700>,
#  <unstructured.documents.elements.Title at 0x7d62497506d0>,
#  <unstructured.documents.elements.Text at 0x7d62497507c0>,
#  <unstructured.documents.elements.Text at 0x7d6249750820>,
#  <unstructured.documents.elements.Text at 0x7d62497507f0>,
#  <unstructured.documents.elements.Text at 0x7d6249750910>,
#  <unstructured.documents.elements.Table at 0x7d624045f970>,
#  <unstructured.documents.elements.Title at 0x7d624045f820>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624045fac0>,
#  <unstructured.documents.elements.Text at 0x7d6249750970>,
#  <unstructured.documents.elements.Text at 0x7d6249750a30>,
#  <unstructured.documents.elements.NarrativeText at 0x7d624045fd60>,
#  <unstructured.documents.elements.Text at 0x7d62497508e0>,
#  <unstructured.documents.elements.Header at 0x7d6240470940>,
#  <unstructured.documents.elements.Header at 0x7d6240470af0>,
#  <unstructured.documents.elements.ListItem at 0x7d6240470c10>,
#  <unstructured.documents.elements.Title at 0x7d6240470d60>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240470eb0>,
#  <unstructured.documents.elements.Title at 0x7d6240471000>,
#  <unstructured.documents.elements.Title at 0x7d6249750ac0>,
#  <unstructured.documents.elements.Title at 0x7d6249750a90>,
#  <unstructured.documents.elements.Title at 0x7d6249750b80>,
#  <unstructured.documents.elements.Table at 0x7d6240471150>,
#  <unstructured.documents.elements.Title at 0x7d62404712a0>,
#  <unstructured.documents.elements.ListItem at 0x7d62404713f0>,
#  <unstructured.documents.elements.ListItem at 0x7d6240471540>,
#  <unstructured.documents.elements.ListItem at 0x7d6240471690>,
#  <unstructured.documents.elements.ListItem at 0x7d62404717e0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240471a80>,
#  <unstructured.documents.elements.Text at 0x7d6249750c10>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240471930>,
#  <unstructured.documents.elements.Header at 0x7d6240472230>,
#  <unstructured.documents.elements.Header at 0x7d62404723b0>,
#  <unstructured.documents.elements.ListItem at 0x7d6240472500>,
#  <unstructured.documents.elements.ListItem at 0x7d6240472650>,
#  <unstructured.documents.elements.ListItem at 0x7d62404727a0>,
#  <unstructured.documents.elements.Title at 0x7d62404728f0>,
#  <unstructured.documents.elements.ListItem at 0x7d6240472a40>,
#  <unstructured.documents.elements.ListItem at 0x7d6240472b90>,
#  <unstructured.documents.elements.ListItem at 0x7d6240472ce0>,
#  <unstructured.documents.elements.Title at 0x7d6240472e30>,
#  <unstructured.documents.elements.Text at 0x7d6249750bb0>,
#  <unstructured.documents.elements.ListItem at 0x7d6240472f80>,
#  <unstructured.documents.elements.ListItem at 0x7d62404730d0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240473220>,
#  <unstructured.documents.elements.Table at 0x7d6240473370>,
#  <unstructured.documents.elements.ListItem at 0x7d62404734c0>,
#  <unstructured.documents.elements.Table at 0x7d6240473610>,
#  <unstructured.documents.elements.ListItem at 0x7d6240473760>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404738b0>,
#  <unstructured.documents.elements.Table at 0x7d6240473a00>,
#  <unstructured.documents.elements.ListItem at 0x7d6240473b50>,
#  <unstructured.documents.elements.Table at 0x7d6240473ca0>,
#  <unstructured.documents.elements.ListItem at 0x7d6240473df0>,
#  <unstructured.documents.elements.Table at 0x7d6240480040>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240480370>,
#  <unstructured.documents.elements.Text at 0x7d6249750cd0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240480220>,
#  <unstructured.documents.elements.Header at 0x7d6240480730>,
#  <unstructured.documents.elements.Header at 0x7d62404808e0>,
#  <unstructured.documents.elements.ListItem at 0x7d6240480a00>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240480b50>,
#  <unstructured.documents.elements.Table at 0x7d6240480ca0>,
#  <unstructured.documents.elements.Text at 0x7d6249750d30>,
#  <unstructured.documents.elements.ListItem at 0x7d6240480df0>,
#  <unstructured.documents.elements.Table at 0x7d6240480f40>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240481090>,
#  <unstructured.documents.elements.Title at 0x7d6240481330>,
#  <unstructured.documents.elements.Title at 0x7d62404811e0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240481480>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404815d0>,
#  <unstructured.documents.elements.Title at 0x7d6240481720>,
#  <unstructured.documents.elements.Title at 0x7d6249750d00>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240481870>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240481c60>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240481b10>,
#  <unstructured.documents.elements.Header at 0x7d6240482020>,
#  <unstructured.documents.elements.Header at 0x7d62404821a0>,
#  <unstructured.documents.elements.ListItem at 0x7d62404822f0>,
#  <unstructured.documents.elements.Title at 0x7d6249750df0>,
#  <unstructured.documents.elements.Title at 0x7d6249750e50>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240482590>,
#  <unstructured.documents.elements.ListItem at 0x7d62404826e0>,
#  <unstructured.documents.elements.ListItem at 0x7d6240482830>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240482980>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240482ad0>,
#  <unstructured.documents.elements.Title at 0x7d6240482c20>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240482d70>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240482ec0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240483160>,
#  <unstructured.documents.elements.Text at 0x7d6249750e20>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404832b0>,
#  <unstructured.documents.elements.Header at 0x7d62404837c0>,
#  <unstructured.documents.elements.Header at 0x7d6240483940>,
#  <unstructured.documents.elements.ListItem at 0x7d6240483a90>,
#  <unstructured.documents.elements.Title at 0x7d6240483be0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240483e80>,
#  <unstructured.documents.elements.Table at 0x7d6240483d30>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404940d0>,
#  <unstructured.documents.elements.ListItem at 0x7d6240494160>,
#  <unstructured.documents.elements.ListItem at 0x7d62404942b0>,
#  <unstructured.documents.elements.ListItem at 0x7d6240494400>,
#  <unstructured.documents.elements.ListItem at 0x7d6240494550>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404946a0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240494a90>,
#  <unstructured.documents.elements.Text at 0x7d6249750f10>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240494940>,
#  <unstructured.documents.elements.Header at 0x7d6240494d00>,
#  <unstructured.documents.elements.Header at 0x7d6240494e80>,
#  <unstructured.documents.elements.ListItem at 0x7d6240494fd0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240495120>,
#  <unstructured.documents.elements.Title at 0x7d6240495270>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404953c0>,
#  <unstructured.documents.elements.ListItem at 0x7d6240495510>,
#  <unstructured.documents.elements.ListItem at 0x7d6240495660>,
#  <unstructured.documents.elements.ListItem at 0x7d62404957b0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240495900>,
#  <unstructured.documents.elements.Title at 0x7d6249750fa0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240495ba0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240495cf0>,
#  <unstructured.documents.elements.Title at 0x7d6240495e40>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240495f90>,
#  <unstructured.documents.elements.ListItem at 0x7d62404960e0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404964d0>,
#  <unstructured.documents.elements.Text at 0x7d6249750f70>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240496380>,
#  <unstructured.documents.elements.Header at 0x7d6240496890>,
#  <unstructured.documents.elements.Header at 0x7d6240496a40>,
#  <unstructured.documents.elements.ListItem at 0x7d6240496b60>,
#  <unstructured.documents.elements.Title at 0x7d6240496cb0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240496f50>,
#  <unstructured.documents.elements.ListItem at 0x7d62404970a0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404971f0>,
#  <unstructured.documents.elements.Title at 0x7d6240497340>,
#  <unstructured.documents.elements.Title at 0x7d62404975e0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240497730>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240497490>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240497880>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404979d0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240497b20>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240497dc0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240497f10>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404a81f0>,
#  <unstructured.documents.elements.Text at 0x7d6249751090>,
#  <unstructured.documents.elements.Text at 0x7d6249751120>,
#  <unstructured.documents.elements.Header at 0x7d62404a85b0>,
#  <unstructured.documents.elements.Table at 0x7d62404a8880>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404a89d0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404a8c70>,
#  <unstructured.documents.elements.FigureCaption at 0x7d62404a8dc0>,
#  <unstructured.documents.elements.Table at 0x7d62404a8f10>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404a9060>,
#  <unstructured.documents.elements.Title at 0x7d62404a91b0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404a96f0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404a9ae0>,
#  <unstructured.documents.elements.Text at 0x7d62497510c0>,
#  <unstructured.documents.elements.Header at 0x7d62404a8730>,
#  <unstructured.documents.elements.Title at 0x7d62497511e0>,
#  <unstructured.documents.elements.Text at 0x7d6249751240>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404a9990>,
#  <unstructured.documents.elements.Header at 0x7d62404a9ff0>,
#  <unstructured.documents.elements.Header at 0x7d62404aa170>,
#  <unstructured.documents.elements.ListItem at 0x7d62404aa2c0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404aa410>,
#  <unstructured.documents.elements.Title at 0x7d62404aa560>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404aa800>,
#  <unstructured.documents.elements.Table at 0x7d62404aa6b0>,
#  <unstructured.documents.elements.Title at 0x7d62404aa950>,
#  <unstructured.documents.elements.Title at 0x7d62404aaaa0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404aabf0>,
#  <unstructured.documents.elements.Title at 0x7d62404aad40>,
#  <unstructured.documents.elements.ListItem at 0x7d62404aae90>,
#  <unstructured.documents.elements.ListItem at 0x7d62404aafe0>,
#  <unstructured.documents.elements.Title at 0x7d62404ab130>,
#  <unstructured.documents.elements.ListItem at 0x7d62404ab280>,
#  <unstructured.documents.elements.Title at 0x7d62404ab3d0>,
#  <unstructured.documents.elements.Title at 0x7d6249751210>,
#  <unstructured.documents.elements.Table at 0x7d62404ab520>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404ab670>,
#  <unstructured.documents.elements.Text at 0x7d6249751300>,
#  <unstructured.documents.elements.Text at 0x7d6249751360>,
#  <unstructured.documents.elements.Header at 0x7d62404abb80>,
#  <unstructured.documents.elements.Header at 0x7d62404abd00>,
#  <unstructured.documents.elements.ListItem at 0x7d62404abe50>,
#  <unstructured.documents.elements.Title at 0x7d62404b80a0>,
#  <unstructured.documents.elements.Table at 0x7d62404b8130>,
#  <unstructured.documents.elements.Table at 0x7d62404b8280>,
#  <unstructured.documents.elements.ListItem at 0x7d62404b83d0>,
#  <unstructured.documents.elements.Table at 0x7d62404b8520>,
#  <unstructured.documents.elements.Title at 0x7d6249751330>,
#  <unstructured.documents.elements.Title at 0x7d6249751420>,
#  <unstructured.documents.elements.Text at 0x7d62497514b0>,
#  <unstructured.documents.elements.Title at 0x7d6249751450>,
#  <unstructured.documents.elements.ListItem at 0x7d6249751540>,
#  <unstructured.documents.elements.Text at 0x7d62497515a0>,
#  <unstructured.documents.elements.Text at 0x7d6249751570>,
#  <unstructured.documents.elements.Text at 0x7d6249752a70>,
#  <unstructured.documents.elements.Header at 0x7d62404b90c0>,
#  <unstructured.documents.elements.Header at 0x7d62404b9270>,
#  <unstructured.documents.elements.ListItem at 0x7d62404b9360>,
#  <unstructured.documents.elements.Table at 0x7d62404b94e0>,
#  <unstructured.documents.elements.Title at 0x7d62404b9630>,
#  <unstructured.documents.elements.Title at 0x7d62404b98d0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404b9a20>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404b9780>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404b9b70>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404b9cc0>,
#  <unstructured.documents.elements.Title at 0x7d62404b9e10>,
#  <unstructured.documents.elements.Table at 0x7d62404b9f60>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404ba0b0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404ba200>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404ba4a0>,
#  <unstructured.documents.elements.Text at 0x7d6249752ad0>,
#  <unstructured.documents.elements.Header at 0x7d62404ba710>,
#  <unstructured.documents.elements.Header at 0x7d62404ba8c0>,
#  <unstructured.documents.elements.ListItem at 0x7d62404ba9e0>,
#  <unstructured.documents.elements.Title at 0x7d62404bab30>,
#  <unstructured.documents.elements.Table at 0x7d62404bac80>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404badd0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404baf20>,
#  <unstructured.documents.elements.Table at 0x7d62404bb070>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404bb1c0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404bb310>,
#  <unstructured.documents.elements.Table at 0x7d62404bb460>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404bb5b0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404bb700>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404bb850>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404bb9a0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404bbaf0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404bbee0>,
#  <unstructured.documents.elements.Header at 0x7d62404bbc40>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404bbd90>,
#  <unstructured.documents.elements.Text at 0x7d6249752aa0>,
#  <unstructured.documents.elements.Header at 0x7d62404cc040>,
#  <unstructured.documents.elements.Header at 0x7d62404cc1f0>,
#  <unstructured.documents.elements.ListItem at 0x7d62404cc310>,
#  <unstructured.documents.elements.Title at 0x7d62404cc460>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404cc700>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404cc5b0>,
#  <unstructured.documents.elements.Table at 0x7d62404cc850>,
#  <unstructured.documents.elements.Title at 0x7d62404cc9a0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404ccc40>,
#  <unstructured.documents.elements.Table at 0x7d62404ccaf0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404ccd90>,
#  <unstructured.documents.elements.Title at 0x7d62404ccee0>,
#  <unstructured.documents.elements.Image at 0x7d62404cd030>,
#  <unstructured.documents.elements.FigureCaption at 0x7d62404cd2d0>,
#  <unstructured.documents.elements.ListItem at 0x7d62404cd180>,
#  <unstructured.documents.elements.ListItem at 0x7d62404cd420>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404cd570>,
#  <unstructured.documents.elements.Text at 0x7d6249752b90>,
#  <unstructured.documents.elements.Text at 0x7d6249752bf0>,
#  <unstructured.documents.elements.Header at 0x7d62404cda80>,
#  <unstructured.documents.elements.Header at 0x7d62404cdc00>,
#  <unstructured.documents.elements.ListItem at 0x7d62404cdd50>,
#  <unstructured.documents.elements.ListItem at 0x7d62404cdea0>,
#  <unstructured.documents.elements.ListItem at 0x7d62404cdff0>,
#  <unstructured.documents.elements.Title at 0x7d62404ce140>,
#  <unstructured.documents.elements.Text at 0x7d6249752bc0>,
#  <unstructured.documents.elements.ListItem at 0x7d62404ce290>,
#  <unstructured.documents.elements.ListItem at 0x7d62404ce3e0>,
#  <unstructured.documents.elements.ListItem at 0x7d62404ce530>,
#  <unstructured.documents.elements.Text at 0x7d6249752cb0>,
#  <unstructured.documents.elements.ListItem at 0x7d62404ce680>,
#  <unstructured.documents.elements.ListItem at 0x7d62404ce7d0>,
#  <unstructured.documents.elements.ListItem at 0x7d62404ce920>,
#  <unstructured.documents.elements.ListItem at 0x7d62404cea70>,
#  <unstructured.documents.elements.Text at 0x7d6249752d10>,
#  <unstructured.documents.elements.Text at 0x7d6249752ce0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404ced10>,
#  <unstructured.documents.elements.Header at 0x7d62404cf370>,
#  <unstructured.documents.elements.Header at 0x7d62404cf520>,
#  <unstructured.documents.elements.ListItem at 0x7d62404cf640>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404cf790>,
#  <unstructured.documents.elements.ListItem at 0x7d62404cf8e0>,
#  <unstructured.documents.elements.ListItem at 0x7d62404cfa30>,
#  <unstructured.documents.elements.Title at 0x7d62404cfb80>,
#  <unstructured.documents.elements.Title at 0x7d62404cfcd0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404cfe20>,
#  <unstructured.documents.elements.Title at 0x7d6249752dd0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404e0070>,
#  <unstructured.documents.elements.Image at 0x7d62404e0100>,
#  <unstructured.documents.elements.FigureCaption at 0x7d62404e0250>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404e0640>,
#  <unstructured.documents.elements.Text at 0x7d6249752e30>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404e04f0>,
#  <unstructured.documents.elements.Header at 0x7d62404e0a00>,
#  <unstructured.documents.elements.Header at 0x7d62404e0bb0>,
#  <unstructured.documents.elements.ListItem at 0x7d62404e0cd0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404e0e20>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404e0f70>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404e10c0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404e1210>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404e1360>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404e14b0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404e1600>,
#  <unstructured.documents.elements.Title at 0x7d62404e18a0>,
#  <unstructured.documents.elements.Image at 0x7d62404e1750>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404e19f0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404e1c90>,
#  <unstructured.documents.elements.Text at 0x7d6249752e00>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404e1de0>,
#  <unstructured.documents.elements.Header at 0x7d62404e2050>,
#  <unstructured.documents.elements.Header at 0x7d62404e21d0>,
#  <unstructured.documents.elements.ListItem at 0x7d62404e2320>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404e2470>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404e2710>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404e2860>,
#  <unstructured.documents.elements.Table at 0x7d62404e29b0>,
#  <unstructured.documents.elements.Title at 0x7d62404e2b00>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404e2c50>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404e2da0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404e3040>,
#  <unstructured.documents.elements.Table at 0x7d62404e3190>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404e32e0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404e3430>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404e36d0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404e3970>,
#  <unstructured.documents.elements.Text at 0x7d6249752ef0>,
#  <unstructured.documents.elements.Text at 0x7d6249752f50>,
#  <unstructured.documents.elements.Header at 0x7d62404e3d30>,
#  <unstructured.documents.elements.Header at 0x7d62404e3ee0>,
#  <unstructured.documents.elements.Title at 0x7d62404f0040>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404f0190>,
#  <unstructured.documents.elements.Table at 0x7d62404f02e0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404f0430>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404f06d0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404f0970>,
#  <unstructured.documents.elements.Table at 0x7d62404f0ac0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404f0c10>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404f0eb0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404f1000>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404f13f0>,
#  <unstructured.documents.elements.Text at 0x7d6249752f20>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404f12a0>,
#  <unstructured.documents.elements.Header at 0x7d62404f1660>,
#  <unstructured.documents.elements.Header at 0x7d62404f1810>,
#  <unstructured.documents.elements.ListItem at 0x7d62404f1930>,
#  <unstructured.documents.elements.Title at 0x7d6249753010>,
#  <unstructured.documents.elements.Title at 0x7d62404f1a80>,
#  <unstructured.documents.elements.Title at 0x7d62404f1bd0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404f1d20>,
#  <unstructured.documents.elements.Title at 0x7d62404f1e70>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404f1fc0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404f2110>,
#  <unstructured.documents.elements.ListItem at 0x7d62404f2260>,
#  <unstructured.documents.elements.ListItem at 0x7d62404f23b0>,
#  <unstructured.documents.elements.ListItem at 0x7d62404f2500>,
#  <unstructured.documents.elements.ListItem at 0x7d62404f2650>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404f27a0>,
#  <unstructured.documents.elements.Title at 0x7d62404f28f0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404f2a40>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404f2b90>,
#  <unstructured.documents.elements.Title at 0x7d62404f2ce0>,
#  <unstructured.documents.elements.Table at 0x7d62404f2e30>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404f2f80>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404f30d0>,
#  <unstructured.documents.elements.Text at 0x7d6249753070>,
#  <unstructured.documents.elements.Text at 0x7d6249753040>,
#  <unstructured.documents.elements.Header at 0x7d62404f35e0>,
#  <unstructured.documents.elements.Header at 0x7d62404f3760>,
#  <unstructured.documents.elements.ListItem at 0x7d62404f38b0>,
#  <unstructured.documents.elements.Table at 0x7d62404f3b50>,
#  <unstructured.documents.elements.Title at 0x7d62404f3a00>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404f3ca0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62404f3df0>,
#  <unstructured.documents.elements.Title at 0x7d6240500040>,
#  <unstructured.documents.elements.Title at 0x7d62497531c0>,
#  <unstructured.documents.elements.Text at 0x7d6249753190>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405000d0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240500220>,
#  <unstructured.documents.elements.Title at 0x7d6240500370>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405004c0>,
#  <unstructured.documents.elements.Image at 0x7d6240500760>,
#  <unstructured.documents.elements.Title at 0x7d6240500610>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405008b0>,
#  <unstructured.documents.elements.Text at 0x7d6249753220>,
#  <unstructured.documents.elements.Text at 0x7d62497532e0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240500b50>,
#  <unstructured.documents.elements.Text at 0x7d6249753340>,
#  <unstructured.documents.elements.Header at 0x7d62405011b0>,
#  <unstructured.documents.elements.Header at 0x7d6240501330>,
#  <unstructured.documents.elements.ListItem at 0x7d6240501480>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405015d0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240501720>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240501870>,
#  <unstructured.documents.elements.Title at 0x7d62405019c0>,
#  <unstructured.documents.elements.Title at 0x7d6249753310>,
#  <unstructured.documents.elements.Text at 0x7d62497535e0>,
#  <unstructured.documents.elements.Title at 0x7d6249753640>,
#  <unstructured.documents.elements.Text at 0x7d6249753610>,
#  <unstructured.documents.elements.Text at 0x7d6249753700>,
#  <unstructured.documents.elements.Title at 0x7d6249753790>,
#  <unstructured.documents.elements.Title at 0x7d6240501b10>,
#  <unstructured.documents.elements.ListItem at 0x7d6240501c60>,
#  <unstructured.documents.elements.ListItem at 0x7d6240501db0>,
#  <unstructured.documents.elements.ListItem at 0x7d6240501f00>,
#  <unstructured.documents.elements.ListItem at 0x7d6240502050>,
#  <unstructured.documents.elements.ListItem at 0x7d62405021a0>,
#  <unstructured.documents.elements.ListItem at 0x7d62405022f0>,
#  <unstructured.documents.elements.ListItem at 0x7d6240502440>,
#  <unstructured.documents.elements.ListItem at 0x7d6240502590>,
#  <unstructured.documents.elements.ListItem at 0x7d62405026e0>,
#  <unstructured.documents.elements.ListItem at 0x7d6240502830>,
#  <unstructured.documents.elements.ListItem at 0x7d6240502ad0>,
#  <unstructured.documents.elements.ListItem at 0x7d6240502c20>,
#  <unstructured.documents.elements.ListItem at 0x7d6240502d70>,
#  <unstructured.documents.elements.ListItem at 0x7d6240502ec0>,
#  <unstructured.documents.elements.ListItem at 0x7d6240503010>,
#  <unstructured.documents.elements.ListItem at 0x7d6240503160>,
#  <unstructured.documents.elements.ListItem at 0x7d62405032b0>,
#  <unstructured.documents.elements.ListItem at 0x7d6240503400>,
#  <unstructured.documents.elements.NarrativeText at 0x7d62405036a0>,
#  <unstructured.documents.elements.Text at 0x7d62497536a0>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6240503550>,
#  <unstructured.documents.elements.Header at 0x7d6240514280>,
#  <unstructured.documents.elements.Header at 0x7d6240514400>,
#  <unstructured.documents.elements.ListItem at 0x7d6240514550>,
#  <unstructured.documents.elements.ListItem at 0x7d62405146a0>,
#  <unstructured.documents.elements.ListItem at 0x7d62405147f0>,
#  <unstructured.documents.elements.ListItem at 0x7d6240514940>,
#  <unstructured.documents.elements.Title at 0x7d6240514a90>,
#  <unstructured.documents.elements.Text at 0x7d6249753820>,
#  <unstructured.documents.elements.NarrativeText at 0x7d6249753880>,
#  <unstructured.documents.elements.Title at 0x7d6249753850>,
#  <unstructured.documents.elements.ListItem at 0x7d6240514be0>,
#  <unstructured.documents.elements.Title at 0x7d62497538e0>,
#  <unstructured.documents.elements.ListItem at 0x7d6240514d30>,
#  <unstructured.documents.elements.Text at 0x7d6249753940>,
#  <unstructured.documents.elements.Text at 0x7d624a72b400>,
#  <unstructured.documents.elements.ListItem at 0x7d6240514e80>,
#  <unstructured.documents.elements.ListItem at 0x7d6240514fd0>,
#  <unstructured.documents.elements.Text at 0x7d624a728ac0>,
#  <unstructured.documents.elements.ListItem at 0x7d6240515120>,
#  <unstructured.documents.elements.Title at 0x7d624a72b190>,
#  <unstructured.documents.elements.ListItem at 0x7d6240515270>,
#  <unstructured.documents.elements.Title at 0x7d624a728220>,
#  <unstructured.documents.elements.Text at 0x7d624a72a800>,
#  <unstructured.documents.elements.ListItem at 0x7d62405153c0>,
#  <unstructured.documents.elements.Title at 0x7d624a72a920>,
#  <unstructured.documents.elements.ListItem at 0x7d6240515510>,
#  <unstructured.documents.elements.ListItem at 0x7d6240515660>,
#  <unstructured.documents.elements.ListItem at 0x7d62405157b0>,
#  ...]

# %%
from unstructured.documents.elements import NarrativeText

# %%
def extract_text_with_metadata(esg_report, source_document):

    text_data = []
    paragraph_counters = {}

    for element in esg_report:
        if isinstance(element, NarrativeText):
            page_number = element.metadata.page_number

            if page_number not in paragraph_counters:
                paragraph_counters[page_number] = 1
            else:
                paragraph_counters[page_number] += 1

            paragraph_number = paragraph_counters[page_number]

            text_content = element.text
            text_data.append({
                "source_document": source_document,
                "page_number": page_number,
                "paragraph_number": paragraph_number,
                "text": text_content
            })

    return text_data

# %%
extracted_data = extract_text_with_metadata(esg_report_raw_data, esg_report_path)

# %%
extracted_data
# Out:
# [{'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 1,
#   'paragraph_number': 1,
#   'text': '~ 28 © 0 ~ 9 eo 8 ae eo 8 ° °° ° a 20 0 © 5 ° °° ° ° © 0 . ° ° of 6 8? coe ° ° ° ° ° ° ~~ 0 °%o -'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 1,
#   'paragraph_number': 2,
#   'text': 'Chapter 1 explained that the primary means of conveying financial information investors, creditors, and other external users is through financial statements and related notes. The purpose of this chapter is to review the fundamen- tal accounting process used to produce the financial statements. This review establishes a framework for the study of the concepts covered in intermediate accounting.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 1,
#   'paragraph_number': 3,
#   'text': 'Actual accounting systems differ significantly from company to company. This chapter focuses on the many features that tend to be common to any accounting system.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 1,
#   'paragraph_number': 4,
#   'text': 'LEARNING -——W—Y® After studying this chapter, you should be able to:'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 1,
#   'paragraph_number': 5,
#   'text': '~ 0 © 0 ~ 0 eo 8 Soe eo 8 ° °°? ° 5 20 0 9% °° ° oo ° ° ° ° °° $e ° ° ° ° ° ° ° , ° ~ 0° %o ° -'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 1,
#   'paragraph_number': 6,
#   'text': 'spi24360_ch02_042-103 42'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 1,
#   'paragraph_number': 7,
#   'text': '05/23/24 09:05 AM'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 2,
#   'paragraph_number': 1,
#   'text': 'After graduating from college a few years ago, two of your friends who majored in engineering started a software ser- vices company. They feel they are doing quite well, and now they would like to borrow $200,000 from a local bank to buy new equipment and office furniture. To support their loan application, the bank manager asked them to report their company’s financial position and performance for the year. Your friends provided the following information about cash received and paid for the most recent year.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 2,
#   'paragraph_number': 2,
#   'text': 'Cash received from customers'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 2,
#   'paragraph_number': 3,
#   'text': 'Cash paid for:'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 2,
#   'paragraph_number': 4,
#   'text': 'The bank manager informed your friends that this is not quite the accounting information needed to be approved for the loan. The manager used terms such as accounting cycle, accounting equation, journal entries, balance sheet, and income statement. They’ve come to you for help.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 2,
#   'paragraph_number': 5,
#   'text': 'By the time you finish this chapter, you should be able to respond appropriately to the questions posed in this case. Compare your response to the solution provided at the end of the chapter.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 2,
#   'paragraph_number': 6,
#   'text': 'Chapter 1 introduced the theoretical structure of financial accounting and the environ- ment within which it operates. The primary function of financial accounting—to provide decision-useful financial information to external users—is accomplished by periodically disseminating financial statements and related notes. To provide this information, some com- panies rely on relatively inexpensive software packages such as QuickBooks and Peachtree. Other, more complex companies have company-specific accounting systems known as Enterprise Resource Planning (ERP) systems. In this chapter, we describe and illustrate a manual accounting information system to provide an overview of the basic model that underlies the computer software programs actually used to process accounting information.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 2,
#   'paragraph_number': 7,
#   'text': 'spi24360_ch02_042-103 43'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 2,
#   'paragraph_number': 8,
#   'text': '05/23/24 09:05 AM'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 3,
#   'paragraph_number': 1,
#   'text': 'Understand routine economic events— transactions—and determine their effects on a company’s financial position and on specific accounts.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 3,
#   'paragraph_number': 2,
#   'text': 'The first objective of any accounting system is to identify the economic events (or transactions) that can be expressed in financial terms by the system.’ An economic event for accounting purposes is any event that directly affects the financial position of the company.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 3,
#   'paragraph_number': 3,
#   'text': 'External events involve an exchange between the company and a separate economic entity. Examples are transactions involving purchasing inventory for cash, borrowing cash from a bank, and paying salaries to employees. In each instance, the company receives something (inventory, cash, and services) in exchange for something else (cash, assumption of a liability, or both).'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 3,
#   'paragraph_number': 4,
#   'text': 'Internal events directly affect the financial position of the company but don’t involve an exchange transaction with another entity. Examples are the depreciation of equipment and the use of supplies. As we will see later in the chapter, both internal and external events must be recorded to properly reflect a company’s financial position and results of operations in accordance with the accrual accounting model.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 3,
#   'paragraph_number': 5,
#   'text': 'The accounting equation summarizes the effects of transactions on the financial position of a company. In Illustration 2-1, the accounting equation shows that a company’s resources (assets) equal claims to those resources by creditors (liabilities) and owners (shareholders’ equity).'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 3,
#   'paragraph_number': 6,
#   'text': 'llustration 2-1 Accounting Equation'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 3,
#   'paragraph_number': 7,
#   'text': 'The accounting equation must always remain in balance: The left side (assets) equals the right side (liabilities plus shareholders’ equity). This means each transaction will have a dual effect. If a transaction increases one side of the equation, then the other side of the equation increases by the same amount. For example, when a company borrows cash from the bank, an asset (cash) increases and a liability (the loan payable to the bank) increases. Illustration 2-1A expands the accounting equation to show the components of sharehold- ers’ equity. Shareholders’ equity for a corporation arises primarily from two sources:'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 3,
#   'paragraph_number': 8,
#   'text': '1. Paid-in capital—Amounts paid in by shareholders of the corporation.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 3,
#   'paragraph_number': 9,
#   'text': 'We can further split retained earnings into its components:'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 3,
#   'paragraph_number': 10,
#   'text': '“There are many economic events that affect a company indirectly and are not recorded. For example, when the Federal Reserve changes its discount rate, it is an important economic event that can affect the company in many ways, but it is not recorded by the company.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 3,
#   'paragraph_number': 11,
#   'text': 'spi24360_ch02_042-103 44'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 3,
#   'paragraph_number': 12,
#   'text': '05/23/24 09:05 AM'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 4,
#   'paragraph_number': 1,
#   'text': 'Expanded Accounting Equation'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 4,
#   'paragraph_number': 2,
#   'text': 'The best way to understand the effects of transactions on the accounting equation is to see them demonstrated with a few examples. Illustration 2—2 shows the effects of four transac- tions on the expanded accounting equation. Notice the following for each transaction:'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 4,
#   'paragraph_number': 3,
#   'text': 'Transaction Analysis for Assets, Liabilities, and Shareholders’ Equity'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 4,
#   'paragraph_number': 4,
#   'text': 'Illustration 2-3 shows how transactions involving revenues, expenses, and dividends affect shareholders’ equity through their effect on retained earnings. Notice that an increase in rev- enues causes an increase to shareholders’ equity, while an increase in expenses or dividends causes a decrease to shareholders’ equity.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 4,
#   'paragraph_number': 5,
#   'text': 'Transaction Analysis for Revenues, Expenses, and Dividends'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 4,
#   'paragraph_number': 6,
#   'text': 'spi24360_ch02_042-103 45'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 4,
#   'paragraph_number': 7,
#   'text': '05/23/24 09:05 AM'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 5,
#   'paragraph_number': 1,
#   'text': "For each account, we need to keep track of the increases and decreases to the account’s balance caused by transactions of the company. Debits and credits are the terms used in accounting to signify an increase or decrease to an account balance. For each transaction, we'll have at least one debit and at least one credit (with the amount of total debits equal- ing the amount of total credits). This dual system of debits and credits is the double-entry system used in accounting to process transactions."},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 5,
#   'paragraph_number': 2,
#   'text': 'For instructional purposes we use T-accounts to represent formal general ledger accounts. A T-account has space at the top for the account title, a left side for recording the debits, and a right side for recording the credits.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 5,
#   'paragraph_number': 3,
#   'text': 'Debit side | Credit side'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 5,
#   'paragraph_number': 4,
#   'text': 'Whether a debit or a credit represents an increase or a decrease to the account balance depends on the type of account.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 5,
#   'paragraph_number': 5,
#   'text': 'As an example, consider receiving cash of $40,000 from a bank loan. Cash (an asset) increased by $40,000, and we show that increase as a debit to the Cash account. Notes payable (a liability) also increased by $40,000, and we show that increase as a credit to the Notes Payable account. When it’s time to pay back that note using cash, we’ll credit the Cash account and debit the Notes Payable account to show both of those account balances decreasing.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 5,
#   'paragraph_number': 6,
#   'text': 'Illustration 2-4 summarizes the effects of debits and credits on each element of the expanded accounting equation.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 5,
#   'paragraph_number': 7,
#   'text': 'Expanded Accounting Equation, Debits and Credits, Increases and Decreases'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 5,
#   'paragraph_number': 8,
#   'text': 'spi24360_ch02_042-103 46'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 6,
#   'paragraph_number': 1,
#   'text': 'For debits to equal credits, any component of shareholders’ equity that increases equity must also increase with a credit. Any component that decreases shareholders’ equity must do the opposite and increase with a debit. Once you understand the logic of increasing an account balance with a debit or credit, then you simply do the opposite to decrease the balance.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 6,
#   'paragraph_number': 2,
#   'text': 'In summary:'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 6,
#   'paragraph_number': 3,
#   'text': 'Now that we’ve reviewed the basics of the double-entry system, let’s look closer at the process used to identify, analyze, record, and summarize transactions and prepare financial statements.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 6,
#   'paragraph_number': 4,
#   'text': 'Describe the steps in the accounting cycle.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 6,
#   'paragraph_number': 5,
#   'text': 'The 10 steps in the accounting cycle are listed in Illustration 2-5. Steps 1-4 occur during the accounting period while steps 5-8 are applied at the end of the accounting period. Steps 9 and 10 are needed only at the end of the year.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 6,
#   'paragraph_number': 6,
#   'text': 'The Accounting Cycle'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 6,
#   'paragraph_number': 7,
#   'text': 'Source documents such as sales invoices, bills from suppliers, and cash register tapes provide evidence that a transaction has occurred and make available the essential information. These source documents usually identify the date and nature of each trans- action, the participating parties, and the monetary terms. For example, a sales invoice identifies the date of sale, the customer, the specific goods sold, the dollar amount of the sale, and the payment terms.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 6,
#   'paragraph_number': 8,
#   'text': 'Obtain information about external transactions from source documents.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 6,
#   'paragraph_number': 9,
#   'text': 'Transaction analysis is the process of reviewing the source documents to determine the dual effect on the accounting equation and the specific accounts affected. For each transac- tion, the net effect on assets must equal the net effect on liabilities plus shareholders’ equity.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 6,
#   'paragraph_number': 10,
#   'text': 'Analyze the transaction.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 6,
#   'paragraph_number': 11,
#   'text': 'A journal provides a chronological record of all transactions expressed in terms of debits and credits. As explained earlier, debits and credits represent increases or decreases to spe- cific accounts, depending on the type of account. For example, if the transaction causes the amount of cash to increase, the Cash account is debited. If the transaction causes the amount of cash to decrease, the Cash account is credited.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 6,
#   'paragraph_number': 12,
#   'text': 'Record the transaction in a journal.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 6,
#   'paragraph_number': 13,
#   'text': 'A journal entry is used to express each transaction in terms of debits and credits to accounts. A common convention to portray a journal entry is to list the debited accounts first'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 6,
#   'paragraph_number': 14,
#   'text': 'spi24360_ch02_042-103 47'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 6,
#   'paragraph_number': 15,
#   'text': '05/23/24 09:05 AM'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 7,
#   'paragraph_number': 1,
#   'text': 'and then list the credited accounts indented. For each journal entry, total debits must equal total credits. A brief description of the transaction is sometimes placed below a journal entry. As an example, the journal entry for a bank loan of $40,000 is shown below. The bank loan increased the company’s cash and increased notes payable. We first debit the Cash account to show its balance increasing and then credit the Notes Payable account to show its balance increasing.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 7,
#   'paragraph_number': 2,
#   'text': 'A general journal provides a chronological record (or list) of all journal entries that have occurred. Some repetitive types of transactions, such as sales to customers, are recorded in a special journal. In Appendix 2C we discuss the use of special journals in more depth.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 7,
#   'paragraph_number': 3,
#   'text': 'Post from the journal to the general ledger accounts.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 7,
#   'paragraph_number': 4,
#   'text': 'Posting involves transferring debits and credits in individual journal entries to individual accounts affected. The total of all debits is subtracted from the total of all credits to obtain the account’s balance. The process of posting debits and credits from the general journal to the ledger and calculating account balances is done automatically using computerized accounting systems. The general ledger provides a collection of all of the company’s vari- ous accounts and their balances.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 7,
#   'paragraph_number': 5,
#   'text': 'Prepare an unadjusted trial balance.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 7,
#   'paragraph_number': 6,
#   'text': 'The unadjusted trial balance is a list of general ledger accounts and their balances at a particular date. We list each account and either its debit or credit balance. This process allows us to verify that the total of all accounts with a debit balance equals the total of all accounts with a credit balance.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 7,
#   'paragraph_number': 7,
#   'text': 'Record adjusting entries and post to the general ledger accounts.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 7,
#   'paragraph_number': 8,
#   'text': 'Adjusting entries are used to update the balances of assets and liabilities (and their related revenues and expenses) for transactions that have occurred during the period but which have not yet been recorded by the end of the period. Before we can prepare the finan- cial statements, we need to bring our account balances up-to-date. We do this by recording and posting adjusting entries to the general ledger accounts at the end of the period.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 7,
#   'paragraph_number': 9,
#   'text': 'Prepare an adjusted trial balance.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 7,
#   'paragraph_number': 10,
#   'text': 'An adjusted trial balance is a trial balance that is prepared after all account balances have been updated for adjusting entries. Like the unadjusted trial balance, the adjusted trial balance helps to verify that total debits equal total credits.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 7,
#   'paragraph_number': 11,
#   'text': 'Prepare financial statements.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 7,
#   'paragraph_number': 12,
#   'text': 'Financial statements are the primary means of providing information to investors, creditors, and other decision makers, which is the purpose of financial reporting. Using the accounts and balances listed in the adjusted trial balance, these statements include the:'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 7,
#   'paragraph_number': 13,
#   'text': 'Close the temporary accounts to retained earnings.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 7,
#   'paragraph_number': 14,
#   'text': 'Closing entries serve two purposes: (1) to transfer the balances of temporary accounts (revenues, gains, expenses, losses, and dividends) to the retained earnings account, and (2) to reduce the balances of these temporary accounts to zero. Temporary accounts measure activity only over the current accounting period, so it makes sense that their balances should start at zero at the beginning of each period. To do that, we need to close them to zero at the end of the period. Permanent accounts include assets, liabilities, and shareholders’ equity (paid-in capital and retained earnings). These accounts keep their balances into the next accounting period.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 7,
#   'paragraph_number': 15,
#   'text': 'Prepare a post-closing trial balance.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 7,
#   'paragraph_number': 16,
#   'text': 'The post-closing trial balance is a list of all permanent accounts and their balances after closing entries have been recorded. Because all temporary accounts have been closed to zero, they are not listed. The final balances in permanent accounts will be used to open (begin) the records in the next period.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 7,
#   'paragraph_number': 17,
#   'text': 'spi24360_ch02_042-103 48'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 7,
#   'paragraph_number': 18,
#   'text': '05/23/24 09:05 AM'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 8,
#   'paragraph_number': 1,
#   'text': 'Now that we have looked at a brief overview of the 10 steps of the accounting cycle, let’s take a closer look at each one. We start by illustrating the first four steps in the cycle using the external transactions described in Illustration 2—6 that occurred during the month of July 2027, the first month of operations for Dress Right Clothing Corporation. The local bank requires that Dress Right furnish financial statements on a monthly basis.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 8,
#   'paragraph_number': 2,
#   'text': 'E . xternal Transactions for July 2027'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 8,
#   'paragraph_number': 3,
#   'text': 'Purchased $60,000 of clothing inventory on account from the Birdwell Wholesale Clothing Company.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 8,
#   'paragraph_number': 4,
#   'text': 'Sold clothing inventory during the month for $35,000 cash. The cost of the inventory sold was $20,000.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 8,
#   'paragraph_number': 5,
#   'text': 'Sold clothing inventory on account to Briarfield School for $3,500. The cost of the inventory sold was $2,000.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 8,
#   'paragraph_number': 6,
#   'text': 'Subleased a portion of the building to a jewelry store. Received $1,000 in advance for the first two months’ rent beginning on July 16.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 8,
#   'paragraph_number': 7,
#   'text': 'F h want d ides th inf : 1 or each transaction, a source document provides the necessary information to comp ete steps 2 and 3 in the accounting cycle: transaction analysis and recording the appropriate — journal entry. Each transaction described in Illustration 2-6 is analyzed > the necessary journal entry.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 8,
#   'paragraph_number': 8,
#   'text': 'Analyze and record transactions using journal entries.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 8,
#   'paragraph_number': 9,
#   'text': 'To record the issuance of common stock.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 8,
#   'paragraph_number': 10,
#   'text': 'Transaction: July 1. Received cash of $60,000 from two investors ($30,000 each). Each investor was issued 3,000 shares of common stock.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 8,
#   'paragraph_number': 11,
#   'text': 'Analysis: This first transaction is an investment by owners that increases an asset (cash) and also increases shareholders’ equity (common stock). Increases in assets are recorded as debits, and increases in shareholders’ equity are recorded as credits. We use the paid-in cap- ital account called common stock because stock was issued in exchange for cash paid in.?'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 8,
#   'paragraph_number': 12,
#   'text': '*The different types of stock are discussed in Chapter 18. Also, some stock has a stated par value. In that case, the amount recorded to common stock is the par value, and the amount of the issue price above par value is recorded to a separate account, Paid-in capital— excess of par.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 8,
#   'paragraph_number': 13,
#   'text': 'spi24360_ch02_042-103 49'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 8,
#   'paragraph_number': 14,
#   'text': '05/23/24 09:05 AM'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 9,
#   'paragraph_number': 1,
#   'text': 'Transaction: July 1. Borrowed $40,000 from a local bank and signed two notes. Analysis: Borrowing from the bank causes increases in both an asset (cash) and a liabil- ity (notes payable). Increases in assets are debits, and increases in liabilities are credits. The notes require repayment of $40,000 in principal plus 10% interest. At this point, we record only the principal amount borrowed. As time passes, we’ll begin to owe interest. We discuss later how interest is recorded.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 9,
#   'paragraph_number': 2,
#   'text': 'Transaction: July 1. Paid $24,000 in advance for one year’s rent.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 9,
#   'paragraph_number': 3,
#   'text': 'Analysis: Paying rent in advance increases one asset (prepaid rent) and decreases another asset (cash). Increases in assets are recorded as debits, and decreases in assets are recorded as credits. Dress Right acquired the right to use the building for one full year. This right is an asset because it represents a future benefit to the company. As we will see later, this asset expires over the one-year rental period.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 9,
#   'paragraph_number': 4,
#   'text': 'Transaction: July 1. Purchased office equipment for $12,000 cash. Analysis: Purchasing equipment increases one asset (office equipment) and decreases another (cash).'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 9,
#   'paragraph_number': 5,
#   'text': 'To record the purchase inventory on account.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 9,
#   'paragraph_number': 6,
#   'text': 'Transaction: July 3. Purchased $60,000 of inventory on account.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 9,
#   'paragraph_number': 7,
#   'text': 'Analysis: Purchasing inventory on account increases an asset (inventory) and increases a liability (accounts payable). Increases in assets are debits. Increases in liabilities are credits. Dress Right uses the perpetual inventory system to keep track of its inventory. This sys- tem requires that the cost of inventory purchased be recorded in inventory, an asset account. When inventory is sold, the inventory account is decreased by the cost of the item sold. An alternative method, the periodic system, is briefly discussed in the Additional Consideration box below. We explore the topic of inventory in depth in Chapters 8 and 9.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 9,
#   'paragraph_number': 8,
#   'text': 'Transaction: July 6. Purchased $2,000 of supplies for cash.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 9,
#   'paragraph_number': 9,
#   'text': 'Analysis: Purchasing supplies increases one asset (supplies) and decreases another asset (cash). Supplies are an asset because they represent future benefits. We won’t record those supplies as an expense until we use them.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 9,
#   'paragraph_number': 10,
#   'text': 'spi24360_ch02_042-103 50'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 9,
#   'paragraph_number': 11,
#   'text': '05/23/24 09:05 AM'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 10,
#   'paragraph_number': 1,
#   'text': 'To record the month’s cash sales and the cost of those sales.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 10,
#   'paragraph_number': 2,
#   'text': 'Transaction: July 4-31. Sold inventory for $35,000 cash with a cost of $20,000. Analysis: We record cash sales to customers in two entries. First, cash sales increase an asset (cash) and increase shareholders’ equity for the amount of the sale to the customer ($35,000). The increase in equity is recorded by a credit to the temporary account, sales revenue.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 10,
#   'paragraph_number': 3,
#   'text': 'Second, cash sales decrease another asset (inventory) and decrease shareholders’ equity for the cost of the inventory sold ($20,000). The decrease to shareholders’ equity is recorded by a debit to the temporary account, cost of goods sold (an expense).'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 10,
#   'paragraph_number': 4,
#   'text': 'For both transactions combined, the net increase in assets (cash received minus inventory used) equals the net increase in shareholders’ equity (sales revenue minus cost of goods sold). Both of these transactions are summary transactions. Normally each sale made during the month requires a separate and similar entry.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 10,
#   'paragraph_number': 5,
#   'text': 'To record a sale on account and the cost of that sale.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 10,
#   'paragraph_number': 6,
#   'text': 'Transaction: July 9. Sold inventory on account for $3,500 with a cost of $2,000. Analysis: Selling inventory on account is similar to the cash sale shown in the previous transaction. The only difference is that the asset acquired is accounts receivable rather than cash.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 10,
#   'paragraph_number': 7,
#   'text': 'Periodic Inventory System. The principal alternative to the perpetual inventory system is the periodic system. By this approach, we record the cost of inventory purchased in a temporary account called purchases. When inventory is sold, the inventory account is not decreased and cost of goods sold is not recorded. Instead, we determine the balance in the inventory account only at the end of a reporting period (periodically), and then we can determine the cost of goods sold for the period.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 10,
#   'paragraph_number': 8,
#   'text': 'For example, the purchase of $60,000 of inventory on account by Dress Right is recorded as follows:'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 10,
#   'paragraph_number': 9,
#   'text': 'No cost of goods sold entry is recorded when sales are made in the periodic system.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 10,
#   'paragraph_number': 10,
#   'text': 'At the end of July, the amount of ending inventory is determined (either by means of a physical count of goods on hand or by estimation) to be $38,000 and cost of goods sold for the month is determined as follows:'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 10,
#   'paragraph_number': 11,
#   'text': 'We record the cost of goods sold for the period and adjust the inventory account to the actual amount on hand (in this case from zero to $38,000) this way:'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 10,
#   'paragraph_number': 12,
#   'text': 'We discuss inventory in depth in Chapters 8 and 9.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 10,
#   'paragraph_number': 13,
#   'text': 'spi24360_ch02_042-103 51'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 10,
#   'paragraph_number': 14,
#   'text': '05/23/24 09:05 AM'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 11,
#   'paragraph_number': 1,
#   'text': 'Transaction: July 16. Received $1,000 in advance for the first two months’ rent begin- ning on July 16.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 11,
#   'paragraph_number': 2,
#   'text': 'Analysis: Receiving cash from a customer prior to the rental services being provided increases an asset (cash) and increases a liability (deferred rent revenue). We don’t yet record revenue because services have not yet been provided. Instead, at the time cash is received, we owe future services to the customer. We’ll recognize the revenue as those ser- vices are provided.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 11,
#   'paragraph_number': 3,
#   'text': 'Transaction: July 20. Paid $25,000 on account to supplier.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 11,
#   'paragraph_number': 4,
#   'text': 'Analysis: Paying cash on accounts payable to a supplier decreases both an asset (cash) and a liability (accounts payable). A debit decreases the liability, and a credit decreases the asset.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 11,
#   'paragraph_number': 5,
#   'text': 'Transaction: July 20. Paid salaries to employees for the first half of the month, $5,000. Analysis: Paying cash to employees for work in the current period decreases an asset (cash) and decreases shareholders’ equity. The decrease to shareholders’ equity is recorded with a debit to a temporary account, salaries expense.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 11,
#   'paragraph_number': 6,
#   'text': 'Transaction: July 25. Received $1,500 on account from customers. Analysis: Receiving cash from customers on account causes one asset to increase (cash) and another asset to decrease (accounts receivable).'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 11,
#   'paragraph_number': 7,
#   'text': 'To record the payment of a cash dividend.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 11,
#   'paragraph_number': 8,
#   'text': 'Transaction: July 30. Paid shareholders a cash dividend of $1,000. Analysis: Paying a cash dividend is a distribution to owners that reduces both cash and retained earnings. Dividends is a temporary account that later is closed (balance transferred) to retained earnings along with the other temporary accounts (revenues, expenses, gains, and losses) at the end of the fiscal year. We discuss and illustrate the closing process later in the chapter.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 11,
#   'paragraph_number': 9,
#   'text': 'spi24360_ch02_042-103 52'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 12,
#   'paragraph_number': 1,
#   'text': 'Illustration 2-7 summarizes each of the transactions as they would appear in a general journal. In addition to the date, account titles, and debit and credit columns, the journal also has a column titled Post Ref. (Posting Reference). In this column we enter the number assigned to the general ledger account that is being debited or credited. For purposes of this illustration, all asset accounts have been assigned numbers in the 100s, all liabilities are 200s, permanent shareholders’ equity accounts are 300s, revenues are 400s, expenses are 500s, and dividends are 600.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 12,
#   'paragraph_number': 2,
#   'text': 'The General Journal'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 12,
#   'paragraph_number': 3,
#   'text': 'spi24360_ch02_042-103 53'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 12,
#   'paragraph_number': 4,
#   'text': '05/23/24 09:05 AM'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 13,
#   'paragraph_number': 1,
#   'text': 'The ledger accounts also contain a posting reference, usually the page number of the journal in which the journal entry was recorded. This allows for easy cross-referencing between the journal and the ledger.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 13,
#   'paragraph_number': 2,
#   'text': 'Post the effects of journal entries to general ledger accounts and prepare an unadjusted trial balance.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 13,
#   'paragraph_number': 3,
#   'text': 'Step 4 in the accounting cycle is to transfer (post) the debit/credit information from the jour- nal to the general ledger. Illustration 2-8 contains the ledger accounts (in T-account form) for Dress Right after all the general journal transactions have been posted. The reference'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 13,
#   'paragraph_number': 4,
#   'text': 'General Ledger Accounts'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 13,
#   'paragraph_number': 5,
#   'text': 'spi24360_ch02_042-103 54'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 13,
#   'paragraph_number': 6,
#   'text': '05/23/24 09:05 AM'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 14,
#   'paragraph_number': 1,
#   'text': 'GJ1 next to each of the posted amounts indicates that the source of the entry is page 1 of the general journal. An alternative is to number each of the entries in chronological order and reference them by number. Note that each account shows the balance that we call a normal balance—that is, the balance is the debit or credit side used to increase the account.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 14,
#   'paragraph_number': 2,
#   'text': 'Step 5 in the accounting cycle is to prepare an unadjusted trial balance. An unadjusted trial balance is a list of the general ledger accounts along with their balances at a particular date, listed in the order that they appear in the ledger. The purpose of the trial balance is to allow us to check for completeness and to verify that the sum of the accounts with debit balances equals the sum of the accounts with credit balances. The fact that the debits and credits are equal, though, does not necessarily ensure that the equal balances are correct. The trial balance could contain offsetting errors. As we will see later in the chapter, this trial balance also helps with preparing adjusting entries. The unadjusted trial balance for Dress Right appears in Illustration 2-9.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 14,
#   'paragraph_number': 3,
#   'text': 'Unadjusted Trial Balance'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 14,
#   'paragraph_number': 4,
#   'text': 'The Wyndham Wholesale Company began operations on August | and had the following JOURNAL ENTRIES transactions during the month of August. FOR EXTERNAL'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 14,
#   'paragraph_number': 5,
#   'text': 'spi24360_ch02_042-103 55'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 14,
#   'paragraph_number': 6,
#   'text': '05/23/24 09:05 AM'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 15,
#   'paragraph_number': 1,
#   'text': 'CASH oe eeseescesseeseesseceeesseseesseeseessessessssuesseeseesseesssseesuessessesueesesseesesseesesueentsaessesneesees 50,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 15,
#   'paragraph_number': 2,
#   'text': 'COMMON StOCK o...ecececsescssssesesescsssesesesessuesesesescsesvsseseseaeseseseseseseseseseeusaeseaesceeee 50,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 15,
#   'paragraph_number': 3,
#   'text': 'c. Paying rent in advance increases prepaid rent and decreases cash.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 15,
#   'paragraph_number': 4,
#   'text': 'd. Purchasing inventory on account increases both inventory and accounts payable.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 15,
#   'paragraph_number': 5,
#   'text': 'e. Borrowing cash by signing a note increases both cash and notes payable.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 15,
#   'paragraph_number': 6,
#   'text': 'g. Collecting cash on account increases cash and decreases accounts receivable.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 15,
#   'paragraph_number': 7,
#   'text': 'h. Paying suppliers on account decreases both accounts payable and cash.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 15,
#   'paragraph_number': 8,
#   'text': 'spi24360_ch02_042-103 56'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 16,
#   'paragraph_number': 1,
#   'text': 'Step 6 in the accounting cycle is to record adjusting entries and post them to the led- ger accounts. These transactions often do not involve an exchange transaction with another entity and, therefore, are not initiated by a source document.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 16,
#   'paragraph_number': 2,
#   'text': 'Identify and describe the gifferent types of adjusting journal entries.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 16,
#   'paragraph_number': 3,
#   'text': '+An alternative is to debit retained earnings at the time the dividends are declared.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 16,
#   'paragraph_number': 4,
#   'text': 'spi24360_ch02_042-103 57'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 16,
#   'paragraph_number': 5,
#   'text': '05/23/24 09:05 AM'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 17,
#   'paragraph_number': 1,
#   'text': 'Adjusting entries are required to implement the accrual accounting model. More specifi- cally, these entries help ensure that balances of all assets, liabilities, revenues, and expenses are correctly stated by the end of the period, regardless of when cash is received or paid. You might think of adjusting entries as a method of bringing the company’s financial infor- mation up-to-date before preparing the financial statements.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 17,
#   'paragraph_number': 2,
#   'text': 'Adjusting entries are necessary for three situations:'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 17,
#   'paragraph_number': 3,
#   'text': 'Prepayments occur when the cash flow occurs before the expense or revenue is rec- ognized. For example, a company may buy supplies in one period but use them in a later period. The prepayment creates an asset (supplies) which then must be expensed in a future period as the asset is used (supplies expense).'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 17,
#   'paragraph_number': 4,
#   'text': 'Similarly, a company may receive cash from a customer in one period but provide the customer with a good or service in a future period. For instance, online subscription com- panies usually receive cash in advance from customers. At the time of the cash inflow, a liability (deferred revenue) is created. This liability represents goods or services owed to customers who have paid in advance. Revenue is then recognized (and the liability is set- tled) over time as the goods or services are provided to customers.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 17,
# ...
#   'page_number': 55,
#   'paragraph_number': 4,
#   'text': 'Prepare the necessary December 31, 2027, adjusting journal entries.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 55,
#   'paragraph_number': 5,
#   'text': 'Accounting cycle; adjusting entries through post-closing trial balance'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 55,
#   'paragraph_number': 6,
#   'text': 'spi24360_ch02_042-103 96'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 55,
#   'paragraph_number': 7,
#   'text': '05/23/24 09:05 AM'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 56,
#   'paragraph_number': 1,
#   'text': 'Adjusting entries'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 56,
#   'paragraph_number': 2,
#   'text': 'Huang Company’s reporting year-end is December 31. Below are the unadjusted and adjusted trial balances for December 31, 2027.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 56,
#   'paragraph_number': 3,
#   'text': 'Prepare the adjusting journal entries that were recorded on December 31, 2027.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 56,
#   'paragraph_number': 4,
#   'text': 'Accounting cycle'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 56,
#   'paragraph_number': 5,
#   'text': 'The general ledger of the Karlin Company, a consulting company, at January 1, 2027, contained the following account balances:'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 56,
#   'paragraph_number': 6,
#   'text': '02-3 through Lo2-8'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 56,
#   'paragraph_number': 7,
#   'text': 'The following is a summary of the transactions for the year:'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 56,
#   'paragraph_number': 8,
#   'text': 'spi24360_ch02_042-103 97'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 56,
#   'paragraph_number': 9,
#   'text': '05/23/24 09:05 AM'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 57,
#   'paragraph_number': 1,
#   'text': 'Adjusting entries and income effects'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 57,
#   'paragraph_number': 2,
#   'text': 'The information necessary for preparing the December 31, 2027, year-end adjusting entries for Vito’s Pizza Parlor appears below.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 57,
#   'paragraph_number': 3,
#   'text': 'Adjusting entries'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 57,
#   'paragraph_number': 4,
#   'text': 'Excaibur Corporation sells video games for personal computers. The unadjusted trial balance as of December 31, 2027, appears below. December 31 is the company’s reporting year-end. The company uses the perpetual inventory system.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 57,
#   'paragraph_number': 5,
#   'text': 'Information necessary to prepare the year-end adjusting entries appears below.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 57,
#   'paragraph_number': 6,
#   'text': 'spi24360_ch02_042-103 98'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 57,
#   'paragraph_number': 7,
#   'text': '05/23/24 09:05 AM'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 58,
#   'paragraph_number': 1,
#   'text': 'spi24360_ch02_042-103 99'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 58,
#   'paragraph_number': 2,
#   'text': 'Prepare the necessary December 31, 2027, adjusting entries.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 58,
#   'paragraph_number': 3,
#   'text': 'The unadjusted trial balance as of December 31, 2027, for the Bags Consulting Company appears below. December 31 is the company’s reporting year-end.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 58,
#   'paragraph_number': 4,
#   'text': '1. From the trial balance and information given, prepare adjusting entries.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 58,
#   'paragraph_number': 5,
#   'text': 'McGuire Corporation began operations in 2027. The company purchases computer equipment from manufactur- ers and then sells to retail stores. During 2027, the bookkeeper used a check register to record all cash collections and cash payments. No other journals were used. The following is a recap of the cash collections and payments made during the year.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 59,
#   'paragraph_number': 1,
#   'text': 'You are called in to prepare financial statements on December 31, 2027. The following additional information was provided to you:'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 59,
#   'paragraph_number': 2,
#   'text': 'Prepare an income statement for 2027 and a balance sheet as of December 31, 2027.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 59,
#   'paragraph_number': 3,
#   'text': 'Cash versus accrual accounting'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 59,
#   'paragraph_number': 4,
#   'text': 'Selected balance sheet information for the Wolf Company at November 30, and December 31, 2027, is presented below. The company uses the perpetual inventory system and all sales to customers are made on credit.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 59,
#   'paragraph_number': 5,
#   'text': 'The following cash flow information also is available:'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 59,
#   'paragraph_number': 6,
#   'text': '1. Determine the following for the month of December on an accrual basis:'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 59,
#   'paragraph_number': 7,
#   'text': 'Zambrano Wholesale Corporation maintains its records on a cash basis. At the end of each year the company’s accountant obtains the necessary information to prepare accrual-basis financial statements. The following cash flows occurred during the year ended December 31, 2027:'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 59,
#   'paragraph_number': 8,
#   'text': 'spi24360_ch02_042-103 100'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 60,
#   'paragraph_number': 1,
#   'text': 'Selected balance sheet information:'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 60,
#   'paragraph_number': 2,
#   'text': 'Additional information:'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 60,
#   'paragraph_number': 3,
#   'text': 'P2-13 Worksheet'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 60,
#   'paragraph_number': 4,
#   'text': '@ Appendix 2A'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 60,
#   'paragraph_number': 5,
#   'text': 'Using the information from P 2-8, prepare and complete a worksheet similar to Illustration 2A-1. Use the information in the worksheet to prepare an income statement and a statement of shareholders’ equity for 2027 and a balance sheet as of December 31, 2027. Cash dividends paid to shareholders during the year amounted to $6,000. Also prepare the necessary closing entries assuming that adjusting entries have been correctly posted to the accounts.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 60,
#   'paragraph_number': 6,
#   'text': 'Apply your critical-thinking ability to the knowledge you’ve gained. These cases will provide you an opportunity to develop your research, analysis, judgment, and communication skills. You also will work with other students, integrate what you’ve learned, apply it in real-world situations, and consider its global and ethical ramifications. This practice will broaden your knowledge and further develop your decision-making abilities.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 60,
#   'paragraph_number': 7,
#   'text': 'Analysis Case 2-1 Adjusting entries @ LO2-5'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 60,
#   'paragraph_number': 8,
#   'text': '“T don’t understand,” stated one of your friends about their introductory accounting class. The comment was in response to your statements that recording adjusting entries is a critical step in the accounting cycle, and the two major classifications of adjusting entries are prepayments and accruals.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 60,
#   'paragraph_number': 9,
#   'text': 'Respond to your friend.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 60,
#   'paragraph_number': 10,
#   'text': 'spi24360_ch02_042-103 101'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 61,
#   'paragraph_number': 1,
#   'text': 'company has always kept its records on a cash basis. You are provided with the following transaction informa- for the fiscal year ending December 31, 2027:'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 61,
#   'paragraph_number': 2,
#   'text': 'Case 2-3 Cash versus accrual accounting; adjusting entries; Chapters 1 and 2 @ LO2-5, LO2-9'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 61,
#   'paragraph_number': 3,
#   'text': 'You have recently been hired by a small public accounting firm. One of the firm’s partners has asked you to deal with a disgruntled client. The client is applying to a local bank for a substantial loan to remodel a store. The bank requires accrual-based financial statements, but the client has always kept the company’s records on a cash basis. The client’s most recent outburst went something like this: “After all, I collect cash from customers, pay my bills cash, and I am going to pay the bank loan with cash. And, I already show my building and equipment as assets and depreciate them. I just don’t understand the problem.”'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 61,
#   'paragraph_number': 4,
#   'text': 'Draft a memo to the client providing an explanation of why the bank requests accrual-based financial statements for loan requests such as his. Include in the memo:'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 61,
#   'paragraph_number': 5,
#   'text': 'Case 2-4 EDGAR; financial statement information; Apple, Inc.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 61,
#   'paragraph_number': 6,
#   'text': 'Visit www.sec.gov and use EDGAR to search for the Apple, Inc. (ticker: AAPL) annual report (10-K) for the year ended September 30, 2023. You also may find the annual report at the company’s website. Locate the income statement and balance sheet.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 61,
#   'paragraph_number': 7,
#   'text': 'Determine the following amounts for 2023.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 61,
#   'paragraph_number': 8,
#   'text': 'Real World Financials'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 61,
#   'paragraph_number': 9,
#   'text': 'Visit www.sec.gov and use EDGAR to search for the United Parcel Service, Inc. (ticker: UPS) and FedEx Corporation (ticker: FDX) annual reports (10-K) for the year ended December 31, 2023, and May 31, 2023, respectively. You also may find the annual report at the company’s website. Locate the income statement and balance sheet.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 61,
#   'paragraph_number': 10,
#   'text': '05/23/24 09:05 AM'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 62,
#   'paragraph_number': 1,
#   'text': 'The reported net income and dividends for McDonald’s Corporation and Dave & Buster’s Entertainment, Inc. for the period 2020-2022 are provided below.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 62,
#   'paragraph_number': 2,
#   'text': 'For each company, calculate the balance of retained earnings at the end of each year for 2020-2022. The amount of Retained Earnings at the end of 2019 is given as a starting point. You can verify your answers by examining the balance of retained earnings in each company’s balance sheet.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 62,
#   'paragraph_number': 3,
#   'text': 'Visit Connect to find a variety of Data Analytics activities that help build Excel, Tableau, and data visualization skills. Assignable materials include Integrated Excel, Applying Excel, Data Visualizations, Tableau Dashboard Activities, and Applying Tableau Cases.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 62,
#   'paragraph_number': 4,
#   'text': 'EDGAR; transaction analysis; adjusting entries; financial statement information @ 102-1, LO2-6,'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 62,
#   'paragraph_number': 5,
#   'text': 'Pfizer Inc. prepares its financial statements according to U.S. GAAP. Pfizer’s 2022 financial statements and dis- closure notes are available in Connect. You also can obtain this information by visiting www.sec.gov and using EDGAR to search for the Pfizer (ticker: PFE) annual report (10-K) or by downloading it from the company’s website (www.pfizer.com).'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 62,
#   'paragraph_number': 6,
#   'text': '@ 102-1, LO2-6, LO2-7, LO2-8'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 62,
#   'paragraph_number': 7,
#   'text': 'EDGAR; journal entries; adjusting entries; financial statement information'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 62,
#   'paragraph_number': 8,
#   'text': 'Novartis AG prepares its financial statements according to IFRS. Novartis’s 2022 financial statements and dis- closure notes are available in Connect. You also can obtain this information by visiting www.sec.gov and using EDGAR to search for the Novartis (ticker: NVS) annual report (20-F) or by downloading it from the company’s website (www.novartis.com).'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 62,
#   'paragraph_number': 9,
#   'text': 'Design elements: Globe: geopaul/Getty Images; Scale: Alex Slobodkin/E+/Getty Images; Compass: Pictafolio/Getty Images'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 62,
#   'paragraph_number': 10,
#   'text': 'spi24360_ch02_042-103 103'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 62,
#   'paragraph_number': 11,
#   'text': '05/23/24 09:05 AM'}]

# %%
from unstructured.documents.elements import Image

# %%
def extract_image_metadata(esg_report, source_document):
    image_data = []

    for element in esg_report:
        if isinstance(element, Image):
            page_number = element.metadata.page_number
            image_path = element.metadata.image_path if hasattr(element.metadata, 'image_path') else None

            image_data.append({
                "source_document": source_document,
                "page_number": page_number,
                "image_path": image_path
            })

    return image_data

# %%
extracted_image_data = extract_image_metadata(esg_report_raw_data, esg_report_path)

# %%
import matplotlib.pyplot as plt
from PIL import Image
import math

# %%
def display_images_from_metadata(extracted_image_data, images_per_row=4):
    valid_images = [img for img in extracted_image_data if img['image_path']]
    if not valid_images:
        print("No valid image data available.")
        return

    num_images = len(valid_images)
    num_rows = math.ceil(num_images / images_per_row)

    fig, axes = plt.subplots(num_rows, images_per_row, figsize=(20, 5*num_rows))
    axes = axes.flatten() if num_rows > 1 else [axes]

    for ax, img_data in zip(axes, valid_images):
        try:
            img = Image.open(img_data['image_path'])
            ax.imshow(img)
            ax.axis('off')
            ax.set_title(f"Page {img_data['page_number']}", fontsize=10)
        except Exception as e:
            print(f"Error loading image {img_data['image_path']}: {str(e)}")
            ax.text(0.5, 0.5, f"Error loading image\n{str(e)}", ha='center', va='center')
            ax.axis('off')

    for ax in axes[num_images:]:
        fig.delaxes(ax)

    plt.tight_layout()
    plt.show()

# %%
display_images_from_metadata(extracted_image_data)

# %%
from unstructured.documents.elements import Table

# %%
def extract_table_metadata(esg_report, source_document):
    table_data = []

    for element in esg_report:
        if isinstance(element, Table):
            page_number = element.metadata.page_number


            table_content = str(element)

            table_data.append({
                "source_document": source_document,
                "page_number": page_number,
                "table_content": table_content
            })

    return table_data

# %%
extracted_table_data = extract_table_metadata(esg_report_raw_data, esg_report_path)

# %%
extracted_table_data
# Out:
# [{'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 1,
#   'table_content': 'OBJECTIVES @ L02-1 Understand routine economic events—transactions—and determine on a company’s financial position and on specific accounts. (p. 44) @ LO2-2 Describe the steps in the accounting cycle. (p. 47) @ LO2-3 = Analyze and record transactions using journal entries. (p. 49) @ LO2-4 Post the effects of journal entries to general ledger accounts and prepare unadjusted trial balance. (p. 54) @ LO2-5 Identify and describe the different types of adjusting journal entries. (p. @ LO2-6 = Record adjusting journal entries in general journal format, post entries, prepare an adjusted trial balance. (p. 58) @ LO2-7 Describe the four basic financial statements. (p. 66) @ LO2-8 = Explain the closing process. (p. 70) @ LO2-9 = Convert from cash-basis net income to accrual-basis net income. (p. 74)'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 2,
#   'table_content': 'Salaries $162,000 Rent 18,000 Supplies 23,000 Utilities 14,000 Advertising 63,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 4,
#   'table_content': 'Shareholders’ Equity Paid-in Retained Assets = Liabilities + Capital + Earnings 1. Provided services of $10,000 to +$10,000 +$10,000 customers on account. (Accounts (t Service Revenue) Receivable) . Incurred (but did not pay) utilities +$5,000 -—$5,000 cost of $5,000 for operations in (Utilities (f Utilities Expense) the current period. Payable) . Paid dividends of $2,000 to —$2,000 shareholders. (t Dividends)'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 5,
#   'table_content': 'Assets = Liabilities + Shareholders’ Equity Cash Note Payable Debit | Credit Debit | Credit 40,000 40,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 6,
#   'table_content': 'Step 5 Prepare an unadjusted trial balance. At the end Step 6 Record adjusting entries and post to the general of the ‘i ledger accounts. accountin period o Step 7 Prepare an adjusted trial balance. Step 8 Prepare financial statements. At the end of Step 9 Close the temporary accounts to retained earnings.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 7,
#   'table_content': 'CASH oo eseecsseecstecsseesseecssessseesseesseeessecesessssecssesssnesssessseeesseesseeesseesseeessecssenesseessessseeesneees 40,000 Notes payable vee To record the borrowing of cash and the signing of a note payable. 40,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 8,
#   'table_content': 'July 1 60,000 Common stock. 60,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 9,
#   'table_content': 'record the borrowing cash and the signing of notes payable.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 9,
#   'table_content': 'record the payment of year’s rent in advance.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 9,
#   'table_content': 'record the purchase of office equipment.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 9,
#   'table_content': 'of'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 9,
#   'table_content': 'To record the purchase of supplies.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 10,
#   'table_content': 'Accounting July 4-31 To record the 35,000 cash sales Sales revenue 35,000 those sales. Cost of goods sold (expense) 20,000 Inventory 20,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 10,
#   'table_content': 'July 9 3.500 , Accounts receivable. Sales revenue... 3,500 Cost Of OOS SOIG wc eeecceceesecesseeseessesstesesssseessesseeseseesesetesesseeneeseeeesetenees 2,000 INVENTOLY oes cesseeseesseeseesseseessessessessesseesuessessesieenessesesseeseesseeetsaeeseesseeseets 2,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 10,
#   'table_content': 'Purchases 60,000 Accounts payable ..... 60,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 10,
#   'table_content': 'Beginning inventory $ 0 Plus: Purchases 60,000 Less: Ending inventory (38,000) Cost of goods sold $ 22,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 10,
#   'table_content': 'Cost of goods sold 22,000 Inventory. 38,000 Purchases.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 11,
#   'table_content': 'record the collection of in advance.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 11,
#   'table_content': 'To record the payment of accounts payable.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 11,
#   'table_content': 'record the payment of salaries for the first half of month.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 11,
#   'table_content': 'record the collection of cash on account.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 11,
#   'table_content': 'To record the payment of a cash dividend.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 12,
#   'table_content': 'Date 2027 General Journal Account Title and Explanation Post Ref. The July 1 Cash Common stock To record the issuance of common stock. Cash Notes payable To record the borrowing of cash and the signing of notes payable. Prepaid rent Cash To record the payment of one year’s rent in advance. Office equipment Cash To record the purchase of office equipment. Inventory Accounts payable To record the purchase of inventory. Supplies Cash To record the purchase of supplies. Cash Sales revenue To record cash sales for the month. Cost of goods sold Inventory To record the cost of inventory sold. Accounts receivable Sales revenue To record a sale on account. Cost of goods sold Inventory To record the cost of inventory sold. Cash Deferred rent revenue To record the collection of rent in advance. Accounts payable Cash To record the payment of accounts payable. Salaries expense Cash To record the payment of salaries for the first half of the month. Cash Accounts receivable To record the collection of cash on account. Dividends Cash To record the payment of a cash dividend. 100 300 100 220'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 13,
#   'table_content': 'Balance Sheet Accounts Cash 100 Prepaid Rent July 1 GJ1 60,000 | 24,000 July1GJ1 July 1 GJ1 24,000 1GJ1 40,000 | 12,000 1GJ1 4-31 GJ1 35,000 2,000 6GJ1 16 GJ1 1,000 | 25,000 20 GJ1 25 GJ1 1,500 5,000 20 GJ1 1,000 30 GJ1 July 31 Bal. 68,500 July 31 Bal. 24,000 Accounts Receivable 110 Inventory 140 July 9 GJ1 3,500 1,500 July 25 GJ1 July 3 GJ1 60,000 | 20,000 July 4-31 2,000 9GJ1 July 31 Bal. 2,000 July 31 Bal. 38,000 Supplies Office equipment July 6 GJ1 2,000 July 1 GJ1 12,000 July 31 Bal. 2,000 July 31 Bal. 12,000 Accounts Payable 210 Notes Payable 220 July 20 GJ1 25,000 | 60,000 July 3 GJ1 40,000 July 1 GJ1 35,000 July 31 Bal. 40,000 July 31 Bal. Deferred Rent Revenue 230 1,000 July 16 GJ1 1,000 July 31 Bal. Common Stock 300 Retained Earnings 310 60,000 July 1 GJ1 60,000 July 31 Bal. oO July 31 Bal. Income Statement Accounts levenue 400 Cost of Goods Sold 35,000 July 4-31 GJ1 July 4-31 GJ1 20,000 3,500 9G)1 9GJ1 2,000 38,500 July31Bal. July 31 Bal. 22,000 Salaries Expense 510 July 20 GJ1 5,000 July 31 Bal. 5,000 Dividends Dividends 600 July 30 GJ1 1,000 July 31 Bal. 1,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 14,
#   'table_content': 'DRESS RIGHT CLOTHING CORPORATION Unadjusted Trial Balance July 31, 2027 Account Title Debit Cash $ 68,500 Accounts receivable 2,000 Supplies 2,000 Prepaid rent 24,000 Inventory 38,000 Office equipment 12,000 Accounts payable $ 35,000 Notes payable 40,000 Deferred rent revenue 1,000 Common stock 60,000 Retained earnings 0 Dividends 1,000 Sales revenue 38,500 Cost of goods sold 22,000 Salaries expense 5,000 Totals* $174,500 $174,500'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 15,
#   'table_content': 'EqQUIPMENA wu... eseeeeseceeseesesseeseessessesseeseesseeseesuessesaeeseesseeseesuesnesetssecsseeseesneeneseeenee 20,000 CASH ooeeeeeeseceeseseeseestesseesteseessessesesseesteseeseessesuesneesiesessenssssueeneeaneeeeseeeseesneeeee 20,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 15,
#   'table_content': 'Prepaid rent. 6,000 6,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 15,
#   'table_content': 'Inventory. 38,000 Accounts payable 38,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 15,
#   'table_content': '30,000 Notes payable 30,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 15,
#   'table_content': 'Accounts receivable. 40,000 Sales revenue... 40,000 Cost of goods sold 22,000 Inventory. 22,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 15,
#   'table_content': '15,000 Accounts receivabl 15,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 15,
#   'table_content': 'ACCOUNTS PAYADIC........ceeccescseecssessseeesseesseecsseesseesssecssecssesesseessesssesessesssneesneesseeeseee 20,000 (Sais beeeereneseenresssneresseressseereseeresasenrreassnenanenrnsessnresnsrenaneeereesseenanenresesrereessnreeneerreese™ 20,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 16,
#   'table_content': 'i. Receiving cash from customers in advance of services to be provided increases cash and increases deferred revenue (a liability). Cash... 2,000 Deferred revenue... 2,000 j. Paying salaries for the period increases salaries expense and decreases cash. Salaries expense. 7,000 7,000 k. Receiving a bill for utilities for the current period increases both utilities expense and accounts payable. Utilities expense Accounts payable.. 2,000 2,000 1. Lending cash to another entity by accepting a note increases notes receivable and decreases cash. Notes receivable . 20,000 Cash 20,000 m. Paying dividends to shareholders increases dividends and decreases cash. 1,000 1,000 2. Prepare an unadjusted trial balance. Account Title Debit Credit Cash $ 23,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 16,
#   'table_content': 'Account Title Debit Credit Cash $ 23,000 Accounts receivable 25,000 Prepaid rent 6,000 Inventory 16,000 Notes receivable 20,000 Equipment 20,000 Accounts payable $ 20,000 Deferred revenue 2,000 Notes payable 30,000 Common stock 50,000 Retained earnings Oo Dividends 1,000 Sales revenue 40,000 Cost of goods sold 22,000 Salaries expense 7,000 Utilities expense 2,000 Totals $142,000 $ 142,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 18,
#   'table_content': 'Beg. bal. 0 Purch. 24,000 End. bal. 22,000 2,000 Adj.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 18,
#   'table_content': 'Beg. bal. 0 Adj. 200 End bal. 200'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 19,
#   'table_content': 'O Beg. bal. 1,000 Received Adj. 250 750 — End bal.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 19,
#   'table_content': '0 Beg. bal. 250 Adj. 250 End bal.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 19,
#   'table_content': 'Adj.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 21,
#   'table_content': 'Beg. bal. 0 Adj. 200 End bal. 200'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 22,
#   'table_content': 'Prepaid Expenses Deferred Revenues | Liability Revenue Accrued Expenses Accrued Revenues | Asset Revenue'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 22,
#   'table_content': 'DRESS RIGHT CLOTHING CORPORATION General Journal 31, 2027 Account Title and Explanation Debit Supplies expense 800 Supplies To record the cost of supplies used during July. Rent expense 2,000 Prepaid rent To record the cost of expired rent for July. Depreciation expense 200 Accumulated depreciation To record depreciation of equipment for July. Deferred rent revenue Rent revenue To record previously deferred rent revenue recognized during July. Salaries expense Salaries payable To record salaries incurred but not yet paid at the end of July. Interest expense Interest payable To record interest incurred but not yet paid at the end of July.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 23,
#   'table_content': 'Adjusted July 31, 2027 Account Title Debit Cash $ 68,500 Accounts receivable 2,000 Supplies 1,200 Prepaid rent 22,000 Inventory 38,000 Office equipment 12,000 Accumulated depreciation Accounts payable Notes payable Deferred rent revenue Salaries payable Interest payable Common stock Retained earnings Dividends 1,000 Sales revenue Rent revenue Cost of goods sold 22,000 Salaries expense 10,500 Supplies expense 800 Rent expense 2,000 Depreciation expense 200 Interest expense Boo) Totals $180,533 $180,533'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 24,
#   'table_content': 'Interest expense 250 Interest payable 250'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 24,
#   'table_content': 'Depreciation expense ......eccecesecceesesiesseesesneeesesesseesesneenesesesseesesneeeeneeeneene 500 Accumulated depreciation .........ccecccecseecsecsseeessesssessseesseesseesneesseesseessesssneess 500'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 24,
#   'table_content': 'Interest receivable . 100 Interest revenue. 100'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 24,
#   'table_content': 'ReMt CXPeNS.... ee eeeceeseseessesseesneesteseesesseeseesseestessesesseesesneeeteseesesneeseesneesteneesneese 2,000 Prepaid Pent woe eseeseesesseesessesseesteseesseeseessesseestesnsseeeseeseeneeseseeseeeseseeenee 2,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 24,
#   'table_content': "Deferred revenue Miscellaneous revenu' 1,250 1,250"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 25,
#   'table_content': 'Account Title Debit Credit Cash $ 23,000 Accounts receivable 25,000 Prepaid rent 4,000 Inventory 16,000 Interest receivable 100 Notes receivable 20,000 Equipment 20,000 Accumulated depreciation $ 500 Accounts payable 20,000 Deferred revenue 750 Interest payable 250 Notes payable 30,000 Common stock 50,000 Retained earnings Dividends 1,000 Sales revenue 40,000 Interest revenue 100 Miscellaneous revenue 1,250 Cost of goods sold 22,000 Salaries expense 7,000 Utilities expense 2,000 Interest expense 250 Depreciation expense 500 Rent expense 2,000 Totals $142,850 $142,850'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 25,
#   'table_content': 'ooanoDm Assets overstated _Liabilities overstated Income overstated Adjusting Entry (understated) (understated) (understated) . Interest expense $ — $ (250) $ 250 . Depreciation expense 500 _ 500 Interest revenue (100) — (100) . Rent expense 2,000 — 2,000 Miscellaneous revenue — 1,250 (1,250) Net effect $2,400 $1,000 $1,400'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 27,
#   'table_content': 'DRESS RIGHT CLOTHING CORPORATION Balance Sheet July 31, 2027 Assets Current assets: Cash $ 68,500 Accounts receivable 2,000 Supplies 1,200 Inventory 38,000 Prepaid rent 22,000 Total current assets 131,700 Property and equipment: Office equipment Less: Accumulated depreciation 11,800 Total assets $143,500 Liabilities and Shareholders’ Equity Current liabilities: Accounts payable $ 35,000 Salaries payable 5,500 Deferred rent revenue 750 Interest payable B35 Notes payable 10,000 Total current liabilities 51,583 Long-term liabilities: Notes payable 30,000 Shareholders’ equity: Common stock (6,000 shares issued and outstanding) Retained earnings Total shareholders’ equity 61,917 Total liabilities and shareholders’ equity $143,500 *Beginning retained earnings + Net income — Dividends $0 + $2,917 — $1,000 =$1,917'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 30,
#   'table_content': 'CHAPTER 2 Review of the'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 30,
#   'table_content': '0 Beg. Bal. Expenses 35,833 | 38,750 Revenues Dividends 1,000 1,917 End Bal.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 31,
#   'table_content': 'DRESS RIGHT CLOTHING CORPORATION Post-Closing Trial Balance July 31, 2027 Account Title Debit Cash $ 68,500 Accounts receivable 2,000 Supplies 1,200 Prepaid rent 22,000 Inventory 38,000 Office equipment 12,000 Accumulated depreciation $ 200 Accounts payable 35,000 Notes payable 40,000 Deferred rent revenue 750 Salaries payable 5,500 Interest payable B33) Common stock 60,000 Retained earnings 1,917 Totals $143,700 $143,700'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 31,
#   'table_content': 'For the Month of August 2027 Sales revenue $40,000 Cost of goods sold 22,000 Gross profit 18,000 Operating expenses: Salaries $7,000 Utilities 2,000 Depreciation 500 Rent 2,000 Total operating expenses 11,500 Operating income 6,500 Other income (expense): Interest revenue 100 Miscellaneous revenue 1,250 Interest expense (250) 1,100 Net income $ 7,600'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 32,
#   'table_content': 'Total Common Retained Shareholders’ Stock Earnings Equity Balance at August 1, 2027 $ oO $ Oo $ ° Issue of common stock 50,000 50,000 Net income for August 2027 7,600 7,600 Less: Dividends (1,000) (1,000) Balance at August 31, 2027 $50,000 $6,600 $56,600'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 32,
#   'table_content': 'Net income for August 2027 7,600 7,600 Less: Dividends (1,000) (1,000) Balance at August 31, 2027 $50,000 $6,600 $56,600 WYNDHAM WHOLESALE COMPANY Balance Sheet At August 31, 2027 Assets Current assets: Cash $ 23,000 Accounts receivable 25,000 Inventory 16,000 Interest receivable 100 Notes receivable 20,000 Prepaid rent 4,000 Total current assets 88,100 Property and equipment: Equipment $20,000 Less: Accumulated depreciation 500 19,500 Total assets $107,600 Liabilities and Shareholders’ Equity Current liabilities: Accounts payable $ 20,000 Interest payable 250 Deferred revenue 750 Total current liabilities 21,000 Long-term lial 2 Notes payable 30,000 Shareholders’ equity: Common stock, 5,000 shares issued and outstanding $50,000 Retained earnings 6,600 Total shareholders’ equity 56,600 Total liabilities and shareholders’ equity $107,600'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 32,
#   'table_content': 'USS Sales revenue 40,000 Interest revenue 100 Miscellaneous revenue 1,250 Retained earnings... 41,350 August 31 Retained earnings 33,750 Cost of goods sold 22,000 Salaries expense... 7,000 Utilities expense 2,000 Depreciation expense 500 Rent expense 2,000 Interest expense 250 August 31 Retained earnings 1,000 Dividends...... 1,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 33,
#   'table_content': 'Post-Closing Trial Balance Account Title Debit Credit Cash $ 23,000 Accounts receivable 25,000 Prepaid rent 4,000 Inventory 16,000 Interest receivable 100 Notes receivable 20,000 Equipment 20,000 Accumulated depreciation $ 500 Accounts payable 20,000 Interest payable 250 Deferred revenue 750 Notes payable 30,000 Common stock 50,000 Retained earnings 6,600 Totals $108,100 $108,100'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 33,
#   'table_content': 'Balance, beginning of year $ 5,000 Plus: Cash paid 20,000 Less: Insurance expense ? Balance, end of year $ 3,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 34,
#   'table_content': 'Salaries Payable Balance, beginning of year $ 12,000 Plus: Salaries expense ? Less: Cash paid (150,000) Balance, end of year $ 18,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 34,
#   'table_content': 'Salaries Payable Salaries Expense 12,000 Beg. balance Cash paid 150,000 ? Salaries expense ? 18,000 End. balance'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 34,
#   'table_content': 'Accounts Receivable Sales Revenue Beg. balance 45,000 Sales on account ? ? Sales on account 220,000 Cash collections End. balance 33,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 35,
#   'table_content': 'January 1, 2027 December 31, 2027 Accounts receivable $ 16,000 $ 25,000 Prepaid expenses 7,000 4,000 Accrued liabilities 2,100 1,400 (for operating expenses) Deferred revenues 3,000 4,200 Accrual net income is $68,500, determined as follows: Cash-basis net income $63,000 Add: Increase in accounts receivable 9,000 Deduct: Decrease in prepaid expenses (3,000) Add: Decrease in accrued liabilities 700 Deduct: Increase in deferred revenues (1,200) Accrual-basis net income $ 68,500'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 35,
#   'table_content': 'Converting Cash-Basis Income to Accrual-Basis Income Increases Decreases Assets Add Deduct Liabilities Deduct Add'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 39,
#   'table_content': 'Salaries Expense Salaries Payable Bal. July 31 10,500 5,500 Bal. July 31 Cash payment 5,500 0 Balance'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 39,
#   'table_content': 'Salaries Expense Salaries Payable Bal. July 31 10,500 5,500 Bal. July 31 5,500 (Reversing entry) 5,500 Cash payment 5,500 Balance 10,500 0 Balance'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 40,
#   'table_content': 'Supplies Supplies Expense (Cash payment) 2,000 800 (Adjusting entry) 800 Bal. July 31 1,200 Bal. July 31 800'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 40,
#   'table_content': 'Supplies Supplies Expense Cash payment 2,000 1,200 (Adjusting entry) 1,200 Bal. July 31 1,200 Bal. July 31 800'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 41,
#   'table_content': 'Accounts Receivable 110 Sales Revenue 400 July 31 Balance 2,000 Aug. 31 SJ1 3,295 3,295 Aug. 31 SJ1'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 42,
#   'table_content': 'Page 1 Accounts Cr. Sales Receivable Sales Revenue (400) Subsidiary Invoice Dr. Accounts Account No. Customer Name No. Receivable (110) 801 Leland High School 1,500 812 Mr. John Smith 813 Greystone School 803 Ms. Barbara Jones 805 Hart Middle School'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 47,
#   'table_content': 'List A List B 4. Source documents a. Record of the dual effect of a transaction in debit/credit form. —_——_ 2. Transaction analysis b. Updates to account balances recorded at the end of a reporting period. 3. Journal c. Primary means of disseminating information to external decision makers. —__—._ 4. Posting d. To zero out the temporary accounts. 5. Unadjusted trial balance e. Determine the dual effect on the accounting equation. 6. Adjusting entries f. List of accounts and their balances before recording adjusting entries. 7. Adjusted trial balance g. List of accounts and their balances after recording closing entries. —_—_ 8. Financial statements h. List of accounts and their balances after recording adjusting entries. 9. Closing entries . Transferring debits and credits from the journal to the ledger. 10. Post-closing trial balance j. Used to identify and process external transactions.'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 48,
#   'table_content': 'Increase (I) or Decrease (D) Account 1. Inventory 2. Depreciation expense 3. Accounts payable 4. Prepaid rent 5. Sales revenue 6. Common stock 7 Salaries payable 8. Cost of goods sold 9 Utilities expense 10. Equipment 11. Accounts receivable 12. Utilities payable 13. Rent expense 14. Interest expense 15. Interest revenue'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 48,
#   'table_content': '(1) Accounts payable (4) Accounts receivable (7) Supplies expense (10) Retained earnings (13) Deferred sales revenue (16) Cost of goods sold (19) Dividends (2) Equipment (5) Cash (8) Prepaid rent (11) Notes payable (14) Rent expense (17) Salaries expense (3) Inventory (6) Supplies (9) Sales revenue (12) Common stock (15) Salaries payable (18) Interest expense'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 49,
#   'table_content': 'Debit Credit Interest expense 7,200 Interest payable 7,200 Rent expense 35,000 Prepaid rent 35,000 Interest receivable 500 Interest revenue 500'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 50,
#   'table_content': 'Account Title Debit Credit Cash $ 21,000 Accounts receivable 300,000 Prepaid rent 10,000 Inventory 50,000 Office equipment 600,000 Accumulated depreciation $ 250,000 Accounts payable 60,000 Notes payable (due in six months) 60,000 Salaries payable 8,000 Interest payable 2,000 Common stock 400,000 Retained earnings 100,000 Sales revenue 800,000 Cost of goods sold 480,000 Salaries expense 120,000 Rent expense 30,000 Depreciation expense 60,000 Interest expense 4,000 Advertising expense 5,000 Totals $1,680,000 $1,680,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 50,
#   'table_content': 'Account Title Debit Credit Retained earnings $ 80,000 Sales revenue 750,000 Interest revenue 3,000 Cost of goods sold $420,000 Salaries expense 100,000 Rent expense 15,000 Depreciation expense 30,000 Interest expense 5,000 Insurance expense 6,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 50,
#   'table_content': 'Sales revenue $492,000 Salaries expense 80,000 Interest revenue 6,000 Advertising expense 10,000 Gain on sale of investments 8,000 Cost of goods sold $284,000 Insurance expense 12,000 Interest expense 4,000 Income tax expense 30,000 Depreciation expense 20,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 50,
#   'table_content': 'accounting; adjusting entries LO2-5, LO2-6, LO2-9 Nov. 30 Dec. 31 Dr. Cr. Dr. Cr. Supplies $1,500 $3,000 Prepaid insurance 6,000 4,500 Salaries payable $10,000 $15,000 Deferred rent revenue 2,000 1,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 51,
#   'table_content': 'Cash collected for: Services to customers $320,000 Cash paid for: Salaries $180,000 Supplies 25,000 Rent 12,000 Insurance 6,000 Miscellaneous 20,000 243,000 Net operating cash flow $ 77,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 52,
#   'table_content': 'January 1, 2027 December 31, 2027 Accounts receivable $32,000 $27,000 Prepaid insurance 0 2,000 Supplies 1,000 1,500 Accrued liabilities 2,400 3,400 (for miscellaneous expenses)'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 52,
#   'table_content': 'January 1, 2027 December 31, 2027 Accounts receivable $62,000 $55,000 Prepaid insurance 4,500 6,000 Prepaid rent 9,200 8,200 Deferred service revenue 9,200 11,000 Accrued liabilities 12,200 15,600 (for various expenses)'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 52,
#   'table_content': 'Account Title Debit Credit Cash $ 20,000 Accounts receivable 35,000 Prepaid rent 5,000 Inventory 50,000 Equipment 100,000 Accumulated depreciation $ 30,000 Accounts payable 25,000 Salaries payable oO Common stock 100,000 Retained earnings 29,000 Sales revenue 323,000 Cost of goods sold 180,000 Salaries expense 71,000 Rent expense 30,000 Depreciation expense 0 Utilities expense 12,000 Advertising expense 4,000 Totals $507,000 $507,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 53,
#   'table_content': 'Transaction 1. Purchased inventory on account. . Collected an account receivable. . Borrowed $20,000 and signed a note. . Recorded depreciation expense. . Purchased equipment for cash. . Sold inventory for cash (the sale only, not the cost of the inventory). . Sold inventory on credit (the sale only, not the cost of the inventory). . Recorded accrued salaries payable. . Paid employee salaries. 10. Sold equipment for cash. 11. Sold equipment on credit. 12. Paid a cash dividend to shareholders. 13. Issued common stock in exchange for cash. 14. Paid accounts payable. ONOORWN © - ° £ 5 3 2'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 53,
#   'table_content': 'Transaction Journal . Paid interest on a loan. . Recorded depreciation expense. . Purchased office equipment for cash. . Purchased inventory on account. Sold inventory on credit (the sale only, not the cost of the inventory). . Sold inventory for cash (the sale only, not the cost of the inventory). . Paid rent. . Recorded accrued interest payable. . Paid advertising bill. . Sold a factory building in exchange for a note receivable. . Collected cash from customers on account. . Paid employee salaries. . Collected interest on the note receivable. ON OAOAWN= N=O00 w'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 54,
#   'table_content': 'Account Title Debit Credit Cash $ 5,000 Accounts receivable 2,000 Inventory 5,000 Equipment 11,000 Accumulated depreciation $ 3,500 Accounts payable 3,000 Accrued liabilities 0 Common stock 10,000 Retained earnings 6,500 Dividends oO Sales revenue 0 Cost of goods sold 0 Salaries expense 0 Rent expense 0 Advertising expense 0 oO Totals $23,000 $ 23,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 55,
#   'table_content': 'Account Title Debit Credit Cash $ 30,000 Accounts receivable 40,000 Supplies 1,500 Inventory 60,000 Notes receivable 20,000 Interest receivable oO Prepaid rent 2,000 Prepaid insurance 6,000 Office equipment 80,000 Accumulated depreciation $ 30,000 Accounts payable 31,000 Salaries payable 0 Notes payable 50,000 Interest payable 0 Deferred sales revenue 2,000 Common stock 60,000 Retained earnings 28,500 Dividends 4,000 Sales revenue 146,000 Interest revenue 0 Cost of goods sold 70,000 Salaries expense 18,900 Rent expense 11,000 Depreciation expense 0 Interest expense 0 Supplies expense 1,100 Insurance expense 0 Advertising expense 3,000 Totals $347,500 $347,500'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 56,
#   'table_content': 'Unadjusted Adjusted Account Title Debit Credit Debit Credit Cash $ 50,000 $ 50,000 Accounts receivable 35,000 35,000 Prepaid rent 2,000 1,200 Supplies 1,500 800 Inventory 60,000 60,000 Notes receivable 30,000 30,000 Interest receivable 0 1,500 Office equipment 45,000 45,000 Accumulated depreciation $ 15,000 $ 21,500 Accounts payable 34,000 34,000 Salaries payable oO 6,200 Notes payable 50,000 50,000 Interest payable oO 2,500 Deferred rent revenue 2,000 0 Common stock 46,000 46,000 Retained earnings 20,000 20,000 Sales revenue 244,000 244,000 Rent revenue 4,000 6,000 Interest revenue oO 1,500 Cost of goods sold 126,000 126,000 Salaries expense 45,000 51,200 Rent expense 11,000 11,800 Depreciation expense ° 6,500 Supplies expense 1,100 1,800 Interest expense 5,400 7,900 Advertising expense 3,000 3,000 Totals $415,000 $415,000 $431,700 $431,700'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 56,
#   'table_content': 'Account Title Debit Credit Cash $30,000 Accounts receivable 15,000 Equipment 20,000 Accumulated depreciation $ 6,000 Salaries payable 9,000 Common stock 40,500 Retained earnings 9,500 Total $65,000 $65,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 57,
#   'table_content': 'Account Title Debit Cash $ 23,300 Accounts receivable 32,500 Supplies 2,000 Prepaid rent 14,000 Inventory 65,000 Office equipment 75,000 Accumulated depreciation $ Accounts payable Salaries payable Notes payable Common stock Retained earnings Dividends 6,000 Sales revenue Cost of goods sold 95,000 Interest expense 0 Salaries expense 32,350 Rent expense 0 Supplies expense 0 Utilities expense 6,000 Totals $351,150'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 58,
#   'table_content': '. . . Account Title Debit Credit Cash $ 8,000 Accounts receivable 9,000 Prepaid insurance 3,000 Land 200,000 Buildings 50,000 Accumulated depreciation—buildings $ 20,000 Office equipment 100,000 Accumulated depreciation—office equipment 40,000 Accounts payable 35,050 Salaries payable 0 Deferred rent revenue 7,500 Common stock 200,000 Retained earnings 56,450 Service revenue 90,000 Interest revenue 3,000 Rent revenue 0 Salaries expense 37,000 Depreciation expense 0 Insurance expense 0 Utilities expense 30,000 Maintenance expense 15,000 Totals $452,000 $452,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 58,
#   'table_content': 'Issue of common stock $ 50,000 Collections from customers 320,000 Borrowed from local bank on April 1, note signed requiring 40,000 principal and interest at 12% to be paid on March 31, 2028 — Total cash collections $410,000 Cash payments: —_—— Purchase of inventory $220,000 Payment of salaries 80,000 Purchase of office equipment 30,000 Payment of rent on building 14,000 Miscellaneous expense 10,000 Total cash payments $354,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 59,
#   'table_content': 'Nov. 30 Dec. 31 Debit Credit Debit Credit Accounts receivable $10,000 $3,000 Prepaid insurance 5,000 7,500 Inventory 7,000 6,000 Accounts payable $12,000 $15,000 Salaries payable 5,000 3,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 59,
#   'table_content': 'From customers $675,000 Interest on note 4,000 Loan from a local bank 100,000 Total cash collections $779,000 payments: Purchase of inventory $390,000 Annual insurance payment 6,000 Payment of salaries 210,000 Dividends paid to shareholders 10,000 Annual rent payment 24,000 Total cash payments $640,000'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 60,
#   'table_content': '12/31/2026 12/31/2027 Cash $ 25,000 $ 164,000 Accounts receivable 62,000 92,000 Inventory 80,000 62,000 Prepaid insurance 2,500 ? Prepaid rent 11,000 ? Interest receivable 3,000 ? Notes receivable 50,000 50,000 Equipment 100,000 100,000 Accumulated depreciation (40,000) (50,000) Accounts payable (for inventory) 110,000 122,000 Salaries payable 20,000 24,000 Notes payable 0 100,000 Interest payable oO ?'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 62,
#   'table_content': 'earnings; McDonald’s and Dave & Buster’s Entertainment @ 102-8 Real World Financials ($ in millions) McDonald’s Dave & Buster’s Entertainment Retained Retained NetIncome Dividends Earnings NetIncome Dividends Earnings 2019 $52,930.5 $433.5 2020 $4,730.5 $3,752.9 $(207.0) $0.0 2021 $7,545.2 $3,918.6 $ 108.6 $0.0 2022 $6,177.4 $4,168.2 $137.1 $0.0'}]

# %%
# %%bash
#
# pip -qqq install langchain-core
# pip -qqq install langchain-openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.6/411.6 kB 14.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.3/454.3 kB 27.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 48.8 MB/s eta 0:00:00

# %%
tables_summarizer_prompt = """
summarize the table deeply understand and form mcq questions with options
Table:{table_content}
"""

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

# %%
# !pip install python-dotenv
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.1

# %%
from google.colab import userdata
userdata.get('LLM_FOUNDARY_API')
# Out:
# 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJlbWFpbCI6Im5pdmVkaGl0aGEuZ2tAc3RyYWl2ZS5jb20ifQ.ypwfXXfxkri1KqreP-kcEFROUjBhd9dnl2oduI9mzVQ'

# %%
import os
from google.colab import userdata


OPENAI_API_KEY = userdata.get('LLM_FOUNDARY_API')


if OPENAI_API_KEY:
    os.environ["LLM_FOUNDARY_API"] = OPENAI_API_KEY
else:

    raise ValueError("LLM_FOUNDARY_API not found in Colab userdata. Please set it correctly.")

# %%
import os
from google.colab import userdata

LLM_FOUNDARY_API = userdata.get('LLM_FOUNDARY_API')

if LLM_FOUNDARY_API:
    os.environ["LLM_FOUNDARY_API"] = LLM_FOUNDARY_API
    print("API key set successfully.")
else:

    OPENAI_API_KEY = input("Please enter your OpenAI API key: ")
    os.environ["LLM_FOUNDARY_API"] = OPENAI_API_KEY
    print("API key set successfully.")
# Out:
# API key set successfully.

# %%
import os
from google.colab import userdata


OPENAI_API_KEY = userdata.get('LLM_FOUNDARY_API')

if OPENAI_API_KEY:

    os.environ["LLM_FOUNDARY_API"] = OPENAI_API_KEY
    print("API key set successfully from userdata.")
else:

    OPENAI_API_KEY = input("Please enter your OpenAI API key: ")

    os.environ["LLM_FOUNDARY_API"] = OPENAI_API_KEY


    print("API key set successfully.")


description_model = ChatOpenAI(
    openai_api_base="https://llmfoundry.straive.com/openai/v1/",
    openai_api_key=f'{os.environ["LLM_FOUNDARY_API"]}:my-test-project',
    model="gpt-4o-mini")
# Out:
# API key set successfully from userdata.

# %%
description_model = ChatOpenAI(
    openai_api_base="https://llmfoundry.straive.com/openai/v1/",
    openai_api_key=f'{os.environ["LLM_FOUNDARY_API"]}:my-test-project',
    model="gpt-4o-mini")

# %%
print(description_model)
# Out:
# client=<openai.resources.chat.completions.Completions object at 0x7d6249d17bb0> async_client=<openai.resources.chat.completions.AsyncCompletions object at 0x7d6228498070> root_client=<openai.OpenAI object at 0x7d62499fdba0> root_async_client=<openai.AsyncOpenAI object at 0x7d6249d17b50> model_name='gpt-4o-mini' model_kwargs={} openai_api_key=SecretStr('**********') openai_api_base='https://llmfoundry.straive.com/openai/v1/'

# %%
def extract_table_metadata_with_summary(esg_report,
                                        source_document,
                                        tables_summarizer_prompt):

    table_data = []
    prompt = ChatPromptTemplate.from_template(tables_summarizer_prompt)

    for element in esg_report:
        if isinstance(element, Table):
            page_number = element.metadata.page_number


            table_content = str(element)


            messages = prompt.format_messages(table_content=table_content)
            description = description_model.predict_messages(messages).content

            table_data.append({
                "source_document": source_document,
                "page_number": page_number,
                "table_content": table_content,
                "description": description
            })

    return table_data

# %%
extracted_table_data_with_summary = extract_table_metadata_with_summary(esg_report_raw_data,
                                                                        esg_report_path,
                                                                        tables_summarizer_prompt)

# %%
extracted_table_data_with_summary
# Out:
# [{'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 1,
#   'table_content': 'OBJECTIVES @ L02-1 Understand routine economic events—transactions—and determine on a company’s financial position and on specific accounts. (p. 44) @ LO2-2 Describe the steps in the accounting cycle. (p. 47) @ LO2-3 = Analyze and record transactions using journal entries. (p. 49) @ LO2-4 Post the effects of journal entries to general ledger accounts and prepare unadjusted trial balance. (p. 54) @ LO2-5 Identify and describe the different types of adjusting journal entries. (p. @ LO2-6 = Record adjusting journal entries in general journal format, post entries, prepare an adjusted trial balance. (p. 58) @ LO2-7 Describe the four basic financial statements. (p. 66) @ LO2-8 = Explain the closing process. (p. 70) @ LO2-9 = Convert from cash-basis net income to accrual-basis net income. (p. 74)',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 2,
#   'table_content': 'Salaries $162,000 Rent 18,000 Supplies 23,000 Utilities 14,000 Advertising 63,000',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 4,
#   'table_content': 'Shareholders’ Equity Paid-in Retained Assets = Liabilities + Capital + Earnings 1. Provided services of $10,000 to +$10,000 +$10,000 customers on account. (Accounts (t Service Revenue) Receivable) . Incurred (but did not pay) utilities +$5,000 -—$5,000 cost of $5,000 for operations in (Utilities (f Utilities Expense) the current period. Payable) . Paid dividends of $2,000 to —$2,000 shareholders. (t Dividends)',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 5,
#   'table_content': 'Assets = Liabilities + Shareholders’ Equity Cash Note Payable Debit | Credit Debit | Credit 40,000 40,000',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 6,
#   'table_content': 'Step 5 Prepare an unadjusted trial balance. At the end Step 6 Record adjusting entries and post to the general of the ‘i ledger accounts. accountin period o Step 7 Prepare an adjusted trial balance. Step 8 Prepare financial statements. At the end of Step 9 Close the temporary accounts to retained earnings.',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 7,
#   'table_content': 'CASH oo eseecsseecstecsseesseecssessseesseesseeessecesessssecssesssnesssessseeesseesseeesseesseeessecssenesseessessseeesneees 40,000 Notes payable vee To record the borrowing of cash and the signing of a note payable. 40,000',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 8,
#   'table_content': 'July 1 60,000 Common stock. 60,000',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 9,
#   'table_content': 'record the borrowing cash and the signing of notes payable.',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 9,
#   'table_content': 'record the payment of year’s rent in advance.',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 9,
#   'table_content': 'record the purchase of office equipment.',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 9,
#   'table_content': 'of',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 9,
#   'table_content': 'To record the purchase of supplies.',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 10,
#   'table_content': 'Accounting July 4-31 To record the 35,000 cash sales Sales revenue 35,000 those sales. Cost of goods sold (expense) 20,000 Inventory 20,000',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 10,
#   'table_content': 'July 9 3.500 , Accounts receivable. Sales revenue... 3,500 Cost Of OOS SOIG wc eeecceceesecesseeseessesstesesssseessesseeseseesesetesesseeneeseeeesetenees 2,000 INVENTOLY oes cesseeseesseeseesseseessessessessesseesuessessesieenessesesseeseesseeetsaeeseesseeseets 2,000',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 10,
#   'table_content': 'Purchases 60,000 Accounts payable ..... 60,000',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 10,
#   'table_content': 'Beginning inventory $ 0 Plus: Purchases 60,000 Less: Ending inventory (38,000) Cost of goods sold $ 22,000',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 10,
#   'table_content': 'Cost of goods sold 22,000 Inventory. 38,000 Purchases.',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 11,
#   'table_content': 'record the collection of in advance.',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 11,
#   'table_content': 'To record the payment of accounts payable.',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 11,
#   'table_content': 'record the payment of salaries for the first half of month.',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 11,
#   'table_content': 'record the collection of cash on account.',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 11,
#   'table_content': 'To record the payment of a cash dividend.',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 12,
#   'table_content': 'Date 2027 General Journal Account Title and Explanation Post Ref. The July 1 Cash Common stock To record the issuance of common stock. Cash Notes payable To record the borrowing of cash and the signing of notes payable. Prepaid rent Cash To record the payment of one year’s rent in advance. Office equipment Cash To record the purchase of office equipment. Inventory Accounts payable To record the purchase of inventory. Supplies Cash To record the purchase of supplies. Cash Sales revenue To record cash sales for the month. Cost of goods sold Inventory To record the cost of inventory sold. Accounts receivable Sales revenue To record a sale on account. Cost of goods sold Inventory To record the cost of inventory sold. Cash Deferred rent revenue To record the collection of rent in advance. Accounts payable Cash To record the payment of accounts payable. Salaries expense Cash To record the payment of salaries for the first half of the month. Cash Accounts receivable To record the collection of cash on account. Dividends Cash To record the payment of a cash dividend. 100 300 100 220',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 13,
#   'table_content': 'Balance Sheet Accounts Cash 100 Prepaid Rent July 1 GJ1 60,000 | 24,000 July1GJ1 July 1 GJ1 24,000 1GJ1 40,000 | 12,000 1GJ1 4-31 GJ1 35,000 2,000 6GJ1 16 GJ1 1,000 | 25,000 20 GJ1 25 GJ1 1,500 5,000 20 GJ1 1,000 30 GJ1 July 31 Bal. 68,500 July 31 Bal. 24,000 Accounts Receivable 110 Inventory 140 July 9 GJ1 3,500 1,500 July 25 GJ1 July 3 GJ1 60,000 | 20,000 July 4-31 2,000 9GJ1 July 31 Bal. 2,000 July 31 Bal. 38,000 Supplies Office equipment July 6 GJ1 2,000 July 1 GJ1 12,000 July 31 Bal. 2,000 July 31 Bal. 12,000 Accounts Payable 210 Notes Payable 220 July 20 GJ1 25,000 | 60,000 July 3 GJ1 40,000 July 1 GJ1 35,000 July 31 Bal. 40,000 July 31 Bal. Deferred Rent Revenue 230 1,000 July 16 GJ1 1,000 July 31 Bal. Common Stock 300 Retained Earnings 310 60,000 July 1 GJ1 60,000 July 31 Bal. oO July 31 Bal. Income Statement Accounts levenue 400 Cost of Goods Sold 35,000 July 4-31 GJ1 July 4-31 GJ1 20,000 3,500 9G)1 9GJ1 2,000 38,500 July31Bal. July 31 Bal. 22,000 Salaries Expense 510 July 20 GJ1 5,000 July 31 Bal. 5,000 Dividends Dividends 600 July 30 GJ1 1,000 July 31 Bal. 1,000',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 14,
#   'table_content': 'DRESS RIGHT CLOTHING CORPORATION Unadjusted Trial Balance July 31, 2027 Account Title Debit Cash $ 68,500 Accounts receivable 2,000 Supplies 2,000 Prepaid rent 24,000 Inventory 38,000 Office equipment 12,000 Accounts payable $ 35,000 Notes payable 40,000 Deferred rent revenue 1,000 Common stock 60,000 Retained earnings 0 Dividends 1,000 Sales revenue 38,500 Cost of goods sold 22,000 Salaries expense 5,000 Totals* $174,500 $174,500',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 15,
#   'table_content': 'EqQUIPMENA wu... eseeeeseceeseesesseeseessessesseeseesseeseesuessesaeeseesseeseesuesnesetssecsseeseesneeneseeenee 20,000 CASH ooeeeeeeseceeseseeseestesseesteseessessesesseesteseeseessesuesneesiesessenssssueeneeaneeeeseeeseesneeeee 20,000',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 15,
#   'table_content': 'Prepaid rent. 6,000 6,000',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 15,
#   'table_content': 'Inventory. 38,000 Accounts payable 38,000',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 15,
#   'table_content': '30,000 Notes payable 30,000',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 15,
#   'table_content': 'Accounts receivable. 40,000 Sales revenue... 40,000 Cost of goods sold 22,000 Inventory. 22,000',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 15,
#   'table_content': '15,000 Accounts receivabl 15,000',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 15,
#   'table_content': 'ACCOUNTS PAYADIC........ceeccescseecssessseeesseesseecsseesseesssecssecssesesseessesssesessesssneesneesseeeseee 20,000 (Sais beeeereneseenresssneresseressseereseeresasenrreassnenanenrnsessnresnsrenaneeereesseenanenresesrereessnreeneerreese™ 20,000',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 16,
#   'table_content': 'i. Receiving cash from customers in advance of services to be provided increases cash and increases deferred revenue (a liability). Cash... 2,000 Deferred revenue... 2,000 j. Paying salaries for the period increases salaries expense and decreases cash. Salaries expense. 7,000 7,000 k. Receiving a bill for utilities for the current period increases both utilities expense and accounts payable. Utilities expense Accounts payable.. 2,000 2,000 1. Lending cash to another entity by accepting a note increases notes receivable and decreases cash. Notes receivable . 20,000 Cash 20,000 m. Paying dividends to shareholders increases dividends and decreases cash. 1,000 1,000 2. Prepare an unadjusted trial balance. Account Title Debit Credit Cash $ 23,000',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 16,
#   'table_content': 'Account Title Debit Credit Cash $ 23,000 Accounts receivable 25,000 Prepaid rent 6,000 Inventory 16,000 Notes receivable 20,000 Equipment 20,000 Accounts payable $ 20,000 Deferred revenue 2,000 Notes payable 30,000 Common stock 50,000 Retained earnings Oo Dividends 1,000 Sales revenue 40,000 Cost of goods sold 22,000 Salaries expense 7,000 Utilities expense 2,000 Totals $142,000 $ 142,000',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 18,
#   'table_content': 'Beg. bal. 0 Purch. 24,000 End. bal. 22,000 2,000 Adj.',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 18,
#   'table_content': 'Beg. bal. 0 Adj. 200 End bal. 200',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 19,
#   'table_content': 'O Beg. bal. 1,000 Received Adj. 250 750 — End bal.',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 19,
#   'table_content': '0 Beg. bal. 250 Adj. 250 End bal.',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 19,
#   'table_content': 'Adj.',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 21,
#   'table_content': 'Beg. bal. 0 Adj. 200 End bal. 200',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 22,
#   'table_content': 'Prepaid Expenses Deferred Revenues | Liability Revenue Accrued Expenses Accrued Revenues | Asset Revenue',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 22,
#   'table_content': 'DRESS RIGHT CLOTHING CORPORATION General Journal 31, 2027 Account Title and Explanation Debit Supplies expense 800 Supplies To record the cost of supplies used during July. Rent expense 2,000 Prepaid rent To record the cost of expired rent for July. Depreciation expense 200 Accumulated depreciation To record depreciation of equipment for July. Deferred rent revenue Rent revenue To record previously deferred rent revenue recognized during July. Salaries expense Salaries payable To record salaries incurred but not yet paid at the end of July. Interest expense Interest payable To record interest incurred but not yet paid at the end of July.',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 23,
#   'table_content': 'Adjusted July 31, 2027 Account Title Debit Cash $ 68,500 Accounts receivable 2,000 Supplies 1,200 Prepaid rent 22,000 Inventory 38,000 Office equipment 12,000 Accumulated depreciation Accounts payable Notes payable Deferred rent revenue Salaries payable Interest payable Common stock Retained earnings Dividends 1,000 Sales revenue Rent revenue Cost of goods sold 22,000 Salaries expense 10,500 Supplies expense 800 Rent expense 2,000 Depreciation expense 200 Interest expense Boo) Totals $180,533 $180,533',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 24,
#   'table_content': 'Interest expense 250 Interest payable 250',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 24,
#   'table_content': 'Depreciation expense ......eccecesecceesesiesseesesneeesesesseesesneenesesesseesesneeeeneeeneene 500 Accumulated depreciation .........ccecccecseecsecsseeessesssessseesseesseesneesseesseessesssneess 500',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 24,
#   'table_content': 'Interest receivable . 100 Interest revenue. 100',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 24,
#   'table_content': 'ReMt CXPeNS.... ee eeeceeseseessesseesneesteseesesseeseesseestessesesseesesneeeteseesesneeseesneesteneesneese 2,000 Prepaid Pent woe eseeseesesseesessesseesteseesseeseessesseestesnsseeeseeseeneeseseeseeeseseeenee 2,000',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 24,
#   'table_content': "Deferred revenue Miscellaneous revenu' 1,250 1,250",
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 25,
#   'table_content': 'Account Title Debit Credit Cash $ 23,000 Accounts receivable 25,000 Prepaid rent 4,000 Inventory 16,000 Interest receivable 100 Notes receivable 20,000 Equipment 20,000 Accumulated depreciation $ 500 Accounts payable 20,000 Deferred revenue 750 Interest payable 250 Notes payable 30,000 Common stock 50,000 Retained earnings Dividends 1,000 Sales revenue 40,000 Interest revenue 100 Miscellaneous revenue 1,250 Cost of goods sold 22,000 Salaries expense 7,000 Utilities expense 2,000 Interest expense 250 Depreciation expense 500 Rent expense 2,000 Totals $142,850 $142,850',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 25,
#   'table_content': 'ooanoDm Assets overstated _Liabilities overstated Income overstated Adjusting Entry (understated) (understated) (understated) . Interest expense $ — $ (250) $ 250 . Depreciation expense 500 _ 500 Interest revenue (100) — (100) . Rent expense 2,000 — 2,000 Miscellaneous revenue — 1,250 (1,250) Net effect $2,400 $1,000 $1,400',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 27,
#   'table_content': 'DRESS RIGHT CLOTHING CORPORATION Balance Sheet July 31, 2027 Assets Current assets: Cash $ 68,500 Accounts receivable 2,000 Supplies 1,200 Inventory 38,000 Prepaid rent 22,000 Total current assets 131,700 Property and equipment: Office equipment Less: Accumulated depreciation 11,800 Total assets $143,500 Liabilities and Shareholders’ Equity Current liabilities: Accounts payable $ 35,000 Salaries payable 5,500 Deferred rent revenue 750 Interest payable B35 Notes payable 10,000 Total current liabilities 51,583 Long-term liabilities: Notes payable 30,000 Shareholders’ equity: Common stock (6,000 shares issued and outstanding) Retained earnings Total shareholders’ equity 61,917 Total liabilities and shareholders’ equity $143,500 *Beginning retained earnings + Net income — Dividends $0 + $2,917 — $1,000 =$1,917',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 30,
#   'table_content': 'CHAPTER 2 Review of the',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 30,
#   'table_content': '0 Beg. Bal. Expenses 35,833 | 38,750 Revenues Dividends 1,000 1,917 End Bal.',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 31,
#   'table_content': 'DRESS RIGHT CLOTHING CORPORATION Post-Closing Trial Balance July 31, 2027 Account Title Debit Cash $ 68,500 Accounts receivable 2,000 Supplies 1,200 Prepaid rent 22,000 Inventory 38,000 Office equipment 12,000 Accumulated depreciation $ 200 Accounts payable 35,000 Notes payable 40,000 Deferred rent revenue 750 Salaries payable 5,500 Interest payable B33) Common stock 60,000 Retained earnings 1,917 Totals $143,700 $143,700',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 31,
#   'table_content': 'For the Month of August 2027 Sales revenue $40,000 Cost of goods sold 22,000 Gross profit 18,000 Operating expenses: Salaries $7,000 Utilities 2,000 Depreciation 500 Rent 2,000 Total operating expenses 11,500 Operating income 6,500 Other income (expense): Interest revenue 100 Miscellaneous revenue 1,250 Interest expense (250) 1,100 Net income $ 7,600',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 32,
#   'table_content': 'Total Common Retained Shareholders’ Stock Earnings Equity Balance at August 1, 2027 $ oO $ Oo $ ° Issue of common stock 50,000 50,000 Net income for August 2027 7,600 7,600 Less: Dividends (1,000) (1,000) Balance at August 31, 2027 $50,000 $6,600 $56,600',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 32,
#   'table_content': 'Net income for August 2027 7,600 7,600 Less: Dividends (1,000) (1,000) Balance at August 31, 2027 $50,000 $6,600 $56,600 WYNDHAM WHOLESALE COMPANY Balance Sheet At August 31, 2027 Assets Current assets: Cash $ 23,000 Accounts receivable 25,000 Inventory 16,000 Interest receivable 100 Notes receivable 20,000 Prepaid rent 4,000 Total current assets 88,100 Property and equipment: Equipment $20,000 Less: Accumulated depreciation 500 19,500 Total assets $107,600 Liabilities and Shareholders’ Equity Current liabilities: Accounts payable $ 20,000 Interest payable 250 Deferred revenue 750 Total current liabilities 21,000 Long-term lial 2 Notes payable 30,000 Shareholders’ equity: Common stock, 5,000 shares issued and outstanding $50,000 Retained earnings 6,600 Total shareholders’ equity 56,600 Total liabilities and shareholders’ equity $107,600',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 32,
#   'table_content': 'USS Sales revenue 40,000 Interest revenue 100 Miscellaneous revenue 1,250 Retained earnings... 41,350 August 31 Retained earnings 33,750 Cost of goods sold 22,000 Salaries expense... 7,000 Utilities expense 2,000 Depreciation expense 500 Rent expense 2,000 Interest expense 250 August 31 Retained earnings 1,000 Dividends...... 1,000',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 33,
#   'table_content': 'Post-Closing Trial Balance Account Title Debit Credit Cash $ 23,000 Accounts receivable 25,000 Prepaid rent 4,000 Inventory 16,000 Interest receivable 100 Notes receivable 20,000 Equipment 20,000 Accumulated depreciation $ 500 Accounts payable 20,000 Interest payable 250 Deferred revenue 750 Notes payable 30,000 Common stock 50,000 Retained earnings 6,600 Totals $108,100 $108,100',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 33,
#   'table_content': 'Balance, beginning of year $ 5,000 Plus: Cash paid 20,000 Less: Insurance expense ? Balance, end of year $ 3,000',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 34,
#   'table_content': 'Salaries Payable Balance, beginning of year $ 12,000 Plus: Salaries expense ? Less: Cash paid (150,000) Balance, end of year $ 18,000',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 34,
#   'table_content': 'Salaries Payable Salaries Expense 12,000 Beg. balance Cash paid 150,000 ? Salaries expense ? 18,000 End. balance',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 34,
#   'table_content': 'Accounts Receivable Sales Revenue Beg. balance 45,000 Sales on account ? ? Sales on account 220,000 Cash collections End. balance 33,000',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 35,
#   'table_content': 'January 1, 2027 December 31, 2027 Accounts receivable $ 16,000 $ 25,000 Prepaid expenses 7,000 4,000 Accrued liabilities 2,100 1,400 (for operating expenses) Deferred revenues 3,000 4,200 Accrual net income is $68,500, determined as follows: Cash-basis net income $63,000 Add: Increase in accounts receivable 9,000 Deduct: Decrease in prepaid expenses (3,000) Add: Decrease in accrued liabilities 700 Deduct: Increase in deferred revenues (1,200) Accrual-basis net income $ 68,500',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 35,
#   'table_content': 'Converting Cash-Basis Income to Accrual-Basis Income Increases Decreases Assets Add Deduct Liabilities Deduct Add',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 39,
#   'table_content': 'Salaries Expense Salaries Payable Bal. July 31 10,500 5,500 Bal. July 31 Cash payment 5,500 0 Balance',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 39,
#   'table_content': 'Salaries Expense Salaries Payable Bal. July 31 10,500 5,500 Bal. July 31 5,500 (Reversing entry) 5,500 Cash payment 5,500 Balance 10,500 0 Balance',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 40,
#   'table_content': 'Supplies Supplies Expense (Cash payment) 2,000 800 (Adjusting entry) 800 Bal. July 31 1,200 Bal. July 31 800',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 40,
#   'table_content': 'Supplies Supplies Expense Cash payment 2,000 1,200 (Adjusting entry) 1,200 Bal. July 31 1,200 Bal. July 31 800',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 41,
#   'table_content': 'Accounts Receivable 110 Sales Revenue 400 July 31 Balance 2,000 Aug. 31 SJ1 3,295 3,295 Aug. 31 SJ1',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 42,
#   'table_content': 'Page 1 Accounts Cr. Sales Receivable Sales Revenue (400) Subsidiary Invoice Dr. Accounts Account No. Customer Name No. Receivable (110) 801 Leland High School 1,500 812 Mr. John Smith 813 Greystone School 803 Ms. Barbara Jones 805 Hart Middle School',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 47,
# ...
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 50,
#   'table_content': 'Sales revenue $492,000 Salaries expense 80,000 Interest revenue 6,000 Advertising expense 10,000 Gain on sale of investments 8,000 Cost of goods sold $284,000 Insurance expense 12,000 Interest expense 4,000 Income tax expense 30,000 Depreciation expense 20,000',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 50,
#   'table_content': 'accounting; adjusting entries LO2-5, LO2-6, LO2-9 Nov. 30 Dec. 31 Dr. Cr. Dr. Cr. Supplies $1,500 $3,000 Prepaid insurance 6,000 4,500 Salaries payable $10,000 $15,000 Deferred rent revenue 2,000 1,000',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 51,
#   'table_content': 'Cash collected for: Services to customers $320,000 Cash paid for: Salaries $180,000 Supplies 25,000 Rent 12,000 Insurance 6,000 Miscellaneous 20,000 243,000 Net operating cash flow $ 77,000',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 52,
#   'table_content': 'January 1, 2027 December 31, 2027 Accounts receivable $32,000 $27,000 Prepaid insurance 0 2,000 Supplies 1,000 1,500 Accrued liabilities 2,400 3,400 (for miscellaneous expenses)',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 52,
#   'table_content': 'January 1, 2027 December 31, 2027 Accounts receivable $62,000 $55,000 Prepaid insurance 4,500 6,000 Prepaid rent 9,200 8,200 Deferred service revenue 9,200 11,000 Accrued liabilities 12,200 15,600 (for various expenses)',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 52,
#   'table_content': 'Account Title Debit Credit Cash $ 20,000 Accounts receivable 35,000 Prepaid rent 5,000 Inventory 50,000 Equipment 100,000 Accumulated depreciation $ 30,000 Accounts payable 25,000 Salaries payable oO Common stock 100,000 Retained earnings 29,000 Sales revenue 323,000 Cost of goods sold 180,000 Salaries expense 71,000 Rent expense 30,000 Depreciation expense 0 Utilities expense 12,000 Advertising expense 4,000 Totals $507,000 $507,000',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 53,
#   'table_content': 'Transaction 1. Purchased inventory on account. . Collected an account receivable. . Borrowed $20,000 and signed a note. . Recorded depreciation expense. . Purchased equipment for cash. . Sold inventory for cash (the sale only, not the cost of the inventory). . Sold inventory on credit (the sale only, not the cost of the inventory). . Recorded accrued salaries payable. . Paid employee salaries. 10. Sold equipment for cash. 11. Sold equipment on credit. 12. Paid a cash dividend to shareholders. 13. Issued common stock in exchange for cash. 14. Paid accounts payable. ONOORWN © - ° £ 5 3 2',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 53,
#   'table_content': 'Transaction Journal . Paid interest on a loan. . Recorded depreciation expense. . Purchased office equipment for cash. . Purchased inventory on account. Sold inventory on credit (the sale only, not the cost of the inventory). . Sold inventory for cash (the sale only, not the cost of the inventory). . Paid rent. . Recorded accrued interest payable. . Paid advertising bill. . Sold a factory building in exchange for a note receivable. . Collected cash from customers on account. . Paid employee salaries. . Collected interest on the note receivable. ON OAOAWN= N=O00 w',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 54,
#   'table_content': 'Account Title Debit Credit Cash $ 5,000 Accounts receivable 2,000 Inventory 5,000 Equipment 11,000 Accumulated depreciation $ 3,500 Accounts payable 3,000 Accrued liabilities 0 Common stock 10,000 Retained earnings 6,500 Dividends oO Sales revenue 0 Cost of goods sold 0 Salaries expense 0 Rent expense 0 Advertising expense 0 oO Totals $23,000 $ 23,000',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 55,
#   'table_content': 'Account Title Debit Credit Cash $ 30,000 Accounts receivable 40,000 Supplies 1,500 Inventory 60,000 Notes receivable 20,000 Interest receivable oO Prepaid rent 2,000 Prepaid insurance 6,000 Office equipment 80,000 Accumulated depreciation $ 30,000 Accounts payable 31,000 Salaries payable 0 Notes payable 50,000 Interest payable 0 Deferred sales revenue 2,000 Common stock 60,000 Retained earnings 28,500 Dividends 4,000 Sales revenue 146,000 Interest revenue 0 Cost of goods sold 70,000 Salaries expense 18,900 Rent expense 11,000 Depreciation expense 0 Interest expense 0 Supplies expense 1,100 Insurance expense 0 Advertising expense 3,000 Totals $347,500 $347,500',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 56,
#   'table_content': 'Unadjusted Adjusted Account Title Debit Credit Debit Credit Cash $ 50,000 $ 50,000 Accounts receivable 35,000 35,000 Prepaid rent 2,000 1,200 Supplies 1,500 800 Inventory 60,000 60,000 Notes receivable 30,000 30,000 Interest receivable 0 1,500 Office equipment 45,000 45,000 Accumulated depreciation $ 15,000 $ 21,500 Accounts payable 34,000 34,000 Salaries payable oO 6,200 Notes payable 50,000 50,000 Interest payable oO 2,500 Deferred rent revenue 2,000 0 Common stock 46,000 46,000 Retained earnings 20,000 20,000 Sales revenue 244,000 244,000 Rent revenue 4,000 6,000 Interest revenue oO 1,500 Cost of goods sold 126,000 126,000 Salaries expense 45,000 51,200 Rent expense 11,000 11,800 Depreciation expense ° 6,500 Supplies expense 1,100 1,800 Interest expense 5,400 7,900 Advertising expense 3,000 3,000 Totals $415,000 $415,000 $431,700 $431,700',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 56,
#   'table_content': 'Account Title Debit Credit Cash $30,000 Accounts receivable 15,000 Equipment 20,000 Accumulated depreciation $ 6,000 Salaries payable 9,000 Common stock 40,500 Retained earnings 9,500 Total $65,000 $65,000',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 57,
#   'table_content': 'Account Title Debit Cash $ 23,300 Accounts receivable 32,500 Supplies 2,000 Prepaid rent 14,000 Inventory 65,000 Office equipment 75,000 Accumulated depreciation $ Accounts payable Salaries payable Notes payable Common stock Retained earnings Dividends 6,000 Sales revenue Cost of goods sold 95,000 Interest expense 0 Salaries expense 32,350 Rent expense 0 Supplies expense 0 Utilities expense 6,000 Totals $351,150',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 58,
#   'table_content': '. . . Account Title Debit Credit Cash $ 8,000 Accounts receivable 9,000 Prepaid insurance 3,000 Land 200,000 Buildings 50,000 Accumulated depreciation—buildings $ 20,000 Office equipment 100,000 Accumulated depreciation—office equipment 40,000 Accounts payable 35,050 Salaries payable 0 Deferred rent revenue 7,500 Common stock 200,000 Retained earnings 56,450 Service revenue 90,000 Interest revenue 3,000 Rent revenue 0 Salaries expense 37,000 Depreciation expense 0 Insurance expense 0 Utilities expense 30,000 Maintenance expense 15,000 Totals $452,000 $452,000',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 58,
#   'table_content': 'Issue of common stock $ 50,000 Collections from customers 320,000 Borrowed from local bank on April 1, note signed requiring 40,000 principal and interest at 12% to be paid on March 31, 2028 — Total cash collections $410,000 Cash payments: —_—— Purchase of inventory $220,000 Payment of salaries 80,000 Purchase of office equipment 30,000 Payment of rent on building 14,000 Miscellaneous expense 10,000 Total cash payments $354,000',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 59,
#   'table_content': 'Nov. 30 Dec. 31 Debit Credit Debit Credit Accounts receivable $10,000 $3,000 Prepaid insurance 5,000 7,500 Inventory 7,000 6,000 Accounts payable $12,000 $15,000 Salaries payable 5,000 3,000',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 59,
#   'table_content': 'From customers $675,000 Interest on note 4,000 Loan from a local bank 100,000 Total cash collections $779,000 payments: Purchase of inventory $390,000 Annual insurance payment 6,000 Payment of salaries 210,000 Dividends paid to shareholders 10,000 Annual rent payment 24,000 Total cash payments $640,000',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 60,
#   'table_content': '12/31/2026 12/31/2027 Cash $ 25,000 $ 164,000 Accounts receivable 62,000 92,000 Inventory 80,000 62,000 Prepaid insurance 2,500 ? Prepaid rent 11,000 ? Interest receivable 3,000 ? Notes receivable 50,000 50,000 Equipment 100,000 100,000 Accumulated depreciation (40,000) (50,000) Accounts payable (for inventory) 110,000 122,000 Salaries payable 20,000 24,000 Notes payable 0 100,000 Interest payable oO ?',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 62,
#   'table_content': 'earnings; McDonald’s and Dave & Buster’s Entertainment @ 102-8 Real World Financials ($ in millions) McDonald’s Dave & Buster’s Entertainment Retained Retained NetIncome Dividends Earnings NetIncome Dividends Earnings 2019 $52,930.5 $433.5 2020 $4,730.5 $3,752.9 $(207.0) $0.0 2021 $7,545.2 $3,918.6 $ 108.6 $0.0 2022 $6,177.4 $4,168.2 $137.1 $0.0',
#   'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"}]

# %%
first_table_details = extracted_table_data_with_summary[0]

# Extract the transcription from the first item
first_description = first_table_details

first_description
# Out:
# {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#  'page_number': 1,
#  'table_content': 'OBJECTIVES @ L02-1 Understand routine economic events—transactions—and determine on a company’s financial position and on specific accounts. (p. 44) @ LO2-2 Describe the steps in the accounting cycle. (p. 47) @ LO2-3 = Analyze and record transactions using journal entries. (p. 49) @ LO2-4 Post the effects of journal entries to general ledger accounts and prepare unadjusted trial balance. (p. 54) @ LO2-5 Identify and describe the different types of adjusting journal entries. (p. @ LO2-6 = Record adjusting journal entries in general journal format, post entries, prepare an adjusted trial balance. (p. 58) @ LO2-7 Describe the four basic financial statements. (p. 66) @ LO2-8 = Explain the closing process. (p. 70) @ LO2-9 = Convert from cash-basis net income to accrual-basis net income. (p. 74)',
#  'description': "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"}

# %%
first_description['description']
# Out:
# "I would be happy to help you summarize the table and create multiple-choice questions (MCQs) based on its content. However, I need to see the table you're referring to in order to assist you effectively. Please provide the details or data from the table, and I'll help you with the summary and questions!"

# %%
from PIL import Image as PILImage
import base64

# %%
images_summarizer_prompt = """

Extract the main info like tables sentences from the image
Image: {image_element}

Limit your description to 3-4 sentences, ensuring it's precise and informative """

# %%
def extract_image_metadata_with_summary(esg_report_raw_data,
                                        esg_report_path,
                                        images_summarizer_prompt):

    image_data = []


    prompt = ChatPromptTemplate.from_template(images_summarizer_prompt)


    description_model = ChatOpenAI( openai_api_base="https://llmfoundry.straive.com/openai/v1/",
        openai_api_key=f'{os.environ["LLM_FOUNDARY_API"]}:my-test-project',
        model="gpt-4o-mini")

    for element in esg_report_raw_data:
        if "Image" in str(type(element)):
            page_number = element.metadata.page_number if hasattr(element.metadata, 'page_number') else None
            image_path = element.metadata.image_path if hasattr(element.metadata, 'image_path') else None

            if image_path and os.path.exists(image_path):

                messages = prompt.format_messages(image_element=image_path)

                description = description_model.predict_messages(messages).content


                with open(image_path, "rb") as image_file:
                    encoded_string = base64.b64encode(image_file.read()).decode('utf-8')

                image_data.append({
                    "source_document": esg_report_path,
                    "page_number": page_number,
                    "image_path": image_path,
                    "description": description,
                    "base64_encoding": encoded_string
                })
            else:
                print(f"Warning: Image file not found or path not available for image on page {page_number}")

    return image_data

# %%
extracted_image_data = extract_image_metadata_with_summary(esg_report_raw_data,
                                                           esg_report_path,
                                                           images_summarizer_prompt)

# %%
extracted_image_data
# Out:
# [{'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 2,
#   'image_path': './data/images/figure-2-1.jpg',
#   'description': "I'm unable to view images directly. However, if you can describe the content of the image or share specific details, I can help you extract the main information or summarize it.",
#   'base64_encoding': '...'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 3,
#   'image_path': './data/images/figure-3-2.jpg',
#   'description': "I'm unable to view images directly. However, if you can describe the content of the image or provide the text, I'd be happy to help you extract and summarize the main information!",
#   'base64_encoding': '...'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 4,
#   'image_path': './data/images/figure-4-3.jpg',
#   'description': "I'm sorry, but I can't view images directly. However, if you describe the contents or share specific details from the image, I can help you extract and summarize the information.",
#   'base64_encoding': '...'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 4,
#   'image_path': './data/images/figure-4-4.jpg',
#   'description': "I'm unable to view images directly. However, if you can describe the content or key elements of the image, I can help summarize or extract information based on your description.",
#   'base64_encoding': '...'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 5,
#   'image_path': './data/images/figure-5-5.jpg',
#   'description': "I'm unable to view images directly. However, if you provide me with a description of the content or key details from the image, I can help you summarize or extract important information from it.",
#   'base64_encoding': '...'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 35,
#   'image_path': './data/images/figure-35-6.jpg',
#   'description': "I'm unable to view images directly. However, if you provide a description or the text from the image, I can help you extract and summarize the main information.",
#   'base64_encoding': '...'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 37,
#   'image_path': './data/images/figure-37-7.jpg',
#   'description': "I'm unable to view images directly. However, if you can describe the content or provide key details from the image, I can help you summarize or extract information from it.",
#   'base64_encoding': '...'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 38,
#   'image_path': './data/images/figure-38-8.jpg',
#   'description': "I'm unable to view images directly. However, you can provide a description of the image or share the text it contains, and I can help summarize or extract information from that.",
#   'base64_encoding': '...'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 42,
#   'image_path': './data/images/figure-42-9.jpg',
#   'description': "I'm unable to view images directly. However, if you can describe the contents of the image or provide the text, I would be happy to help you extract and summarize the main information!",
#   'base64_encoding': '...'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 56,
#   'image_path': './data/images/figure-56-10.jpg',
#   'description': "I'm unable to view images directly. However, if you provide a description or key details from the image, I can help summarize or extract information based on that text.",
#   'base64_encoding': '...'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 58,
#   'image_path': './data/images/figure-58-11.jpg',
#   'description': "I'm unable to view images directly. If you can describe the contents of the image or provide the text you want help with, I'd be happy to assist you in summarizing or extracting the main information!",
#   'base64_encoding': '...'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 59,
#   'image_path': './data/images/figure-59-12.jpg',
#   'description': "I'm sorry, but I cannot view or access images directly. If you can describe the content of the image or provide specific text, I would be happy to help summarize or extract information from it!",
#   'base64_encoding': '...'},
#  {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#   'page_number': 60,
#   'image_path': './data/images/figure-60-13.jpg',
#   'description': "I'm unable to view images directly. However, if you describe the content or share the main details from the image, I can help you extract and summarize the information effectively.",
#   'base64_encoding': '...'}]

# %%
sixth_image_details = extracted_image_data[5]

sixth_image_details
# Out:
# {'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf',
#  'page_number': 35,
#  'image_path': './data/images/figure-35-6.jpg',
#  'description': "I'm unable to view images directly. However, if you provide me with a description or details about the image, I can help you formulate a precise and informative summary based on that information.",
#  'base64_encoding': '...'}

# %%
sixth_image_details['description']
# Out:
# "I'm unable to view images directly. However, if you provide me with a description or details about the image, I can help you formulate a precise and informative summary based on that information."

# %%
# !pip -qqq install weaviate-client
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.4/325.4 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.8/223.8 kB 13.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 53.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 16.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.17.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.29.2 which is incompatible.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 5.29.2 which is incompatible.

# %%
import weaviate

# %%
URL = userdata.get('WCS_URL')
APIKEY = userdata.get('WCS_API_KEY')

# %%
URL
# Out:
# 'https://zogyaxlqlmjne69qniklq.c0.asia-southeast1.gcp.weaviate.cloud'

# %%
client = weaviate.connect_to_wcs(
    cluster_url=URL,
    auth_credentials=weaviate.auth.AuthApiKey(APIKEY),
    headers = {
        "X-OpenAI-Api-Key":LLM_FOUNDARY_API
    }
)

# %%
client

# %%
import weaviate.classes.config as wc

properties = [
    wc.Property(name="source_document", data_type=wc.DataType.TEXT, skip_vectorization=True),
    wc.Property(name="page_number", data_type=wc.DataType.INT, skip_vectorization=True),
    wc.Property(name="paragraph_number", data_type=wc.DataType.INT, skip_vectorization=True),
    wc.Property(name="text", data_type=wc.DataType.TEXT),
    wc.Property(name="image_path", data_type=wc.DataType.TEXT, skip_vectorization=True),
    wc.Property(name="description", data_type=wc.DataType.TEXT),
    wc.Property(name="base64_encoding", data_type=wc.DataType.BLOB, skip_vectorization=True),
    wc.Property(name="table_content", data_type=wc.DataType.TEXT),
    wc.Property(name="url", data_type=wc.DataType.TEXT, skip_vectorization=True),
    wc.Property(name="audio_path", data_type=wc.DataType.TEXT, skip_vectorization=True),
    wc.Property(name="transcription", data_type=wc.DataType.TEXT),
    wc.Property(name="content_type", data_type=wc.DataType.TEXT, skip_vectorization=True),
]

# %%
client.collections.create(
    name="RAGLLMDocuments",
    properties=properties,
    vectorizer_config=None
)

# %%
from weaviate.util import generate_uuid5
from tqdm import tqdm
from openai import OpenAI
OPENAI_API_KEY = userdata.get('LLM_FOUNDARY_API')
openai_client = OpenAI(api_key=LLM_FOUNDARY_API)

# %%
from langchain_openai import OpenAIEmbeddings

# %%
def get_embedding(text):
    response =OpenAIEmbeddings(
    openai_api_base="https://llmfoundry.straive.com/openai/v1/",
    openai_api_key=f'{os.environ["LLM_FOUNDARY_API"]}:my-test-project',
    model="text-embedding-3-small",
)

    return response.embed_query(text)

# Ingestion functions
def ingest_audio_data(collection, audio_data):
    with collection.batch.dynamic() as batch:
        for audio in tqdm(audio_data, desc="Ingesting audio data"):
            vector = get_embedding(audio['transcription'])
            audio_obj = {
                "url": audio['url'],
                "audio_path": audio['audio_path'],
                "transcription": audio['transcription'],
                "content_type": "audio"
            }
            batch.add_object(
                properties=audio_obj,
                uuid=generate_uuid5(audio['url']),
                vector=vector
            )

def ingest_text_data(collection, text_data):
    with collection.batch.dynamic() as batch:
        for text in tqdm(text_data, desc="Ingesting text data"):
            vector = get_embedding(text['text'])
            text_obj = {
                "source_document": text['source_document'],
                "page_number": text['page_number'],
                "paragraph_number": text['paragraph_number'],
                "text": text['text'],
                "content_type": "text"
            }
            batch.add_object(
                properties=text_obj,
                uuid=generate_uuid5(f"{text['source_document']}_{text['page_number']}_{text['paragraph_number']}"),
                vector=vector
            )

def ingest_image_data(collection, image_data):
    with collection.batch.dynamic() as batch:
        for image in tqdm(image_data, desc="Ingesting image data"):
            vector = get_embedding(image['description'])
            image_obj = {
                "source_document": image['source_document'],
                "page_number": image['page_number'],
                "image_path": image['image_path'],
                "description": image['description'],
                "base64_encoding": image['base64_encoding'],
                "content_type": "image"
            }
            batch.add_object(
                properties=image_obj,
                uuid=generate_uuid5(f"{image['source_document']}_{image['page_number']}_{image['image_path']}"),
                vector=vector
            )

def ingest_table_data(collection, table_data):
    with collection.batch.dynamic() as batch:
        for table in tqdm(table_data, desc="Ingesting table data"):
            vector = get_embedding(table['description'])
            table_obj = {
                "source_document": table['source_document'],
                "page_number": table['page_number'],
                "table_content": table['table_content'],
                "description": table['description'],
                "content_type": "table"
            }
            batch.add_object(
                properties=table_obj,
                uuid=generate_uuid5(f"{table['source_document']}_{table['page_number']}"),
                vector=vector
            )

def ingest_all_data(collection_name, text_data, image_data, table_data):

    collection = client.collections.get(collection_name)


    ingest_text_data(collection, text_data)
    ingest_image_data(collection, image_data)
    ingest_table_data(collection, table_data)

    if len(collection.batch.failed_objects) > 0:
        print(f"Failed to import {len(collection.batch.failed_objects)} objects")
    else:
        print("All objects imported successfully")

# %%
import weaviate

URL = userdata.get('WCS_URL')
APIKEY = userdata.get('WCS_API_KEY')
LLM_FOUNDARY_API = userdata.get('LLM_FOUNDARY_API') #Get the key

client = weaviate.connect_to_wcs(
    cluster_url=URL,
    auth_credentials=weaviate.auth.AuthApiKey(APIKEY),
    headers = {
        "X-OpenAI-Api-Key":LLM_FOUNDARY_API
    }
)

# %%
ingest_all_data(collection_name="RAGLLMDocuments",

                text_data=extracted_data,
                image_data=extracted_image_data,
                table_data=extracted_table_data_with_summary
            )
# Out:
# Ingesting text data: 100%|██████████| 509/509 [05:56<00:00,  1.43it/s]
# Ingesting image data: 100%|██████████| 13/13 [00:13<00:00,  1.03s/it]
# Ingesting table data: 100%|██████████| 96/96 [02:02<00:00,  1.27s/it]
# All objects imported successfully

# %%
collection = client.collections.get("RAGLLMDocuments")

# %%
try:
    first_item = next(collection.iterator(include_vector=True))
    print(first_item.properties)
    print(first_item.vector)
except StopIteration:
    print("The collection is empty.")
# Out:
# {'image_path': None, 'description': None, 'transcription': None, 'text': 'A worksheet often is used to organize the accounting information needed to prepare adjusting and closing entries and the financial statements. It is an informal tool only and is not part of the accounting system. There are many different ways to design and use worksheets. We will illustrate a representative method using the financial information for the Dress Right Clothing Corporation presented in the chapter. Software, such as Excel, facilitates the use of worksheets. Illustration 2A—1 presents the completed worksheet. The worksheet is utilized in con- junction with step 5 in the accounting cycle, preparation of an unadjusted trial balance.', 'source_document': '/content/spi24360_ch02_042-103_CS_pf_IACPs.pdf', 'page_number': 37, 'url': None, 'content_type': 'text', 'paragraph_number': 2, 'audio_path': None, 'table_content': None}
# {'default': [0.01903069205582142, 0.012030115351080894, 0.016719821840524673, 0.010614141821861267, 0.01448824629187584, -0.002871595323085785, 0.010138374753296375, 0.008903644979000092, 0.0080710519105196, 0.022179817780852318, 0.022961435839533806, -0.04587756097316742, 0.018486957997083664, -0.03402869030833244, 0.041278477758169174, 0.03649814799427986, 0.01696903258562088, 0.0004449698608368635, -0.030811594799160957, -0.00191439688205719, 0.02139819972217083, 0.026869524270296097, -0.04644395038485527, 0.03343964368104935, 0.024037575349211693, -0.00717049278318882, -0.019993552938103676, -0.010721755214035511, -0.013151567429304123, -0.012902355752885342, -0.004179955460131168, -0.020356042310595512, 0.014307001605629921, 0.030063960701227188, 0.0291350819170475, 0.029497571289539337, -0.006694725248962641, 0.042932335287332535, 0.014748785644769669, -0.009628623723983765, -0.008631777949631214, -0.0114297429099679, 0.011871526949107647, 0.002649287460371852, -0.004191283136606216, 0.05392029136419296, -0.020469320937991142, -0.009662606753408909, 0.03806138411164284, -0.033960722386837006, -0.01490737497806549, 0.03432321175932884, 0.06130601465702057, -0.05867796391248703, -0.020899776369333267, -0.003494624048471451, -0.05632178485393524, 0.012437916360795498, -0.0014669491210952401, 0.002745573641732335, 0.0271413903683424, 0.042411256581544876, -0.005145649891346693, -0.0009040994336828589, -0.04703299328684807, 0.01308360043913126, -0.03599972277879715, 0.09066765010356903, -0.014556213282048702, -0.019347868859767914, -0.010608477517962456, 0.007646259851753712, 0.0012963243061676621, 0.0022924619261175394, 0.014091773889958858, -0.011735592968761921, -0.008903644979000092, -0.0058677964843809605, 0.014839407987892628, 0.003681532572954893, 0.053739048540592194, -0.027005458250641823, -0.010517855174839497, 0.01734285056591034, 0.025850022211670876, -0.013842562213540077, -0.009260470047593117, 0.03511615842580795, -0.04336278885602951, -0.050884444266557693, -0.04451822489500046, 0.04907199740409851, -0.013072272762656212, 0.013649989850819111, 0.029746783897280693, 0.00966827105730772, -0.012925011105835438, -0.013717956840991974, -0.01810181327164173, -0.03108346275985241, -0.0002807168639265001, 0.04472212493419647, -0.0105688301846385, -0.016357332468032837, 0.03726843744516373, 0.023561809211969376, -0.006881633773446083, -0.050929754972457886, -0.05478120595216751, 4.323145913076587e-05, -0.06126070022583008, -0.0025912325363606215, 0.005964082665741444, -0.015077291987836361, 0.034640390425920486, 0.03593175858259201, 0.009889163076877594, -0.022089194506406784, 0.0005897532100789249, -0.07181820273399353, 0.0072158039547502995, 0.018215090036392212, 0.019279902800917625, -0.026756245642900467, 0.012539866380393505, 0.01922326348721981, -0.052878133952617645, 0.041799552738666534, 0.0419807992875576, -0.006207630503922701, 0.020288076251745224, 0.009107545018196106, 0.03640752658247948, -0.033167775720357895, -0.02594064548611641, -0.0055562821216881275, 0.045628346502780914, 0.05709207430481911, -0.025396911427378654, 0.001792623195797205, 0.057454563677310944, 0.03124205209314823, 0.046308014541864395, 0.006439850199967623, -0.06266535073518753, 0.014023806899785995, 0.04757672920823097, 0.008235305547714233, -0.03683798015117645, -0.0457189716398716, -0.018033845350146294, 0.03180843964219093, 0.028024958446621895, 0.00015301369421649724, 0.01701434515416622, 0.021726705133914948, -0.02444537542760372, 0.01749011129140854, 0.029724126681685448, -0.000793653482105583, 0.01768268458545208, 0.0019497963367030025, -0.009028250351548195, 0.017784634605050087, -0.005261759739369154, -0.04551507160067558, -0.015756959095597267, -0.0018478462006896734, -0.05863265320658684, 0.023335251957178116, -0.030585039407014847, -0.003978887107223272, 0.01559837069362402, -0.016040153801441193, -0.016753805801272392, 0.003041512332856655, -0.03078893944621086, -9.841020073508844e-05, -0.00822397693991661, -0.05518900603 ...

# %%
import weaviate.classes.query as wq

# %%
def search_multimodal(query: str, limit: int = 3):
    query_vector = get_embedding(query)

    esg_documents = client.collections.get("RAGLLMDocuments")

    response = esg_documents.query.near_vector(
        near_vector=query_vector,
        limit=limit,
        return_metadata=wq.MetadataQuery(distance=True),
        return_properties=[
            "content_type", "url", "audio_path", "transcription",
            "source_document", "page_number", "paragraph_number", "text",
            "image_path", "description", "table_content"
        ]
    )

    return response.objects

# %%
def search_and_print_results(query, limit=3):

    search_results = search_multimodal(query, limit)

    print(f"Search Results for query: '{query}'")
    for item in search_results:
        print(f"Type: {item.properties['content_type']}")
        if item.properties['content_type'] == 'audio':
            print(f"URL: {item.properties['url']}")
            print(f"Transcription: {item.properties['transcription'][:100]}...")
        elif item.properties['content_type'] == 'text':
            print(f"Source: {item.properties['source_document']}, Page: {item.properties['page_number']}")
            print(f"Paragraph {item.properties['paragraph_number']}")
            print(f"Text: {item.properties['text'][:100]}...")
        elif item.properties['content_type'] == 'image':
            print(f"Source: {item.properties['source_document']}, Page: {item.properties['page_number']}")
            print(f"Description: {item.properties['description']}")
        elif item.properties['content_type'] == 'table':
            print(f"Source: {item.properties['source_document']}, Page: {item.properties['page_number']}")
            print(f"Description: {item.properties['description']}")
        print(f"Distance to query: {item.metadata.distance:.3f}")
        print("---")

# %%
query = '''
you are an accounts teacher generating questions for mcq
compile all the information to provide questions for  each topic 20 questions mcq questions,fill in the blanks,scenario based,calculation based with tough mcq options with distractors questions can be given related to table and descriptive also show the question example table
'''
search_and_print_results(query)
# Out:
# Search Results for query: '
# you are an accounts teacher generating questions for mcq
# compile all the information to provide questions for  each topic 20 questions mcq questions,fill in the blanks,scenario based,calculation based with tough mcq options with distractors questions can be given related to table and descriptive also show the question example table
# '
# Type: table
# Source: /content/spi24360_ch02_042-103_CS_pf_IACPs.pdf, Page: 15
# Description: It seems the text you've provided is garbled and difficult to interpret. However, I can help create multiple-choice questions based on the assumption that you are referring to a table or dataset related to accounts payable.
#
# Assuming the table includes typical elements of accounts payable such as amounts, vendors, due dates, and payment statuses, here are some sample multiple-choice questions (MCQs):
#
# ### Sample MCQs:
#
# 1. **What is the total amount listed in the accounts payable section?**
#    - A) $10,000
#    - B) $15,000
#    - C) $20,000
#    - D) $25,000
#    **Answer:** C) $20,000
#
# 2. **If a vendor has an amount due of $20,000, what is the primary concern for the accounts payable department?**
#    - A) Ensuring payment is made before the due date
#    - B) Increasing the amount due
#    - C) Reducing vendor relationships
#    - D) Ignoring the payment
#    **Answer:** A) Ensuring payment is made before the due date
#
# 3. **In managing accounts payable, which of the following is NOT typically a key factor?**
#    - A) Payment terms
#    - B) Cash flow management
#    - C) Employee satisfaction
#    - D) Vendor relationships
#    **Answer:** C) Employee satisfaction
#
# 4. **What is the primary purpose of accounts payable?**
#    - A) To track employee salaries
#    - B) To manage incoming revenue
#    - C) To record and manage obligations to pay suppliers
#    - D) To allocate budget for marketing
#    **Answer:** C) To record and manage obligations to pay suppliers
#
# 5. **Which of the following actions would be considered best practice in accounts payable management?**
#    - A) Paying invoices only when reminded by vendors
#    - B) Setting up a system for early payment discounts
#    - C) Ignoring discrepancies in invoices
#    - D) Delaying payments to improve cash flow
#    **Answer:** B) Setting up a system for early payment discounts
#
# If you can provide more context or clarify the information in the table, I can tailor the questions and answers more specifically to that content.
# Distance to query: 0.468
# ---
# Type: table
# Source: /content/spi24360_ch02_042-103_CS_pf_IACPs.pdf, Page: 19
# Description: It seems like you're referring to a specific table labeled "Adj." but I don't have the content of that table. To assist you effectively, please provide the data or information contained in the table. Once I have that, I can help summarize it and create multiple-choice questions based on it.
# Distance to query: 0.473
# ---
# Type: table
# Source: /content/spi24360_ch02_042-103_CS_pf_IACPs.pdf, Page: 41
# Description: To create multiple-choice questions (MCQs) based on the provided table information, let's first summarize the key points from the table:
#
# ### Summary of the Table
# 1. **Accounts Receivable**:
#    - Balance as of July 31 is 2,000.
#    - There is an entry on August 31 (SJ1) with an amount of 3,295.
#
# 2. **Sales Revenue**:
#    - Total Sales Revenue recorded is 400.
#
# 3. **Date Entries**:
#    - The entries are dated July 31 for the balance and August 31 for the journal entry SJ1.
#
# ### Multiple-Choice Questions (MCQs)
#
# **Question 1:** What was the balance of Accounts Receivable on July 31?
# - A) 3,295
# - B) 400
# - C) 2,000
# - D) 0
# **Correct Answer:** C) 2,000
#
# ---
#
# **Question 2:** What is the amount recorded for Sales Revenue?
# - A) 2,000
# - B) 400
# - C) 3,295
# - D) 1,500
# **Correct Answer:** B) 400
#
# ---
#
# **Question 3:** On which date was the journal entry SJ1 recorded?
# - A) July 31
# - B) August 1
# - C) August 31
# - D) September 1
# **Correct Answer:** C) August 31
#
# ---
#
# **Question 4:** What is the total increase in Accounts Receivable from July 31 to the August 31 entry?
# - A) 1,295
# - B) 3,295
# - C) 1,000
# - D) 5,295
# **Correct Answer:** A) 1,295 (3,295 - 2,000)
#
# ---
#
# **Question 5:** Which of the following amounts represents the difference between Accounts Receivable and Sales Revenue?
# - A) 1,600
# - B) 1,200
# - C) 1,800
# - D) 2,000
# **Correct Answer:** D) 2,000 (2,000 - 400)
#
# These questions cover the key elements of the table while testing comprehension of the data presented.
# Distance to query: 0.516
# ---

# %%
def generate_response(query: str, context: str) -> str:
    prompt = f"""
   you are an accounts teacher generating questions for mcq
   compile all the information to provide questions for  each topic 20 questions mcq questions,fill in the blanks,scenario based,calculation based with tough mcq options with distractors questions can be given related to table and descriptive also show the question example table


    Context:
    {context}

    User Question: {query}

    Please provide a detailed and accurate answer based on the given context:
    """

    response = openai_client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": " you are a Finance reporter"},
            {"role": "user", "content": prompt}
        ],
        temperature=0
    )

    return response.choices[0].message.content

# %%
import os
from google.colab import userdata
from openai import OpenAI


def generate_response(query: str, context: str) -> str:
    prompt = f"""
    You are an accounts teacher generating questions for MCQ.
    Compile all the information to provide questions for each topic: 20 MCQ questions, fill in the blanks, scenario-based, calculation-based with tough MCQ options with distractors.
    Questions can be given related to tables and descriptions.
    Also, show the question example table.

    Context:
    {context}

    User Question: {query}

    Please provide a detailed and accurate answer based on the given context:
    """


    LLM_FOUNDARY_API = userdata.get('LLM_FOUNDARY_API')
    if LLM_FOUNDARY_API:
        os.environ["LLM_FOUNDARY_API"] = LLM_FOUNDARY_API
        print("API key set successfully from userdata.")
    else:
        LLM_FOUNDARY_API = input("Please enter your LLM Foundry API key: ")
        os.environ["LLM_FOUNDARY_API"] = LLM_FOUNDARY_API
        print("API key set successfully.")


    openai_client = OpenAI(
        api_key=f'{os.environ["LLM_FOUNDARY_API"]}:my-test-project',
        base_url="https://llmfoundry.straive.com/openai/v1/"
    )

    response = openai_client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": "You are a Finance reporter"},
            {"role": "user", "content": prompt}
        ],
        temperature=0
    )

    return response.choices[0].message.content

# %%
def esg_analysis(user_query: str):


    search_results = search_multimodal(user_query)


    context = ""
    for item in search_results:
        if item.properties['content_type'] == 'audio':
            context += f"Audio Transcription from {item.properties['url']}: {item.properties['transcription']}\n\n"
        elif item.properties['content_type'] == 'text':
            context += f"Text from {item.properties['source_document']} (Page {item.properties['page_number']}, Paragraph {item.properties['paragraph_number']}): {item.properties['text']}\n\n"
        elif item.properties['content_type'] == 'image':
            context += f"Image Description from {item.properties['source_document']} (Page {item.properties['page_number']}, Path: {item.properties['image_path']}): {item.properties['description']}\n\n"
        elif item.properties['content_type'] == 'table':
            context += f"Table Description from {item.properties['source_document']} (Page {item.properties['page_number']}): {item.properties['description']}\n\n"


    response = generate_response(user_query, context)


    sources = []
    for item in search_results:
        source = {
            "type": item.properties["content_type"],
            "distance": item.metadata.distance
        }
        if item.properties["content_type"] == 'text':
            source.update({
                "document": item.properties["source_document"],
                "page": item.properties["page_number"],
                "paragraph": item.properties["paragraph_number"]
            })
        elif item.properties["content_type"] == 'image':
            source.update({
                "document": item.properties["source_document"],
                "page": item.properties["page_number"],
                "image_path": item.properties["image_path"]
            })
        elif item.properties["content_type"] == 'table':
            source.update({
                "document": item.properties["source_document"],
                "page": item.properties["page_number"]
            })
        elif item.properties["content_type"] == 'audio':
            source.update({
                "url": item.properties["url"]
            })
        sources.append(source)


    sources.sort(key=lambda x: x['distance'])

    final_output = {
        "user_query": user_query,
        "ai_response": response,
        "sources": sources
    }

    return final_output

# %%
# !pip -qqq install textwrap3

# %%
import textwrap

def wrap_text(text, width=120):

    wrapped_text = textwrap.fill(text, width=width)

    return wrapped_text

# %%
def analyze_and_print_esg_results(user_question):
    result = esg_analysis(user_question)

    print("User Query:", result["user_query"])
    print("\nAI Response:", wrap_text(result["ai_response"]))
    print("\nSources (sorted by relevance):")
    for source in result["sources"]:
        print(f"- Type: {source['type']}, Distance: {source['distance']:.3f}")
        if source['type'] == 'text':
            print(f"  Document: {source['document']}, Page: {source['page']}, Paragraph: {source['paragraph']}")
        elif source['type'] == 'image':
            print(f"  Document: {source['document']}, Page: {source['page']}, Image Path: {source['image_path']}")
        elif source['type'] == 'table':
            print(f"  Document: {source['document']}, Page: {source['page']}")
        elif source['type'] == 'audio':
            print(f"  URL: {source['url']}")
        print("---")

# %%
user_question = '''
 you are an accounts teacher generating questions for mcq
   compile all the information to provide questions for  each topic 20 questions mcq questions,fill in the blanks,scenario based,calculation based with tough mcq options with distractors questions can be given related to table and descriptive also show the question example table
{context}

make it morestractured give space for each ques
{query}'''
analyze_and_print_esg_results(user_question)
# Out:
# API key set successfully from userdata.
# User Query:
#  you are an accounts teacher generating questions for mcq
#    compile all the information to provide questions for  each topic 20 questions mcq questions,fill in the blanks,scenario based,calculation based with tough mcq options with distractors questions can be given related to table and descriptive also show the question example table
# {context}
#
# make it morestractured give space for each ques
# {query}
#
# AI Response: Certainly! Below is a structured compilation of 20 questions related to accounts payable and the purchase of supplies,
# including multiple-choice questions (MCQs), fill-in-the-blanks, scenario-based questions, and calculation-based
# questions. Each question is designed to challenge students and includes distractors.  ### Example Table: Purchase of
# Supplies  | Date       | Item Description | Quantity | Unit Price | Total Cost | Vendor         | Payment Method |
# |------------|------------------|----------|------------|------------|----------------|-----------------| | 2023-01-01 |
# Paper            | 10       | $5         | $50        | Office Supplies | Credit Card     | | 2023-01-02 | Ink
# | 5        | $20        | $100       | Print Co.      | Invoice         | | 2023-01-03 | Office Chair     | 2        |
# $150       | $300       | Furniture Inc.  | Cash            | | 2023-01-04 | Stapler          | 15       | $3         |
# $45        | Office Supplies | Credit Card     | | 2023-01-05 | Whiteboard       | 1        | $200       | $200       |
# Office Supplies | Invoice         |  ### Multiple-Choice Questions (MCQs)  1. **What is the total cost of the supplies
# purchased on January 1, 2023?**    - A) $50    - B) $100    - C) $150    - D) $200      **Correct Answer:** A  2.
# **Which vendor supplied the ink purchased on January 2, 2023?**    - A) Office Supplies    - B) Print Co.    - C)
# Furniture Inc.    - D) Stationery World      **Correct Answer:** B  3. **If the total cost of an item is $300 and the
# unit price is $150, how many units were purchased?**    - A) 1    - B) 2    - C) 3    - D) 4      **Correct Answer:** B
# 4. **Which payment method was used for the stapler purchased on January 4, 2023?**    - A) Cash    - B) Credit Card    -
# C) Invoice    - D) Check      **Correct Answer:** B  5. **What is the total quantity of items purchased from Office
# Supplies?**    - A) 25    - B) 30    - C) 35    - D) 40      **Correct Answer:** A  6. **Which of the following items
# has the highest unit price?**    - A) Paper    - B) Ink    - C) Office Chair    - D) Stapler      **Correct Answer:** C
# 7. **What is the primary purpose of the 'Payment Method' column in the table?**    - A) To track the delivery date    -
# B) To record how the payment was made    - C) To list the vendors    - D) To calculate total costs      **Correct
# Answer:** B  8. **If the total cost of the whiteboard is $200, what is the unit price if only one unit was purchased?**
# - A) $100    - B) $150    - C) $200    - D) $250      **Correct Answer:** C  ### Fill-in-the-Blanks  9. **The total cost
# is calculated by multiplying the quantity by the __________.**      **Correct Answer:** Unit Price  10. **The __________
# column indicates the supplier from whom the supplies were purchased.**      **Correct Answer:** Vendor  ### Scenario-
# Based Questions  11. **A company needs to purchase additional office supplies. If they decide to buy 20 units of paper
# at $5 each, what will be the total cost?**    - A) $75    - B) $100    - C) $125    - D) $150      **Correct Answer:** B
# 12. **If a vendor offers a 10% discount on a $200 invoice, what will be the final amount payable?**    - A) $180    - B)
# $190    - C) $200    - D) $210      **Correct Answer:** A  ### Calculation-Based Questions  13. **Calculate the total
# cost for 15 staplers purchased at $3 each.**    - A) $30    - B) $35    - C) $40    - D) $45      **Correct Answer:** A
# 14. **If a company has a total accounts payable of $1,000 and pays off $400, what is the remaining balance?**    - A)
# $600    - B) $700    - C) $800    - D) $900      **Correct Answer:** A  15. **If the company purchases 5 office chairs
# at $150 each, what is the total expenditure?**    - A) $500    - B) $600    - C) $700    - D) $800      **Correct
# Answer:** B  ### Additional Questions  16. **Which of the following is NOT a typical column in a purchase supplies
# table?**    - A) Date    - B) Item Description    - C) Employee Name    - D) Total Cost      **Correct Answer:** C  17.
# **What is the significance of tracking the 'Quantity' of supplies purchased?**    - A) To determine employee performance
# - B) To manage inventory levels effectively    - C) To calculate employee bonuses    - D) To assess vendor reliability
# **Correct Answer:** B  18. **If a company uses a credit card for payment, which column would reflect this information?**
# - A) Date    - B) Vendor    - C) Payment Method    - D) Total Cost      **Correct Answer:** C  19. **If the total cost
# of supplies purchased is $500 and the company has a budget of $600, what is the remaining budget after the purchase?**
# - A) $50    - B) $100    - C) $150    - D) $200      **Correct Answer:** B  20. **In the context of accounts payable,
# what does the term 'due date' refer to?**    - A) The date when the supplies are delivered    - B) The date by which
# payment must be made    - C) The date when the invoice is issued    - D) The date when the order is placed
# **Correct Answer:** B  This structured approach provides a comprehensive set of questions that cover various aspects of
# accounts payable and the purchase of supplies, ensuring a thorough understanding of the topic.
#
# Sources (sorted by relevance):
# - Type: table, Distance: 0.469
#   Document: /content/spi24360_ch02_042-103_CS_pf_IACPs.pdf, Page: 19
# ---
# - Type: table, Distance: 0.477
#   Document: /content/spi24360_ch02_042-103_CS_pf_IACPs.pdf, Page: 15
# ---
# - Type: table, Distance: 0.526
#   Document: /content/spi24360_ch02_042-103_CS_pf_IACPs.pdf, Page: 9
# ---

# %%
result=analyze_and_print_esg_results(user_question)
formatted_data = f"""
   User Query: {result["user_query"]}

   AI Response: {result["ai_response"]}

   Sources (sorted by relevance):
   {analyze_and_print_esg_results['sources']}
   """
# Out:
# API key set successfully from userdata.
# User Query:
#  you are an accounts teacher generating questions for mcq
#    compile all the information to provide questions for  each topic 20 questions mcq questions,fill in the blanks,scenario based,calculation based with tough mcq options with distractors questions can be given related to table and descriptive also show the question example table
# {context}
#
# make it morestractured give space for each ques
# {query}
#
# AI Response: Certainly! Below is a structured compilation of 20 questions related to accounts payable and the purchase of supplies,
# including multiple-choice questions (MCQs), fill-in-the-blanks, scenario-based questions, and calculation-based
# questions. Each question is designed to challenge students and includes distractors.  ### Example Table: Purchase of
# Supplies  | Date       | Item Description | Quantity | Unit Price | Total Cost | Vendor         | Payment Method |
# |------------|------------------|----------|------------|------------|----------------|-----------------| | 2023-01-01 |
# Paper            | 10       | $5         | $50        | Office Supplies | Credit Card     | | 2023-01-02 | Ink
# | 5        | $20        | $100       | Print Co.      | Invoice         | | 2023-01-03 | Office Chair     | 2        |
# $150       | $300       | Furniture Inc.  | Cash            | | 2023-01-04 | Stapler          | 15       | $3         |
# $45        | Office Supplies | Credit Card     | | 2023-01-05 | Whiteboard       | 1        | $200       | $200       |
# Office Supplies | Invoice         |  ### Multiple-Choice Questions (MCQs)  1. **What is the total cost of the supplies
# purchased on January 1, 2023?**    - A) $50    - B) $100    - C) $150    - D) $200      **Correct Answer:** A  2.
# **Which vendor supplied the ink purchased on January 2, 2023?**    - A) Office Supplies    - B) Print Co.    - C)
# Furniture Inc.    - D) Stationery World      **Correct Answer:** B  3. **If the total cost of an item is $300 and the
# unit price is $150, how many units were purchased?**    - A) 1    - B) 2    - C) 3    - D) 4      **Correct Answer:** B
# 4. **Which payment method was used for the stapler purchased on January 4, 2023?**    - A) Cash    - B) Credit Card    -
# C) Invoice    - D) Check      **Correct Answer:** B  5. **What is the total quantity of items purchased from Office
# Supplies?**    - A) 25    - B) 30    - C) 35    - D) 40      **Correct Answer:** A  6. **Which of the following items
# has the highest unit price?**    - A) Paper    - B) Ink    - C) Office Chair    - D) Stapler      **Correct Answer:** C
# 7. **What is the primary purpose of the 'Payment Method' column in the table?**    - A) To track the delivery date    -
# B) To record how the payment was made    - C) To list the vendors    - D) To calculate total costs      **Correct
# Answer:** B  8. **If the total cost of the whiteboard is $200, what is the unit price if only one unit was purchased?**
# - A) $100    - B) $150    - C) $200    - D) $250      **Correct Answer:** C  ### Fill-in-the-Blanks  9. **The total cost
# is calculated by multiplying the quantity by the __________.**      **Correct Answer:** Unit Price  10. **The __________
# column indicates the supplier from whom the supplies were purchased.**      **Correct Answer:** Vendor  ### Scenario-
# Based Questions  11. **A company needs to purchase additional office supplies. If they decide to buy 20 units of paper
# at $5 each, what will be the total cost?**    - A) $75    - B) $100    - C) $125    - D) $150      **Correct Answer:** B
# 12. **If a vendor offers a 10% discount on a $200 invoice, what will be the final amount payable?**    - A) $180    - B)
# $190    - C) $200    - D) $210      **Correct Answer:** A  ### Calculation-Based Questions  13. **Calculate the total
# cost for 15 staplers purchased at $3 each.**    - A) $30    - B) $35    - C) $40    - D) $45      **Correct Answer:** A
# 14. **If a company has a total accounts payable of $1,000 and pays off $400, what is the remaining balance?**    - A)
# $600    - B) $700    - C) $800    - D) $900      **Correct Answer:** A  15. **If the company purchases 5 office chairs
# at $150 each, what is the total expenditure?**    - A) $500    - B) $600    - C) $700    - D) $800      **Correct
# Answer:** B  ### Additional Questions  16. **Which of the following is NOT a typical column in a purchase supplies
# table?**    - A) Date    - B) Item Description    - C) Employee Name    - D) Total Cost      **Correct Answer:** C  17.
# **What is the significance of tracking the 'Quantity' of supplies purchased?**    - A) To determine employee performance
# - B) To manage inventory levels effectively    - C) To calculate employee bonuses    - D) To assess vendor reliability
# **Correct Answer:** B  18. **If a company uses a credit card for payment, which column would reflect this information?**
# - A) Date    - B) Vendor    - C) Payment Method    - D) Total Cost      **Correct Answer:** C  19. **If the total cost
# of supplies purchased is $500 and the company has a budget of $600, what is the remaining budget after the purchase?**
# - A) $50    - B) $100    - C) $150    - D) $200      **Correct Answer:** B  20. **In the context of accounts payable,
# what does the term 'due date' refer to?**    - A) The date when the supplies are delivered    - B) The date by which
# payment must be made    - C) The date when the invoice is issued    - D) The date when the order is placed
# **Correct Answer:** B  This structured approach provides a comprehensive set of questions that cover various aspects of
# accounts payable and the purchase of supplies, ensuring a thorough understanding of the topic.
#
# Sources (sorted by relevance):
# - Type: table, Distance: 0.469
#   Document: /content/spi24360_ch02_042-103_CS_pf_IACPs.pdf, Page: 19
# ---
# - Type: table, Distance: 0.477
#   Document: /content/spi24360_ch02_042-103_CS_pf_IACPs.pdf, Page: 15
# ---
# - Type: table, Distance: 0.526
#   Document: /content/spi24360_ch02_042-103_CS_pf_IACPs.pdf, Page: 9
# ---
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-130-c40473202cb1> in <cell line: 2>()
#       1 result=analyze_and_print_esg_results(user_question)
#       2 formatted_data = f"""
# ----> 3    User Query: {result["user_query"]}
#       4
#       5    AI Response: {result["ai_response"]}
#
# TypeError: 'NoneType' object is not subscriptable
